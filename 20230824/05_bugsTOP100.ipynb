# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Computer.use_jedi = False
import requests
from bs4 import BeautifulSoup
from datetime import datetime as dt

# %%
print(dt.now())
# Out:
# 2023-08-23 17:04:21.150439

# %%
targetSite = 'https://music.bugs.co.kr/chart'
request = requests.get(targetSite)
# print(request)
html = request.text
# print(html)
soup = BeautifulSoup(html, 'html.parser')
# print(soup)

# %%
# 노래 제목 크롤링
titles = soup.findAll('p', {'class': 'title'})
# print(len(titles))
# print(titles)

for i in range(len(titles)):
    # print('{:3d}위 {}'.format(i + 1, titles[i].text.strip()))
    # print('{:3d}위 {}'.format(i + 1, titles[i].text.split('\n')[1]))
    print('{:3d}위 {}'.format(i + 1, titles[i].text.strip().split('\n')[0]))
# Out:
#   1위 Love Lee
#   2위 ETA
#   3위 후라이의 꿈
#   4위 Super Shy
#   5위 Seven (feat. Latto) - Clean Ver.
#   6위 Fast Forward
#   7위 New Jeans
#   8위 I AM
#   9위 Summer (Feat. BE’O (비오))
#  10위 Steal The Show (From “엘리멘탈”)
#  11위 헤어지자 말해요
#  12위 퀸카 (Queencard)
#  13위 Underwater
#  14위 Cool With You
#  15위 이브, 프시케 그리고 푸른 수염의 아내
#  16위 Spicy
#  17위 Hype Boy
#  18위 Ditto
#  19위 Kitsch
#  20위 Bubble
#  21위 Attention
#  22위 여름이 들려 (Summer Comes)
#  23위 CAKE
#  24위 After LIKE
#  25위 UNFORGIVEN (feat. Nile Rodgers)
#  26위 OMG
#  27위 ASAP
#  28위 사막에서 꽃을 피우듯
#  29위 LOVE DIVE
#  30위 건물 사이에 피어난 장미 (Rose Blossom)
#  31위 Dangerously
#  32위 사건의 지평선
#  33위 한 페이지가 될 수 있게
#  34위 I Don’t Think That I Like Her
#  35위 Allergy
#  36위 꽃
#  37위 너의 모든 순간
#  38위 Teddy Bear
#  39위 손오공
#  40위 ANTIFRAGILE
#  41위 Shine
#  42위 When I Get Old
#  43위 잠깐 시간 될까
#  44위 Cupid
#  45위 Miracle (우리라는 기적)
#  46위 STAY
#  47위 ISTJ
#  48위 오르트구름
#  49위 That's Hilarious
#  50위 주저하는 연인들을 위해
#  51위 사실말야내가말야그게그러니까말이야
#  52위 Off My Face
#  53위 That’s Not How This Works (feat. Dan + Shay)
#  54위 Shut Down
#  55위 심(心)
#  56위 모든 날, 모든 순간 (Every day, Every Moment)
#  57위 KNOCK
#  58위 I WANT
#  59위 파이팅 해야지 (Feat. 이영지)
#  60위 TOMBOY
#  61위 취중고백
#  62위 Thirsty
#  63위 다정히 내 이름을 부르면
#  64위 Better Things
#  65위 Monologue
#  66위 INVU
#  67위 사랑인가 봐
#  68위 Still With You
#  69위 그때 그 순간 그대로 (그그그)
#  70위 Roller Coaster
#  71위 나의 바람 (Wind And Wish)
#  72위 민들레 (single ver.)
#  73위 Cookie
#  74위 나의 X에게
#  75위 Pink Venom
#  76위 ELEVEN
#  77위 해요 (2022)
#  78위 그라데이션
#  79위 예뻤어 (여름날 우리 X 김민석 (멜로망스))
#  80위 나에게 그대만이
#  81위 Candy
#  82위 도깨비불 (Illusion)
#  83위 Dynamite
#  84위 빛이 나는 너에게
#  85위 PERFORMER
#  86위 Sugarcoat (NATTY Solo)
#  87위 FEARLESS
#  88위 달빛에 그려지는
#  89위 사랑은 늘 도망가
#  90위 잘 지내자, 우리 (여름날 우리 X 로이킴)
#  91위 HARD
#  92위 Love Me Like This
#  93위 Miracle (우리라는 기적) (Inst.)
#  94위 정이라고 하자 (Feat. 10CM)
#  95위 여름날 (feat. 하현상)
#  96위 물론
#  97위 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
#  98위 특
#  99위 Nxde
# 100위 미친 사랑의 노래

# %%
# 아티스트 크롤링
artists = soup.findAll('p', {'class': 'artist'})
# print(len(artists))
# print(artists)

for i in range(len(artists)):
    # print('{:3d}위 {}'.format(i + 1, artists[i].text.strip())) # 적절 X
    # print('{:3d}위 {}'.format(i + 1, artists[i].text.split('\n')[1])) # 적절 X
    print('{:3d}위 {}'.format(i + 1, artists[i].text.strip().split('\n')[0]))
# Out:
#   1위 AKMU(악뮤)
#   2위 NewJeans
#   3위 AKMU(악뮤)
#   4위 NewJeans
#   5위 정국
#   6위 전소미
#   7위 NewJeans
#   8위 IVE (아이브)
#   9위 Paul Blanco
#  10위 Lauv(라우브)
#  11위 박재정
#  12위 (여자)아이들
#  13위 권은비
#  14위 NewJeans
#  15위 LE SSERAFIM (르세라핌)
#  16위 aespa
#  17위 NewJeans
#  18위 NewJeans
#  19위 IVE (아이브)
#  20위 STAYC(스테이씨)
#  21위 NewJeans
#  22위 오마이걸(OH MY GIRL)
#  23위 ITZY (있지)
#  24위 IVE (아이브)
#  25위 LE SSERAFIM (르세라핌)
#  26위 NewJeans
#  27위 NewJeans
#  28위 우디(Woody)
#  29위 IVE (아이브)
#  30위 H1-KEY (하이키)
#  31위 Charlie Puth(찰리 푸스)
#  32위 윤하(Younha/ユンナ)
#  33위 DAY6 (데이식스)
#  34위 Charlie Puth(찰리 푸스)
#  35위 (여자)아이들
#  36위 지수(JISOO)
#  37위 성시경
#  38위 STAYC(스테이씨)
#  39위 세븐틴(SEVENTEEN)
#  40위 LE SSERAFIM (르세라핌)
#  41위 리베란테(Libelante)
#  42위 Christopher(크리스토퍼)
#  43위 이무진
#  44위 FIFTY FIFTY
#  45위 포르테나 (Forténa)
#  46위 The Kid LAROI
#  47위 NCT DREAM
#  48위 윤하(Younha/ユンナ)
#  49위 Charlie Puth(찰리 푸스)
#  50위 잔나비
#  51위 케이시
#  52위 Justin Bieber(저스틴 비버)
#  53위 Charlie Puth(찰리 푸스)
#  54위 BLACKPINK
#  55위 DK(디셈버)
#  56위 폴킴(Paul Kim)
#  57위 이채연
#  58위 IVE (아이브)
#  59위 부석순(SEVENTEEN)
#  60위 (여자)아이들
#  61위 김민석 (멜로망스)
#  62위 aespa
#  63위 경서예지
#  64위 aespa
#  65위 테이(Tei)
#  66위 태연 (TAEYEON)
#  67위 멜로망스(MeloMance)
#  68위 정국
#  69위 WSG워너비 (가야G)
#  70위 NMIXX
#  71위 비투비
#  72위 우효(Oohyo)
#  73위 NewJeans
#  74위 경서
#  75위 BLACKPINK
#  76위 IVE (아이브)
#  77위 #안녕
#  78위 10CM
#  79위 김민석 (멜로망스)
#  80위 탑현
#  81위 NCT DREAM
#  82위 aespa
#  83위 방탄소년단
#  84위 던 (DAWN)
#  85위 VANNER(배너)
#  86위 KISS OF LIFE
#  87위 LE SSERAFIM (르세라핌)
#  88위 미연 ((여자)아이들)
#  89위 임영웅
#  90위 로이킴
#  91위 SHINee (샤이니)
#  92위 NMIXX
#  93위 포르테나 (Forténa)
#  94위 BIG Naughty (서동현)
#  95위 볼빨간사춘기
#  96위 허각
#  97위 너드커넥션(Nerd Connection)
#  98위 Stray Kids (스트레이 키즈)
#  99위 (여자)아이들
# 100위 김연지

# %%
print(dt.now())
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    print('{:3d}위 {} - {}'.format(i + 1, artist, title))
# Out:
# 2023-08-23 17:04:21.757845
#   1위 AKMU(악뮤) - Love Lee
#   2위 NewJeans - ETA
#   3위 AKMU(악뮤) - 후라이의 꿈
#   4위 NewJeans - Super Shy
#   5위 정국 - Seven (feat. Latto) - Clean Ver.
#   6위 전소미 - Fast Forward
#   7위 NewJeans - New Jeans
#   8위 IVE (아이브) - I AM
#   9위 Paul Blanco - Summer (Feat. BE’O (비오))
#  10위 Lauv(라우브) - Steal The Show (From “엘리멘탈”)
#  11위 박재정 - 헤어지자 말해요
#  12위 (여자)아이들 - 퀸카 (Queencard)
#  13위 권은비 - Underwater
#  14위 NewJeans - Cool With You
#  15위 LE SSERAFIM (르세라핌) - 이브, 프시케 그리고 푸른 수염의 아내
#  16위 aespa - Spicy
#  17위 NewJeans - Hype Boy
#  18위 NewJeans - Ditto
#  19위 IVE (아이브) - Kitsch
#  20위 STAYC(스테이씨) - Bubble
#  21위 NewJeans - Attention
#  22위 오마이걸(OH MY GIRL) - 여름이 들려 (Summer Comes)
#  23위 ITZY (있지) - CAKE
#  24위 IVE (아이브) - After LIKE
#  25위 LE SSERAFIM (르세라핌) - UNFORGIVEN (feat. Nile Rodgers)
#  26위 NewJeans - OMG
#  27위 NewJeans - ASAP
#  28위 우디(Woody) - 사막에서 꽃을 피우듯
#  29위 IVE (아이브) - LOVE DIVE
#  30위 H1-KEY (하이키) - 건물 사이에 피어난 장미 (Rose Blossom)
#  31위 Charlie Puth(찰리 푸스) - Dangerously
#  32위 윤하(Younha/ユンナ) - 사건의 지평선
#  33위 DAY6 (데이식스) - 한 페이지가 될 수 있게
#  34위 Charlie Puth(찰리 푸스) - I Don’t Think That I Like Her
#  35위 (여자)아이들 - Allergy
#  36위 지수(JISOO) - 꽃
#  37위 성시경 - 너의 모든 순간
#  38위 STAYC(스테이씨) - Teddy Bear
#  39위 세븐틴(SEVENTEEN) - 손오공
#  40위 LE SSERAFIM (르세라핌) - ANTIFRAGILE
#  41위 리베란테(Libelante) - Shine
#  42위 Christopher(크리스토퍼) - When I Get Old
#  43위 이무진 - 잠깐 시간 될까
#  44위 FIFTY FIFTY - Cupid
#  45위 포르테나 (Forténa) - Miracle (우리라는 기적)
#  46위 The Kid LAROI - STAY
#  47위 NCT DREAM - ISTJ
#  48위 윤하(Younha/ユンナ) - 오르트구름
#  49위 Charlie Puth(찰리 푸스) - That's Hilarious
#  50위 잔나비 - 주저하는 연인들을 위해
#  51위 케이시 - 사실말야내가말야그게그러니까말이야
#  52위 Justin Bieber(저스틴 비버) - Off My Face
#  53위 Charlie Puth(찰리 푸스) - That’s Not How This Works (feat. Dan + Shay)
#  54위 BLACKPINK - Shut Down
#  55위 DK(디셈버) - 심(心)
#  56위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  57위 이채연 - KNOCK
#  58위 IVE (아이브) - I WANT
#  59위 부석순(SEVENTEEN) - 파이팅 해야지 (Feat. 이영지)
#  60위 (여자)아이들 - TOMBOY
#  61위 김민석 (멜로망스) - 취중고백
#  62위 aespa - Thirsty
#  63위 경서예지 - 다정히 내 이름을 부르면
#  64위 aespa - Better Things
#  65위 테이(Tei) - Monologue
#  66위 태연 (TAEYEON) - INVU
#  67위 멜로망스(MeloMance) - 사랑인가 봐
#  68위 정국 - Still With You
#  69위 WSG워너비 (가야G) - 그때 그 순간 그대로 (그그그)
#  70위 NMIXX - Roller Coaster
#  71위 비투비 - 나의 바람 (Wind And Wish)
#  72위 우효(Oohyo) - 민들레 (single ver.)
#  73위 NewJeans - Cookie
#  74위 경서 - 나의 X에게
#  75위 BLACKPINK - Pink Venom
#  76위 IVE (아이브) - ELEVEN
#  77위 #안녕 - 해요 (2022)
#  78위 10CM - 그라데이션
#  79위 김민석 (멜로망스) - 예뻤어 (여름날 우리 X 김민석 (멜로망스))
#  80위 탑현 - 나에게 그대만이
#  81위 NCT DREAM - Candy
#  82위 aespa - 도깨비불 (Illusion)
#  83위 방탄소년단 - Dynamite
#  84위 던 (DAWN) - 빛이 나는 너에게
#  85위 VANNER(배너) - PERFORMER
#  86위 KISS OF LIFE - Sugarcoat (NATTY Solo)
#  87위 LE SSERAFIM (르세라핌) - FEARLESS
#  88위 미연 ((여자)아이들) - 달빛에 그려지는
#  89위 임영웅 - 사랑은 늘 도망가
#  90위 로이킴 - 잘 지내자, 우리 (여름날 우리 X 로이킴)
#  91위 SHINee (샤이니) - HARD
#  92위 NMIXX - Love Me Like This
#  93위 포르테나 (Forténa) - Miracle (우리라는 기적) (Inst.)
#  94위 BIG Naughty (서동현) - 정이라고 하자 (Feat. 10CM)
#  95위 볼빨간사춘기 - 여름날 (feat. 하현상)
#  96위 허각 - 물론
#  97위 너드커넥션(Nerd Connection) - 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
#  98위 Stray Kids (스트레이 키즈) - 특
#  99위 (여자)아이들 - Nxde
# 100위 김연지 - 미친 사랑의 노래

# %%
# 크롤링한 결과를 텍스트 파일에 저장한다.
# file = open('C:\\k_digital\\python\\crawling\\workspace\\output\\bugsTOP100.txt', 'w') # 절대경로
# file = open('C:/k_digital/python/crawling/workspace/output/bugsTOP100.txt', 'w') # 절대경로
# file = open('./output/bugsTOP100.txt', 'w') # 상대경로
# 위의 open() 함수와 같이 파일을 열때 'cp949 ~' 에러가 발생되면 아래와 같이 open 한다.
file = open('./output/bugsTOP100.txt', 'w', -1, 'utf-8')
# file.write(str(dt.now()) + '\n')
file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
for i in range(100):
    artist = artists[i].text.strip().split('\n')[0]
    title = titles[i].text.strip().split('\n')[0]
    file.write('{:3d}위 {} - {}\n'.format(i + 1, artist, title))
file.close()
print('bugdTOP100.txt 파일로 쓰기 완료')
# Out:
# bugdTOP100.txt 파일로 쓰기 완료

# %%
# with 구문을 사용해서 파일을 open 하면 with 블록의 내용이 모두 실행된 후 자동으로 파일을 닫는다.
with open('./output/bugsTOP100.txt', 'w', -1, 'utf-8') as file:
    file.write(dt.now().strftime('%Y-%m-%d %H:%M:%S') + '\n')
    for i in range(100):
        artist = artists[i].text.strip().split('\n')[0]
        title = titles[i].text.strip().split('\n')[0]
        file.write('{:3d}위 {} - {}\n'.format(i + 1, artist, title))
# ===== with
print('bugdTOP100.txt 파일로 쓰기 완료')
# Out:
# bugdTOP100.txt 파일로 쓰기 완료

# %%
# 폴더에 저장된 파일 이름 가져오기
import os
fileList = os.listdir('./output/')
print(fileList)
print(type(fileList))
for file in fileList:
    # print(file[:-4]) # 확장명이 무조건 3글자일 때
    print(file[:file.rindex('.')]) # 파일 이름에 '.'이 여러 개이고 확장명 길이가 가변적일 때
# Out:
# ['bugsTOP100.txt']
# <class 'list'>
# bugsTOP100

# %%
# 텍스트 파일에 저장된 데이터를 읽어서 화면에 출력한다.
try:
    file = open('./output/bugsTOP100.txt', 'r', -1, 'utf-8')
    lines = file.readlines()
    for line in lines:
        print(line.rstrip())
except FileNotFoundError:
    print('디스크에 파일이 없습니다.')
# Out:
# 2023-08-23 17:04:21
#   1위 AKMU(악뮤) - Love Lee
#   2위 NewJeans - ETA
#   3위 AKMU(악뮤) - 후라이의 꿈
#   4위 NewJeans - Super Shy
#   5위 정국 - Seven (feat. Latto) - Clean Ver.
#   6위 전소미 - Fast Forward
#   7위 NewJeans - New Jeans
#   8위 IVE (아이브) - I AM
#   9위 Paul Blanco - Summer (Feat. BE’O (비오))
#  10위 Lauv(라우브) - Steal The Show (From “엘리멘탈”)
#  11위 박재정 - 헤어지자 말해요
#  12위 (여자)아이들 - 퀸카 (Queencard)
#  13위 권은비 - Underwater
#  14위 NewJeans - Cool With You
#  15위 LE SSERAFIM (르세라핌) - 이브, 프시케 그리고 푸른 수염의 아내
#  16위 aespa - Spicy
#  17위 NewJeans - Hype Boy
#  18위 NewJeans - Ditto
#  19위 IVE (아이브) - Kitsch
#  20위 STAYC(스테이씨) - Bubble
#  21위 NewJeans - Attention
#  22위 오마이걸(OH MY GIRL) - 여름이 들려 (Summer Comes)
#  23위 ITZY (있지) - CAKE
#  24위 IVE (아이브) - After LIKE
#  25위 LE SSERAFIM (르세라핌) - UNFORGIVEN (feat. Nile Rodgers)
#  26위 NewJeans - OMG
#  27위 NewJeans - ASAP
#  28위 우디(Woody) - 사막에서 꽃을 피우듯
#  29위 IVE (아이브) - LOVE DIVE
#  30위 H1-KEY (하이키) - 건물 사이에 피어난 장미 (Rose Blossom)
#  31위 Charlie Puth(찰리 푸스) - Dangerously
#  32위 윤하(Younha/ユンナ) - 사건의 지평선
#  33위 DAY6 (데이식스) - 한 페이지가 될 수 있게
#  34위 Charlie Puth(찰리 푸스) - I Don’t Think That I Like Her
#  35위 (여자)아이들 - Allergy
#  36위 지수(JISOO) - 꽃
#  37위 성시경 - 너의 모든 순간
#  38위 STAYC(스테이씨) - Teddy Bear
#  39위 세븐틴(SEVENTEEN) - 손오공
#  40위 LE SSERAFIM (르세라핌) - ANTIFRAGILE
#  41위 리베란테(Libelante) - Shine
#  42위 Christopher(크리스토퍼) - When I Get Old
#  43위 이무진 - 잠깐 시간 될까
#  44위 FIFTY FIFTY - Cupid
#  45위 포르테나 (Forténa) - Miracle (우리라는 기적)
#  46위 The Kid LAROI - STAY
#  47위 NCT DREAM - ISTJ
#  48위 윤하(Younha/ユンナ) - 오르트구름
#  49위 Charlie Puth(찰리 푸스) - That's Hilarious
#  50위 잔나비 - 주저하는 연인들을 위해
#  51위 케이시 - 사실말야내가말야그게그러니까말이야
#  52위 Justin Bieber(저스틴 비버) - Off My Face
#  53위 Charlie Puth(찰리 푸스) - That’s Not How This Works (feat. Dan + Shay)
#  54위 BLACKPINK - Shut Down
#  55위 DK(디셈버) - 심(心)
#  56위 폴킴(Paul Kim) - 모든 날, 모든 순간 (Every day, Every Moment)
#  57위 이채연 - KNOCK
#  58위 IVE (아이브) - I WANT
#  59위 부석순(SEVENTEEN) - 파이팅 해야지 (Feat. 이영지)
#  60위 (여자)아이들 - TOMBOY
#  61위 김민석 (멜로망스) - 취중고백
#  62위 aespa - Thirsty
#  63위 경서예지 - 다정히 내 이름을 부르면
#  64위 aespa - Better Things
#  65위 테이(Tei) - Monologue
#  66위 태연 (TAEYEON) - INVU
#  67위 멜로망스(MeloMance) - 사랑인가 봐
#  68위 정국 - Still With You
#  69위 WSG워너비 (가야G) - 그때 그 순간 그대로 (그그그)
#  70위 NMIXX - Roller Coaster
#  71위 비투비 - 나의 바람 (Wind And Wish)
#  72위 우효(Oohyo) - 민들레 (single ver.)
#  73위 NewJeans - Cookie
#  74위 경서 - 나의 X에게
#  75위 BLACKPINK - Pink Venom
#  76위 IVE (아이브) - ELEVEN
#  77위 #안녕 - 해요 (2022)
#  78위 10CM - 그라데이션
#  79위 김민석 (멜로망스) - 예뻤어 (여름날 우리 X 김민석 (멜로망스))
#  80위 탑현 - 나에게 그대만이
#  81위 NCT DREAM - Candy
#  82위 aespa - 도깨비불 (Illusion)
#  83위 방탄소년단 - Dynamite
#  84위 던 (DAWN) - 빛이 나는 너에게
#  85위 VANNER(배너) - PERFORMER
#  86위 KISS OF LIFE - Sugarcoat (NATTY Solo)
#  87위 LE SSERAFIM (르세라핌) - FEARLESS
#  88위 미연 ((여자)아이들) - 달빛에 그려지는
#  89위 임영웅 - 사랑은 늘 도망가
#  90위 로이킴 - 잘 지내자, 우리 (여름날 우리 X 로이킴)
#  91위 SHINee (샤이니) - HARD
#  92위 NMIXX - Love Me Like This
#  93위 포르테나 (Forténa) - Miracle (우리라는 기적) (Inst.)
#  94위 BIG Naughty (서동현) - 정이라고 하자 (Feat. 10CM)
#  95위 볼빨간사춘기 - 여름날 (feat. 하현상)
#  96위 허각 - 물론
#  97위 너드커넥션(Nerd Connection) - 그대만 있다면 (여름날 우리 X 너드커넥션 (Nerd Connection))
#  98위 Stray Kids (스트레이 키즈) - 특
#  99위 (여자)아이들 - Nxde
# 100위 김연지 - 미친 사랑의 노래
