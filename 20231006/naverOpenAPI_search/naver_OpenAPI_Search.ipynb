# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Completer.use_jedi = False
import requests

# %%
headers = {
    'User-agent': 'Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko',
    'X-Naver-Client-Id': 'NHtVrL_nvgfod8MoAJnK',
    'X-Naver-Client-Secret': 'xIbayY2gfo'
}

# %% [markdown]
# 블로그 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/blog.json?query=' + searchText
# print(targetSite)

response = requests.get(targetSite, headers=headers)
# print(type(response.text))
# print(response.text)
searchResult = response.json()
# print(type(searchResult))
# print(searchResult.keys())
# print(searchResult['items'])
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 영화
# {'title': '<b>영화</b> 30일  한국 로맨틱 코미디 <b>영화</b> 정보  출연진 후기... ', 'link': 'https://blog.naver.com/mindeft/223229217942', 'description': '<b>영화</b> 30일 한국 로맨틱 코미디 <b>영화</b> 정보 출연진 후기 결말 (2023) 한국 로맨틱 코미디 <b>영화</b> 30일 정보 사진 출처 네이버 <b>영화</b> 개봉일 2023년 10월 3일 등급 12세 관람가 장르 로맨틱 코미디 국가 한국 러닝타임 119분... ', 'bloggername': '무빙의 영화 TALK', 'bloggerlink': 'blog.naver.com/mindeft', 'postdate': '20231005'}
# ========================================================================================================================
# {'title': '히사이시 조 <b>영화</b>음악콘서트 서울 후기', 'link': 'https://blog.naver.com/nevergiveup0/223228311616', 'description': '꼭 한번 가보고 싶었던 히사이시조 <b>영화</b>음악 콘서트에 다녀왔는데요. 그때의 여운과 감동을 기억하려 바로 포스팅합니다. (내용이 다소 주저리 주저리 합니다) 히사이시 조 <b>영화</b>음악콘서트 공연 한 시간전에... ', 'bloggername': 'ISFP ISFJ', 'bloggerlink': 'blog.naver.com/nevergiveup0', 'postdate': '20231004'}
# ========================================================================================================================
# {'title': '[<b>영화</b>추천] 케빈에 대하여. 수상작', 'link': 'https://blog.naver.com/gia1220/223229744551', 'description': '그녀의 내면을 화면에 정직하게 담은 <b>영화</b>이다. 케빈의 울음소리와 공사장 소음은 비교 대상이 되지... 질문하는 <b>영화</b>이다. 남편 프랭클린은 그녀의 상태를 짐작하지 못한다. 가정적인 아빠의 모습들이 자주... ', 'bloggername': '구름모모', 'bloggerlink': 'blog.naver.com/gia1220', 'postdate': '20231006'}
# ========================================================================================================================
# {'title': '<b>영화</b> 거미집 후기 : 송강호 김지운 환상 콜라보', 'link': 'https://blog.naver.com/bookey3/223228540601', 'description': '추석 연휴가 길다 보니 가족끼리 오붓하게 <b>영화</b>관 많이들 가셨을 텐데요 저 역시 김지운 감독의 <b>영화</b> 거미집 리뷰 남겨봅니다 <b>영화</b> 거미집 후기 : 송강호 김지운 블랙 코미디 환상 콜라보 결정판 저는 사실... ', 'bloggername': '우쿠리의 매일 저장소', 'bloggerlink': 'blog.naver.com/bookey3', 'postdate': '20231005'}
# ========================================================================================================================
# {'title': '인의없는 약쟁이 (<b>영화</b> 마약전쟁, 毒戰, Drug War, 2013)', 'link': 'https://blog.naver.com/wlswnd2/223228325033', 'description': '쑨홍레이 난 이 <b>영화</b>에서 쑨홍레이의 형사연기와 귀머거리 형제의 캐릭터 묘사를 매우 인상적이게... 어쩌면 약물 사형도 <b>영화</b>에 등장하는 범죄자에게는 예의처벌이라고 본다. 공권력을 농락하고 자신의 형제와... ', 'bloggername': '파란꽃', 'bloggerlink': 'blog.naver.com/wlswnd2', 'postdate': '20231005'}
# ========================================================================================================================
# {'title': '<b>영화</b> 속 기술 이야기 12편 – 인터스텔라 -', 'link': 'https://blog.naver.com/love_kopo/223228777848', 'description': '출처/ 워너 브러더스 코리아(주) 오늘의 <b>영화</b> 속 기술 이야기는 미래의 식량난에 당면한 지구를 대체할 행성을 찾아 떠난 우주 탐험과 사랑 더 나아가 인류애를 그린 천만 SF <b>영화</b>! &lt;인터스텔라&gt;입니다... ', 'bloggername': '한국폴리텍대학 공식블로그', 'bloggerlink': 'blog.naver.com/love_kopo', 'postdate': '20231005'}
# ========================================================================================================================
# {'title': '<b>영화</b> 교섭 실화 샘물교회 결말 아쉬움 가득', 'link': 'https://blog.naver.com/sadmn/223229192840', 'description': '바탕의 <b>영화</b> 교섭은 탈레반의 인질이 된 한국인들을 구하기 위해 아프가니스탄으로 간 외교관과 현지 국정원 요원의 교섭 작전을 그렸습니다. 믿고 보는 배우 황정민과 현빈, 강기영 주연으로 한국 <b>영화</b>... ', 'bloggername': '영화의 위로', 'bloggerlink': 'blog.naver.com/sadmn', 'postdate': '20231005'}
# ========================================================================================================================
# {'title': '<b>영화</b> 오픈 더 도어 * 장항준 감독 미스터리 심리스릴러 (정보... ', 'link': 'https://blog.naver.com/rmfoaxj/223228804525', 'description': '부산국제<b>영화</b>제의 시기. 당분간 관련 소식이 뉴스를 장식하겠지. 그렇다면 이때쯤 개봉 소식이 들려올만도 한데... 라는 생각을 하던 타임에 접한 소식이 있다. 바로 2022년 부산국제<b>영화</b>제(BIFF) 에 초청되면서... ', 'bloggername': '멈추지 않는 날들을 위해', 'bloggerlink': 'blog.naver.com/rmfoaxj', 'postdate': '20231005'}
# ========================================================================================================================
# {'title': '<b>영화</b> &quot;박쥐&quot; 출연진 및 줄거리', 'link': 'https://blog.naver.com/webhackyo/223229616117', 'description': '&quot;박쥐&quot;(Thirst, 2009)는 박찬욱 감독의 2009년 대한민국 공포 <b>영화</b>입니다. 이 <b>영화</b>는 공포, 드라마, 블랙 코미디가 독특하게 혼합된 것으로 유명합니다. 출연진 : 현상현 역 - 송강호 : 독실한 가톨릭 신부로 의학... ', 'bloggername': '꿈과 미래', 'bloggerlink': 'blog.naver.com/webhackyo', 'postdate': '20231006'}
# ========================================================================================================================
# {'title': '<b>영화</b> &lt;밀수&gt; : 은밀하게 혹은 대담하게', 'link': 'https://blog.naver.com/true4753/223229217715', 'description': '<b>영화</b> 감상평에 배우들을 한분한분 언급하기엔 너무 관극 주저리 같은 후기가 되어버리는 것 같아... 바다에서 일어난 밀수 이야기인 만큼 여름 겨낭 7월 말 개봉한 <b>영화</b>지만 무빙 종료 시점에서 버프 제대로... ', 'bloggername': '추억이 될 오늘에게 感.중진담', 'bloggerlink': 'blog.naver.com/true4753', 'postdate': '20231006'}
# ========================================================================================================================

# %% [markdown]
# 뉴스 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/news.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 영화
# {'title': "[28th BIFF] 부산 찾은 '코리안 디아스포라'…&quot;가족으로 받아주는 기분&quot;", 'originallink': 'https://news.mtn.co.kr/news-detail/2023100613512081109', 'link': 'https://news.mtn.co.kr/news-detail/2023100613512081109', 'description': "사진 제공=뉴스1할리우드에서 활약 중인 네 명의 재미교포 <b>영화</b>인이 나란히 부산을 찾았다. 6일 오후 부산 해운대구 KNN시어터에서는 제28회 부산국제<b>영화</b>제(BIFF) '코리안 아메리칸 특별전: 코리안 디아스포라' 기자회견이... ", 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': '[사진] 이솜과 안재홍, 스킨십은 액션처럼', 'originallink': 'http://www.osen.co.kr/article/G1112198282', 'link': 'https://n.news.naver.com/mnews/article/109/0004942011?sid=106', 'description': '6일 부산 해운대구 센텀시티 <b>영화</b>의 전당 BIFF X GENESIS 야외무대에서 제28회 부산국제<b>영화</b>제 <b>영화</b> ‘LTNS’ 오픈토크가 열렸다. 이솜과 안재홍이 얘기도중 마주보며 활짝 웃고 있다. 2023.10.06', 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': 'LG유플러스, 전국 매장에서 2030 부산엑스포 응원한다', 'originallink': 'http://www.ilyoseoul.co.kr/news/articleView.html?idxno=479333', 'link': 'http://www.ilyoseoul.co.kr/news/articleView.html?idxno=479333', 'description': '- 10월 한 달 간 전국 2천여 개 매장에 부산엑스포 유치 기원 영상 상영 - 부산국제<b>영화</b>제 기간 이동기지국... 이와 함께 부산국제<b>영화</b>제가 열리는 기간 동안 원활한 통신서비스를 제공하기 위해 파견된 이동기지국에... ', 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': "코믹+버디무비+스릴러 '유괴의 날' [OTT PICK 5]", 'originallink': 'https://www.econovill.com/news/articleView.html?idxno=627396', 'link': 'https://www.econovill.com/news/articleView.html?idxno=627396', 'description': '어느 날 맥스가 숨겨왔던 음악가적 재능을 발견하게 되고, 모자는 음악을 통해 화합하게 된다. 애플tv+가 선댄스 <b>영화</b>제에서 스트리밍 권리를 인수한 <b>영화</b>. 음악을 매개로 이뤄지는 가족의 화합이 전하는 감동이 있다.', 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': '[포토]안재홍, 남친룩의 정석', 'originallink': 'http://www.joynews24.com/view/1639515', 'link': 'http://www.joynews24.com/view/1639515', 'description': "배우 안재홍이 6일 오후 부산광역시 해운대구 <b>영화</b>의전당에서 진행된 제28회 부산국제<b>영화</b>제 'LTNS' 오픈토크에 참석하고 있다. 배우 안재홍이 6일 오후 부산광역시 해운대구 <b>영화</b>의전당에서 진행된 제28회... ", 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': '걸스데이 소진, 오는 11월 유부녀 된다 ··· 예비신랑은 배우 이동하', 'originallink': 'https://www.ftimes.kr/news/articleView.html?idxno=23245', 'link': 'https://www.ftimes.kr/news/articleView.html?idxno=23245', 'description': "두 사람은 2021년 <b>영화</b> '괴기맨숀'에서 호흡을 맞춘바 있으며 오랜 만남으로 두터운 신뢰를 쌓았다고 전해왔다. 오는 11월 서울 모처에서 양가 가족과 지인을 초대해 비공개로 예식을 진행할 예정이다. 박소진은 2010년 그룹... ", 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': "&quot;고수위 'LTNS', 이솜·안재홍이 불태웠다&quot; [28th BIFF 종합]", 'originallink': 'http://www.stoo.com/article.php?aid=89457096578', 'link': 'http://www.stoo.com/article.php?aid=89457096578', 'description': "6일 오후 부산광역시 해운대구 <b>영화</b>의 전당 GIFFXGENESIS 야외무대에서 제28회 부산국제<b>영화</b>제(28th BUSAN Internaitonal Film Festival, 이하 28th BIFF) 온 스크린 섹션에 공식 초청된 티빙 오리지널 시리즈 'LTNS(Long Time No Sex)'(극본... ", 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': "[TD포토] 이솜 '예쁘다 예뻐~'", 'originallink': 'http://www.tvdaily.co.kr/read.php3?aid=16965741991688463017', 'link': 'http://www.tvdaily.co.kr/read.php3?aid=16965741991688463017', 'description': '해운대구 <b>영화</b>의전당 야외무대에서 열렸다. 이날 전고운 감독, 임대형 감독, 이솜, 안재홍이 참석해 자리를 빛냈다. 대한민국 대표 배우 송강호가 올해 호스트로 포문을 여는 이번 부산국제<b>영화</b>제에서는 69개국... ', 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': '[사진] 이솜과 안재홍, 부부의 감정 연기는 질문의 연속이었다.', 'originallink': 'http://www.osen.co.kr/article/G1112198281', 'link': 'https://n.news.naver.com/mnews/article/109/0004942012?sid=106', 'description': '6일 부산 해운대구 센텀시티 <b>영화</b>의 전당 BIFF X GENESIS 야외무대에서 제28회 부산국제<b>영화</b>제 <b>영화</b> ‘LTNS’ 오픈토크가 열렸다. 이솜과 안재홍이 얘기도중 마주보며 활짝 웃고 있다. 2023.10.06', 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================
# {'title': '걸스데이 막내 혜리, 소진 결혼 소식에 “막냉이는 벌써 웁니다” 격한 반응', 'originallink': 'https://www.ekn.kr/web/view.php?key=20231006010001248', 'link': 'https://www.ekn.kr/web/view.php?key=20231006010001248', 'description': '최근 소진과 혜리는 함께 여행을 다녀온 사진을 SNS에 올렸고, 유라는 민아가 주연을 맡은 <b>영화</b> ‘화사한 그녀’ VIP 시사회에 참석했다. 한편, 배우 박소진은 오는 11월 3살 연상의 배우 이동하와 비공개 결혼식을 올린다.... ', 'pubDate': 'Fri, 06 Oct 2023 15:40:00 +0900'}
# ========================================================================================================================

# %% [markdown]
# 도서 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/book.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 영화
# {'title': '관객의 마음을 사로잡는 영상 연출법 101 (관객의 마음을 사로잡는)', 'link': 'https://search.shopping.naver.com/book/catalog/42292596624', 'image': 'https://shopping-phinf.pstatic.net/main_4229259/42292596624.20231004072324.jpg', 'author': '스킴온웨스트(김성영)', 'discount': '15300', 'publisher': '동녘', 'pubdate': '20230828', 'isbn': '9788972971061', 'description': '“영상 연출법에도 수학처럼 정답이 있다면 이 책이 그 답이다!” \n-김시선(160만 구독 영화 유튜버) 강력 추천 도서\n\n현직 픽사 수석 아티스트가 알려주는 영상 연출 노하우!\n매력적인 비주얼 스토리텔링을 위한 필독서\n\n영화, 애니메이션, 방송, 컴퓨터그래픽(CG)을 비롯해 모바일 기기 중심의 동영상 서비스 플랫폼 틱톡, 유튜브, 1인 방송·비주얼 광고 등 시각적으로 구현되는 영상 제작에 관한 수요와 공급이 증가함에 따라, 영상을 제작하고 유통하는 일을 취미로 삼는 사람들이 늘고 있다. 또한 이에 비례해 전 세계적으로 동영상 콘텐츠의 수요는 폭발적으로 많아지고 있다. 이처럼 영상 제작에서 아마추어와 프로 사이의 경계가 사라진 지금, 좋은 영상 콘텐츠를 만들고 또 영상을 올바르게 이해하기 위해서는 영상 연출법에 관한 지식이 중요해졌다. 또한 여기서 더 나아가 영상 연출법을 넘어서 영상 콘텐츠로 관객들과 소통할 수 있는 스토리텔링의 기술의 중요성 역시 점점 더 중요해지고 있다. \n\n이 책은 세계 최고 애니메이션 스튜디오로 평가받는 디즈니 픽사 스튜디오에서 [소울], [루카], [코코], [토이스토리 4], [도리를 찾아서] 등 10여 편의 장편 애니메이션에 제작에 레이아웃 아티스트(영화로 치면 촬영감독에 해당)로 참여해온 저자가 영화, 방송, 애니메이션, 동영상 크리에이터들에게 관객의 마음을 사로잡는 영상 연출법을 소개한 영상 문법 지침서다. 영상 언어를 구성하고 운용하는 데 따르는 규칙이 영상 문법인데, 영상 문법은 영상을 연출하고 편집하기 위해 알아야 할 기본적인 지식이며, 효과적인 영상을 제작하기 위해서는 이러한 지식을 습득할 필요가 있다. 이 책은 애니메이션을 포함한 영화를 중심으로 영상, 일러스트레이션, 시각 디자인 등 다양한 분야에서 시각적 언어를 효과적으로 다룰 수 있도록 돕는 유용하고 실용적인 팁을 준다. 또한 영화 및 영상 연출자부터 그래픽 디자이너까지, 자신의 아이디어를 시각적으로 구현하는 데 어려움을 겪는 모든 창작자를 위한 핵심 기술 101가지를 담았다.'}
# ========================================================================================================================
# {'title': 'SAVE THE CAT!: 흥행하는 영화 시나리오의 8가지 법칙 (흥행하는 영화 시나리오의 8가지 법칙)', 'link': 'https://search.shopping.naver.com/book/catalog/32491451008', 'image': 'https://shopping-phinf.pstatic.net/main_3249145/32491451008.20230418163925.jpg', 'author': '블레이크 스나이더', 'discount': '13500', 'publisher': '비즈앤비즈', 'pubdate': '20140226', 'isbn': '9788997716395', 'description': '『SAVE THE CAT 흥행하는 영화 시나리오의 8가지 법칙』은 예술성과 상업성을 모두 만족시킬 수 있는 흥행하는 시나리오 쓰는 법을 소개한다. 20년 경력의 작가인 블레이크 스나이더는 경쾌한 문체로 이 방법들을 효율적이고 재치 있게 써놓았다. 성공하는 로그라인 4요소, 시나리오 불변의 8가지 법칙 등 시나리오 작가나 시나리오에 관심이 많이 이들에게 유용한 정보를 제공할 것이다.'}
# ========================================================================================================================
# {'title': '악귀 세트 (김은희 대본집)', 'link': 'https://search.shopping.naver.com/book/catalog/41478893619', 'image': 'https://shopping-phinf.pstatic.net/main_4147889/41478893619.20230729071153.jpg', 'author': '김은희', 'discount': '44460', 'publisher': '세계사', 'pubdate': '20230901', 'isbn': '9788933872277', 'description': '★ ‘김은희가 곧 장르’ 한국형 오컬트 미스터리 열풍 일으킨 〈악귀〉 대본집 출간\n★ 전 채널, 전체 미니시리즈 시청률 1위, TV-OTT 드라마 화제성 1위 등극!\n★ 2049 시청률 5주 연속 전 채널 전체 드라마 중 1위, 키노라이츠 5주 연속 OTT 통합 1위\n★ 숨은 ‘악귀’도 다시 보자! N차 리플레이 열풍!\n\nSBS에서 2023년 여름 방영한 금토드라마 〈악귀〉는 김은희 작가가 선보이는 한국형 오컬트 미스터리로, 악귀에 씐 여자와 그 악귀를 볼 수 있는 남자가 다섯 가지 신체(神體)를 둘러싼 의문의 죽음을 파헤치는 내용을 담았다. 우리의 민속학을 핵심 소재로 접목하는 새로운 시도와 이 시대를 살아가는 청춘들의 서사가 절묘하게 녹아들어 있다. \n‘악귀’는 사람의 끝없는 욕망을 은유하는 존재로, 미지의 영을 다루는 것에 그치지 않고 황금만능주의와 사람의 이야기를 담고 있어 장르물의 재미 속에서도 사회에 대한 깊이 있는 통찰과 메시지를 놓치지 않는다. \n 장르물의 대가 김은희 작가, 섬세한 연출력의 이정림 감독, 몰입감 높은 연기와 자기만의 색깔을 유연하게 담아내는 김태리, 오정세, 홍경 배우의 만남으로 〈악귀〉는 시작부터 “웰메이드 드라마”라는 찬사를 받았다. 그 결과 “비주류 드라마인 오컬트라는 장르를 주류로 끌어올렸다”는 시청자들의 극찬 속에 전체 드라마 화제성 1위, 시청률 1위라는 두 가지 타이틀을 동시에 거머쥐는 기염을 토했다. 한편 김은희 작가는 제작사 스튜디오S와 〈악귀〉 대본집 선인세 전액을 초록우산어린이재단에 기부해 선한 영향력을 전했다.'}
# ========================================================================================================================
# {'title': "스즈메의 문단속 (영화 '젰스즈메의 문단속'hasSmryReview><isHotDeal>0<힁I 원작)", 'link': 'https://search.shopping.naver.com/book/catalog/37128011625', 'image': 'https://shopping-phinf.pstatic.net/main_3712801/37128011625.20230926085041.jpg', 'author': '신카이 마코토', 'discount': '11000', 'publisher': '대원씨아이', 'pubdate': '20230113', 'isbn': '9791169791977', 'description': '《너의 이름은。》《날씨의 아이》\n신카이 마코토 감독의 신작 원작소설\n\n규슈의 조용한 마을에서 이모와 함께 살아가는 17살 소녀 스즈메. 어느 날 등굣길에 아름다운 청년과 스쳐간 스즈메는 “문을 찾고 있다”는 그의 뒤를 쫓아 산속 폐허에 들어선다. 그곳에서 스즈메가 발견한 것은 붕괴에서 빗겨난 듯 덩그러니 남겨진 낡고 하얀 문. 무언가에 이끌리듯 스즈메는 문을 향해 손을 뻗는데…. \n\n과거와 현재와 미래를 잇는 스즈메의 ‘문단속’ 이야기가 시작된다. 2023년 3월 8일 개봉 예정인 극장판 애니메이션 《스즈메의 문단속》의 원작소설이다. 신카이 마코토 감독이 직접 집필하여 영화에서 소개되지 않은 캐릭터의 감정과 더 정밀한 세계관의 묘사를 담았다.  『너의 이름은。』 이후의 작품을 관람하고 읽은 팬이라면 어느 정도 짐작하고 있었을 신카이 마코토 감독의 마음이 활자로 온전히 적혀 있는 셈. 길지 않은 작가 후기이지만 신카이 마코토 감독의 팬이라면 그의 창작이 어디서 비롯되고 있는지 확인하는 계기가 될 것이다. 또한 앞으로 신카이 마코토 감독이 어떤 작품을 선보일지 기대하게 될 것이다.'}
# ========================================================================================================================
# {'title': '오펜하이머 각본집 (세상을 영원히 바꾸다)', 'link': 'https://search.shopping.naver.com/book/catalog/42078247618', 'image': 'https://shopping-phinf.pstatic.net/main_4207824/42078247618.20231004072340.jpg', 'author': 'Christopher Nolan', 'discount': '15120', 'publisher': '허블', 'pubdate': '20230829', 'isbn': '9791193078082', 'description': '"금세기 최고이자 가장 중요한 영화“\n 역사와 인물 모두를 놓치지 않고 충실히 그려냄으로써\n너무나도 복잡한 한 인간의 이야기를 뛰어난 시각 예술로 재탄생시킨 역작\n\n2023년 7월 최초 개봉 이후, 저명한 영화 평론가이기도 한 영화감독 폴 슈레이더가 남긴 평을 비롯해 크리스토퍼 놀란 감독의 열두 번째 장편 영화 〈오펜하이머〉에 대한 평단과 일반 관객의 찬사가 끊임없이 쏟아졌다. 상업적으로도 북미에서 개봉 3주차 흥행 수익 5억 달러를 돌파하는 등 흥행가도를 달리고 있다. 〈오펜하이머〉는 『아메리칸 프로메테우스』를 원작으로 하는 줄리어스 로버트 오펜하이머의 전기영화이다. 젊은 시절의 불안했던 정신 상태와 사생활, 맨해튼 계획의 총괄과 핵폭탄 실험 성공의 영광, 대량살상무기를 만들어버린 과학자로서의 양심과 죄책감, 매카시즘의 피해자로서 얼룩진 노년…. 크리스토퍼 놀란이 재해석한 이 복잡한 삶이 영화 상영 시간 내내 농밀하게 펼쳐진다.\n\n저자는 《토탈 필름》 2023년 신년호에서, 영화를 흑백 장면과 컬러 장면으로 나누어 구성했다고 밝혔다. 흑백 장면은 3인칭의 객관적 역사를 따르며, 컬러 장면은 로버트 오펜하이머의 시점에서 재구성한 주관적 경험을 선보인다. 컬러 장면의 내레이션 또한 로버트 오펜하이머 역의 주연배우 킬리언 머피가 맡았다. 이러한 철저한 구분 또한 물론 각본집에 알기 쉽게 반영되어, 각 장면을 구분해 읽는 것을 통해 저자의 집필 의도를 효과적으로 추적할 수 있다. 대량살상무기의 발명과 과학의 책임을 둘러싼 무거운 역사적 스토리텔링에 더해, 오펜하이머의 인간적인 면모를 보여주는 소소한 에피소드나 유머 섞인 장면이 전체적인 플롯을 해치지 않는 선에서 적절히 가미되어 읽는 재미를 더한다.\n\n『아메리칸 프로메테우스』의 저자 카이 버드가 각본을 읽고 남긴 말처럼 크리스토퍼 놀란 감독은 이 과정을 통해, ‘역사’와 ‘인물’ 모두를 놓치지 않고 충실히 그려냄으로써 줄리어스 로버트 오펜하이머라고 하는 복잡하고 다면적인 인물의 이야기를 하나의 예술로 승화시켰다.'}
# ========================================================================================================================
# {'title': '스토리 : 흥행하는 글쓰기 (21세기 한국 영화들로 파헤친 시나리오 작법)', 'link': 'https://search.shopping.naver.com/book/catalog/32481953447', 'image': 'https://shopping-phinf.pstatic.net/main_3248195/32481953447.20221227203941.jpg', 'author': '오기환', 'discount': '9900', 'publisher': '시공아트', 'pubdate': '20201029', 'isbn': '9791165792268', 'description': '이준익, 민규동, 허진호, 윤제균, 장항준 등 \n현직 영화감독과 시나리오 작가들의 감탄\n“쉽고 재미있고 날카롭고 유용하다!”\n\n기존의 작법서들을 무력화시키는 매력을 가진 책!\n- 21세기 한국 영화들로 가득 채워진 시나리오 분석\n- 현직 영화감독, 시나리오 작가들이 추천하는 필독서\n- ‘오의 공식’을 통해 파헤치는 시나리오 구조의 비밀\n- 시나리오와 글쓰기에 대한 가장 현명하고 친절한 답\n\n작가도 작법서를 읽을까? 물론이다. 스티븐 킹, 제임스 미치너 같은 유명 작가들도 글쓰기에 관한 책을 발표했고, 무라카미 하루키는 여러 에세이에서 자신의 글쓰기 습관을 상세하게 밝힌 바 있다. 또한 대통령 비서관, 기자, 출판사와 잡지사 에디터, 그리고 다양한 직종에서 글을 업으로 삼는 이들이 글쓰기에 관한 책을 내놓았다. 물론 『스토리: 흥행하는 글쓰기』가 논하는 글쓰기란 소설이나 에세이가 아니라 영상 산업, 즉 영화와 드라마 작법이다. 그러나 저자는 작법 기술만이 아니라 글을 대하는 자세와 마음가짐까지 챙긴다는 점에서도 유의미하다.\n       『스토리: 흥행하는 글쓰기』는 영화감독이자 시나리오 작가인 저자의 오랜 경험과 애정의 결과물이다. 왜 시나리오 작법서는 지루해야 하는가, 어째서 대한민국 작가들이 할리우드 영화를 다룬 작법서로 공부해야 하는가, 언제까지 1941년에 만들어진 〈시민 케인〉을 분석해야 하는가, 그리고 ‘이제부터 혼자 써 보라!’가 아니라 ‘같이 써 보자!’라고 손 내밀어 주는 책은 없는가에 대한 답이다. 영화감독 민규동은 글길 막힘이라는 미로에 갇힌 우리 테세우스(작가)에게 꼭 필요한 아리아드네의 실타래 같은 책이라 평했다. 저자는 자신이 개발한 ‘오(기환)의 공식’을 통해 세상의 모든 영화를 간결하게 분석해 내면서도 영화의 메시지와 작가의 주제 의식을 놓치지 않는다. ‘이 책을 읽고 나면 시나리오를 잘 쓸 수 있을까’라는 독자의 물음은 책을 덮은 후에 말끔하게 해소된다.'}
# ========================================================================================================================
# {'title': '나의 해방일지 세트 (박해영 대본집)', 'link': 'https://search.shopping.naver.com/book/catalog/37233439627', 'image': 'https://shopping-phinf.pstatic.net/main_3723343/37233439627.20230919123228.jpg', 'author': '박해영', 'discount': '57600', 'publisher': '오브제', 'pubdate': '20230130', 'isbn': '9791130696065', 'description': '“날 추앙해요. \n사랑으론 안 돼. 추앙해요.”\n\n한국방송작가상 드라마 부문 수상작\n「나의 해방일지」 오리지널 대본집 출간\n\n「나의 아저씨」 박해영 작가가 쓴 또 하나의 인생드라마. ‘구씨앓이’ ‘추앙’ 신드롬을 일으키며 방영 당시 4주 연속 드라마 화제성 1위에 오른 드라마 「나의 해방일지」가 박해영 작가의 오리지널 대본으로 출간되었다. 2022년 5월에 막을 내린 JTBC 드라마 「나의 해방일지」는 경기도 끝자락에 사는 삼 남매를 중심으로 외지인 구씨와 주변 사람들이 각자의 행복을 찾기 위해 해방을 꿈꾸는 이야기를 현실감 있게 그려 한국방송작가상을 받았다. 다시 보고 싶은 장면과 다시 듣고 싶은 대사, 작가와 배우의 생생한 목소리가 들리는 인터뷰 등 『나의 해방일지 대본집』에 모두 담았다.\n\n경기도 산포와 서울을 오가는 왕복 세 시간, 염 씨네 삼 남매의 고된 출퇴근길에는 이리저리 치이는 사회생활, 쓸데없는 말로 포장하는 인간관계, 도태되지 않으려고 끊임없이 무언가를 하고 있는 흔한 현대인의 피로가 투영되어 있다. 평범에서도 조금 뒤처진 인물들이 물리적으로도 중심(서울)이 아닌 주변 도시(경기도)에 놓임으로써 아웃사이더 감성이 짙게 묻어난다. 답답함이 폭발하듯 무기력의 끝에 선 주인공들은 선언한다. 올겨울엔 아무나 사랑하겠다고(기정), 회사를 때려치우겠다고(창희), 해방할 거라고(미정), 추앙하겠다고(구씨). 드라마는 행복하지도 그렇다고 크게 불행하지도 않은 지루한 일상을 반복하는 우리 모두에게 ‘해방’을 권한다.'}
# ========================================================================================================================
# {'title': '기획하는 일, 만드는 일 (우리가 사랑한 콘텐츠들, PD와 작가에게 묻다)', 'link': 'https://search.shopping.naver.com/book/catalog/40949568618', 'image': 'https://shopping-phinf.pstatic.net/main_4094956/40949568618.20230919125806.jpg', 'author': '장수연', 'discount': '16420', 'publisher': '터틀넥프레스', 'pubdate': '20230720', 'isbn': '9791198340900', 'description': '〈스트릿 우먼 파이터〉, 〈공부왕찐천재 홍진경〉, 〈D.P.〉…\n트렌드를 이끌고 대중의 마음을 사로잡은 그 콘텐츠들, \n기획하고 제작하고 감독한 사람은 누굴까?\n\n잘 만든 작품, 잘된 콘텐츠를 보면 궁금해진다. 누가, 어떻게 기획하고 만든 걸까? 어디에서 아이디어를 얻었을까? 이 책은 최근 2년간 트렌드를 이끌고, 새로운 관점을 제시하고, 사람들의 마음을 사로잡은 영상콘텐츠를 만든 PD와 작가 10팀을 인터뷰했다. 유튜브 채널, 예능, 드라마까지 그 콘텐츠를 어떻게 기획하고 어떤 과정을 거쳐 만들었는지 창작 비하인드를 만든 이들이 직접 공개한다. 영웅담도, 성공담도 아닌 직업인들의 진짜 이야기를 들려주는 책.'}
# ========================================================================================================================
# {'title': '인간의 마음을 사로잡는 스무 가지 플롯', 'link': 'https://search.shopping.naver.com/book/catalog/32455963935', 'image': 'https://shopping-phinf.pstatic.net/main_3245596/32455963935.20230919130125.jpg', 'author': '로널드 B. 토비아스', 'discount': '13830', 'publisher': '풀빛', 'pubdate': '20120525', 'isbn': '9788974744052', 'description': '명작을 위한 스무 가지 플롯의 패턴!\n\n『인간의 마음을 사로잡는 스무 가지 플롯』은 명작을 위한 스무 가지 유형의 플롯을 제시한 책이다. 소설, 희곡, 시나리오, 텔레비전 드라마나 이벤트 또는 스토리 등을 짜는 데 구체적이면서도 당장 활용할 수 있는 풍부한 지침들을 제공한다. 저자는 플롯에 대한 세심한 충고들을 신화와 동화, 소설, 시나리오와 희곡의 유형으로부터 추출하고 구체적인 장면들을 곁들여 설명하고 있다. 제1부에서는 플롯에 대한 이론들을 정리하고, 제2부에서는 가장 성공적인 플롯의 패턴을 스무 가지로 나누어 소개하며 작가지망생들이 각각의 플롯에 맞는 감각을 제대로 익힐 수 있도록 도와준다. 이번 개정판에서는 번역을 다시 검토하여 어색한 문장을 다듬고, 이해를 돕기 위해 역자의 각주를 새로 덧붙였다.'}
# ========================================================================================================================
# {'title': '안소연의 성우되는 법 (KBS 성우가 쓴 국내 최초의 성우 입문서)', 'link': 'https://search.shopping.naver.com/book/catalog/36694037636', 'image': 'https://shopping-phinf.pstatic.net/main_3669403/36694037636.20230920072527.jpg', 'author': '안소연', 'discount': '14400', 'publisher': '시대인', 'pubdate': '20230515', 'isbn': '9791138340632', 'description': '친환경 99.9% 항균잉크(V-CLEAN99)로 인쇄한 안심도서!\n\n‘성우가 되려면 어떻게 해야 합니까?’라는 질문에 대답을 해 줄 유일한 성우 입문서!\n·성우가 되기 위한 준비 과정 소개 \n·실전 연습과 대본 분석 요령 제공 \n·주요 방송사별 성우 시험 기출문제 수록'}
# ========================================================================================================================

# %% [markdown]
# 성인 검색어 판별
# 성인 검색어 판별 결과: '0' - 일반 검색어, '1' - 성인 검색어

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/adult.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
# print(searchResult.keys())
adult = searchResult['adult']
print('{}(은)는 {} 검색어 입니다.'.format(searchText, '일반' if adult == '0' else '성인' ))
# Out:
# 검색어 입력: 성인검색
# 성인검색(은)는 성인 검색어 입니다.

# %% [markdown]
# 백과사전 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/encyc.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 영화
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=567818&cid=46665&categoryId=46665', 'description': ' 촬영으로 필름에 기록한 화상을 스크린에 투영, 영상과 음향을 통해 보여주는 영상물. [요약문] <b>영화</b>는 촬영으로 필름에 기록한 화상을 스크린에 투영, 영상과 음향을 통해 보여주는 영상물이다. 제작과정에... ', 'thumbnail': 'http://openapi-dbscthumb.phinf.naver.net/2644_000_2/20190718020630869_T0LTEG4T0.jpg/9a82132a-965f-41.jpg?type=m160_160'}
# ========================================================================================================================
# {'title': '<b>영화</b>란 무엇인가', 'link': 'https://terms.naver.com/entry.naver?docId=2275294&cid=42219&categoryId=51141', 'description': '[<b>영화</b>의 이해] <b>영화</b>는 우리가 살고 있는 세상에서 가장 영향력이 큰 대중매체라고 할 수 있다. 전 세계에서 하루에도 수백만 명이 <b>영화</b>를 보고 있다. <b>영화</b> 관람 방식도 <b>영화</b>관만 이용하는 시대는 지났다.... ', 'thumbnail': ''}
# ========================================================================================================================
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=2377647&cid=50762&categoryId=51366', 'description': "'<b>영화</b>'(榮化)란, 구속(救贖)의 현실적 적용에 있어서 최종 단계를 말한다. 그것은 유효적인 소명을 가지고 시작된 구원 과정을 완성하는 것으로, 구원의 전 과정의 완성 곧 영광스러운 변화를 의미한다(롬8... ", 'thumbnail': ''}
# ========================================================================================================================
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=3551484&cid=55589&categoryId=55589', 'description': ' 19세기 후반에는 사진을 연속적으로 찍은 방법이 탐구되면서 <b>영화</b>의 탄생을 예고했다. 1891년에 에디슨과 딕슨은 ‘키네토스코프’를 발명했으며, 1894년에는 에디슨 제작사가 <b>영화</b> 사업을 시작했다.... ', 'thumbnail': 'http://openapi-dbscthumb.phinf.naver.net/3864_000_1/20170116165811922_2G8TM3L4Z.jpg/da8_52_i1.jpg?type=m160_160'}
# ========================================================================================================================
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=1714427&cid=43938&categoryId=43953', 'description': '<b>영화</b>는 미국에서 태어나지는 않았지만 미국이 세계 연예계에 가장 큰 기여를 했던 분야다. 1900년대 초, <b>영화</b> 매체가 아직 생소했을 무렵 많은 이민자들이 미국 <b>영화</b> 산업에서 일자리를 구했다. 그리고... ', 'thumbnail': 'http://openapi-dbscthumb.phinf.naver.net/2281_000_1/20120611144449638_BZ9ZWTRBN.jpg/bf1_127_i1.jpg?type=m160_160'}
# ========================================================================================================================
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=349806&cid=42617&categoryId=42617', 'description': '세기 초 우리나라와 일본에서는 <b>영화</b>를 활동사진(活動寫眞)이라 불렀는데 이는 무빙 픽처(moving picture)를 직역한 것으로 ‘움직이는 사진’이란 뜻이다. 1895년 프랑스의 루이 뤼미에르(Lumière)... ', 'thumbnail': 'http://openapi-dbscthumb.phinf.naver.net/2531_000_1/20130808152215357_PMM7MZWMK.jpg/01064_i1.jpg?type=m160_160'}
# ========================================================================================================================
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=3548277&cid=58555&categoryId=58556', 'description': '<b>영화</b>를 사랑하는 사람이라면 오늘은 색다른 <b>영화</b>관으로 향해 보자. 인천의 자랑거리인 아래 세 개의 <b>영화</b>관에서는 당신을 위한 다양하고 좋은 <b>영화</b>들이 준비되어 있다. [추천코스] <b>영화</b>공간 주안... ', 'thumbnail': 'http://openapi-dbscthumb.phinf.naver.net/4727_000_1/20161121183640327_XR0AJ5ZMF.jpg/fb55_25_i1.jpg?type=m160_160'}
# ========================================================================================================================
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=1127498&cid=40942&categoryId=33091', 'description': " 연속촬영으로 기록한 필름상의 화상을 스크린에 투영, 움직임 있는 영상과 소리를 통해서 보여주는 영상물.  한국에 <b>영화</b>가 도입된 초기에는 영어의 'motion picture'를 직역하여 '활동사진(活動寫眞)'이라고... ", 'thumbnail': 'http://openapi-dbscthumb.phinf.naver.net/2765_000_34/20180930194426814_O18IBHXYX.jpg/28509.jpg?type=m160_160'}
# ========================================================================================================================
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=567817&cid=46620&categoryId=46620', 'description': " 중국 동진시대 중국왕조의 연호. [요약] <b>영화</b>(永和)는 중국 동진시대 중국왕조의 연호이다. 동진(東晉)시대의 '<b>영화</b>' 연호(年號)는 한반도에서 발견된 몇몇 무덤과도 밀접한 관련이 있다. 구체적으로... ", 'thumbnail': ''}
# ========================================================================================================================
# {'title': '<b>영화</b>', 'link': 'https://terms.naver.com/entry.naver?docId=6042390&cid=67006&categoryId=67310&anchorTarget=TABLE_OF_CONTENT1#TABLE_OF_CONTENT1', 'description': '[고야의 유령(Goya’s Ghosts), 2006] 2008년 개봉한 밀로스 포먼 감독의 <b>영화</b>로 천재화가 프란시스코 고야와 그의 아름다운 뮤즈였던 이네스의 이야기를 담고 있다.죄 없는 이들을 이단으로 몰아 고문... ', 'thumbnail': ''}
# ========================================================================================================================

# %% [markdown]
# 영화 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/movie.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
print(response.text)
searchResult = response.json()
print(searchResult.keys())
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 영웅본색
# {
# 	"errorMessage":"Invalid search api (존재하지 않는 검색 api 입니다.)",
# 	"errorCode":"SE05"
# }
# dict_keys(['errorMessage', 'errorCode'])
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12376\3206659488.py in <module>
#       5 searchResult = response.json()
#       6 print(searchResult.keys())
# ----> 7 items = searchResult['items']
#       8 for item in items:
#       9     print('{}'.format(item), end='\n' + '=' * 120 + '\n')
#
# KeyError: 'items'

# %% [markdown]
# 카페글 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/cafearticle.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 나트랑
# {'title': '<b>나트랑</b> 롯데마트 과일 구경하기', 'link': 'http://cafe.naver.com/mindy7857/2689325', 'description': '#<b>나트랑</b>롯데마트 물가대비? 다른 과일값대비 비쌌던 사과 5개.. 더얼~익어서 오는날까지 호텔에 두고 왔어도... 저어기 <b>나트랑</b> 롯데마트로 가고싶다고 우리동네 롯데마트말고 <b>나트랑</b> 롯데마트... ', 'cafename': '베나자-베트남나트랑자유여행,베트남,...', 'cafeurl': 'https://cafe.naver.com/mindy7857'}
# ========================================================================================================================
# {'title': '<b>나트랑</b>여행 갔다와서 후회한 것', 'link': 'http://cafe.naver.com/mindy7857/2681892', 'description': '<b>나트랑</b> 여행 5박7일... 일주일 간 갔다왔어요~ 가기전부터 멘붕~ 많은 일들이 있었지만... 처음부터 시어른들과... 비엣젯 항공은 <b>나트랑</b> 출발 전 2시간 연착! 모든 일정은 딜레이 되고~ 정말 쉽지 않는 여행이였습니다! 그... ', 'cafename': '베나자-베트남나트랑자유여행,베트남,...', 'cafeurl': 'https://cafe.naver.com/mindy7857'}
# ========================================================================================================================
# {'title': '[GoodBye <b>나트랑</b>]4방때도 즐겁게.', 'link': 'http://cafe.naver.com/zzop/1839985', 'description': '시간이 참 빠르네요 어느덧 <b>나트랑</b> 작별의 시간이 일단 A구역 끝자락 에서 샌딩. 반가운 도깨비 차 보여서 한컷 !! 누군가 내리는데 모르시는분 저차 타고 다시 <b>나트랑</b> 시내로 가고 싶었어요. 출국심사... ', 'cafename': '나트랑 도깨비 - 베트남 나트랑 자유여...', 'cafeurl': 'https://cafe.naver.com/zzop'}
# ========================================================================================================================
# {'title': '베트남 <b>나트랑</b>,달랏 6박8일 일정 마치고 오늘밤 비행기 탑니다ㅠㅠ', 'link': 'http://cafe.naver.com/newhd/663176', 'description': '두번째 방문하는 <b>나트랑</b>! 꿈만 같았던 6박8일 시간이 지나고 일상으로 돌아갑니다ㅠㅠ <b>나트랑</b> 야경입니다 호텔 입구 오도방구 사람들로 시끌시끌 활기 넘쳐요 그 유명한 야시장 앞 인기에 비해서 볼거없어요 40층 수영장 뷰... ', 'cafename': '화도사랑', 'cafeurl': 'https://cafe.naver.com/newhd'}
# ========================================================================================================================
# {'title': '다 가보셨죠? <b>나트랑</b>', 'link': 'http://cafe.naver.com/minecraftpe/3120818', 'description': '다들 다낭 <b>나트랑</b>을거쳐 푸꾸옥으로 오시더라구요 저도 8년전 <b>나트랑</b> 처음 가보고 그후로 두번 더가고 이번달 푸꾸옥 가고 1윌 방학때 애들 데리고 사방하려고 <b>나트랑</b> 뱅기표를 계속 새로고침 하고 있어요 세번다... ', 'cafename': '푸꾸옥 고스트 - 베트남푸꾸옥 자유여...', 'cafeurl': 'https://cafe.naver.com/minecraftpe'}
# ========================================================================================================================
# {'title': '다낭vs<b>나트랑</b> 추천은 어디?', 'link': 'http://cafe.naver.com/happyibook/4190951', 'description': '워디가 더좋아요? <b>나트랑</b>은 심심한가요? 뱅기 수속하는데 패키지 어머님왈 <b>나트랑</b>이 낫다 하시네요 담엔 <b>나트랑</b>가까요?', 'cafename': '다낭 도깨비 - 베트남 다낭자유여행 ,...', 'cafeurl': 'https://cafe.naver.com/happyibook'}
# ========================================================================================================================
# {'title': '나 <b>나트랑</b> 좋아하네...(2탄)', 'link': 'http://cafe.naver.com/casuallydressed/626339', 'description': '안녕하세요•ܫ• <b>나트랑</b> 2탄으로 돌아왔습니다. 3일차는 무이네 선라이즈 지프투어 화이트샌듄 <b>나트랑</b>에서 무이네까지 4시간 정도 걸리는데요 밤 11시반쯤 시내에서 출발해서 다음날 새벽4시 넘어 도착했어요 버스에서... ', 'cafename': 'GO OUT CASUALLY DRESSED 캐주얼 패션...', 'cafeurl': 'https://cafe.naver.com/casuallydressed'}
# ========================================================================================================================
# {'title': '<b>나트랑</b> 샤워필터 이런거였나요? 당황 ㅠㅠ', 'link': 'http://cafe.naver.com/culturebloom/2040601', 'description': '제가 아토피가 조금 있는 편이라 지난 방콕 여행때 샤워기 필터를 사가서 썼었어요~ 그런데 3박4일 여행이라 그런건지 필터 변화가 하나도 없더라고요 이번엔 <b>나트랑</b>으로 여행을 가는데 <b>나트랑</b> 샤워필터 꼭 필요할까요?? 제... ', 'cafename': '컬처블룸★체험,리뷰,라이프,건강,맛집...', 'cafeurl': 'https://cafe.naver.com/culturebloom'}
# ========================================================================================================================
# {'title': '<b>나트랑</b> 다녀왔어요^^', 'link': 'http://cafe.naver.com/jookjeonmom/1392291', 'description': '명절앞두고 다녀왔더니 올 추석은 시댁,친정 다 패쓰할수있어서 넘넘 해피하게 보냈어요 <b>나트랑</b>은 지금... 많아서 하루동안 다 못놀아서 아쉬웠어요.. 물가도 저렴하고, 호텔도 깨끗하고 넓고~ 행복한 <b>나트랑</b> 여행이였습니다', 'cafename': '죽전 보정 마북 구성 동백 엄마들의 카...', 'cafeurl': 'https://cafe.naver.com/jookjeonmom'}
# ========================================================================================================================
# {'title': '<b>나트랑</b> 온가족 여행~', 'link': 'http://cafe.naver.com/momsofsongdoifez/1185275', 'description': '다음주에 온가족이 <b>나트랑</b>을 가게되었습니다~ㅎ 성인 5명 + 청소년 2명 + 유아(만1세) 1명 총 8명을 제가... ㅎㅎ 미리 감사 드립니다 ## 아 그리고 <b>나트랑</b> 여행시 준비 팁이나 가볼만한곳 있으면 추천을 부탁드려볼게요', 'cafename': '☆송도국제도시맘(송도맘)☆', 'cafeurl': 'https://cafe.naver.com/momsofsongdoifez'}
# ========================================================================================================================

# %% [markdown]
# 지식in 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/kin.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 공부 잘하는 방법
# {'title': '재수생입니다 <b>공부잘하는방법</b> 알려주세요 (양재역... ', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=7&dirId=70301&docId=446181343&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=1&search_sort=0&spq=0', 'description': '재수생인데요 이번에는 의과대학 붙어야 해요 <b>공부잘하는방법</b> 기억력 암기력 좋아지게 해주는 방법을 위해 뭘 하는게... <b>공부잘하는방법</b> 관련해서 질문을 주신 것 같습니다. <b>공부잘하는방법</b>으로 공진단을 드셔보는 것은 어떠신지요?... '}
# ========================================================================================================================
# {'title': '<b>공부 잘하는 방법</b>..', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=13&dirId=1301&docId=450252484&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=2&search_sort=0&spq=0', 'description': '... 다음 기말 땐 성적을 더 올리고 싶네요 멘탈 관리법이나 자존감 올리는법도 괜찮으니 <b>공부 잘하는 방법</b> 있으시면 알려주세요…!!! 답변 해주시면 제가 그 답변 듣고 더 노력하도록 하겠습니다! 답변 부탁드리고 제 얘기 들어주셔서... '}
# ========================================================================================================================
# {'title': '과학 역사 <b>공부 잘하는 방법</b>좀요', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110304&docId=429554200&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=3&search_sort=0&spq=0', 'description': '과학 역사 <b>공부 잘하는 방법</b>좀요  안녕하세요!!질문자님~~ 과학 역사 <b>공부 잘하는 방법</b>을 찾고 계시는군요!! 공부방법에는 다양한 방법들이 있다고 생각해요!! 그것이 누구의 공부방법이 아니라 본인에게 맞는 공부방법을 찾는게... '}
# ========================================================================================================================
# {'title': '<b>공부잘하는방법</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=11080106&docId=208755831&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=4&search_sort=0&spq=0', 'description': '... 좋은 공부습관, <b>공부 잘하는방법</b>, 혼자서 예습하는 법 등 부탁드립니다! -전 6학년 여학생입니다! 답변이 등록되면 질문 삭제가 불가합니다. 질문내용에 개인정보(실명, 전화번호, 카카오톡 아이디 등)를 포함하거나 요청할 경우... '}
# ========================================================================================================================
# {'title': '<b>공부 잘하는 방법</b>좀 알려주시여', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=110304&docId=442819051&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=5&search_sort=0&spq=0', 'description': '<b>공부 잘하는 방법</b>좀 알려주시어요  안녕하세요! 질문자님^^ 공부 잘하고 싶군요. 공부는 시간과의 싸움이라고 생각합니다. 나에게 주어진 시간을 어떻게 쓰느냐가 다른 성적을 만들어내요. 아래에 스터디 플래너(다이어리), 무료... '}
# ========================================================================================================================
# {'title': '고1 <b>공부 잘하는 방법</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=1104&docId=430115501&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=6&search_sort=0&spq=0', 'description': '... 어떻게 해야할지 모르겠어요 ㅠㅠ <b>공부 잘하는 방법</b>좀 알려주세요..  안녕하세요! 질문자님^^ 고1이시군요. 공부를 열심히 했는데 원했던 거보다 안좋게 나와서 속상하겠어요. 그래도 성적표에 나온 게 냉정하게 실제 성적이니까... '}
# ========================================================================================================================
# {'title': '<b>공부잘하는방법</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=20&dirId=200106&docId=207588356&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=7&search_sort=0&spq=0', 'description': '... 1.<b>공부잘하는방법</b>을 구체적으로 알려주세요 2.제가열심히만하면 성적올릴수있죠? 3.의사,판사,검사,PD가 제 꿈인데 각각 얼마나공부를잘해야되고 어떤과정을통해 꿈을이룰수있을까요 4.지금 제가 고민중인 인문계가 두곳인데 A와... '}
# ========================================================================================================================
# {'title': '<b>공부 잘하는 방법</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=11080106&docId=436835606&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=8&search_sort=0&spq=0', 'description': '<b>공부 잘하는 방법</b> 같은 건 없나요? 엄... 예를 들면 필기 잘하는 법? 같은 거요 질문자님! 안녕하세요~~ 국어공부하는 방법과 시험대비로 걱정이 많으신걸까요? 전과목 공부하는 방법은 당연히 있습니다!! 하지만 수능1등급 이라도 나에게... '}
# ========================================================================================================================
# {'title': '<b>공부 잘하는 방법</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=8&dirId=80107&docId=455085476&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=9&search_sort=0&spq=0', 'description': '<b>공부 잘하는 방법</b>  <b>공부 잘하는 방법</b>은 계획을 세우고 집중력을 유지하는 것이 중요하며, 효율적인 메모와 복습을 통해 학습 내용을 정리하고 반복하는 것이 도움이 됩니다.'}
# ========================================================================================================================
# {'title': '<b>공부 잘 하는 방법</b>', 'link': 'https://kin.naver.com/qna/detail.naver?d1id=11&dirId=111304&docId=453157849&qb=6rO167aAIOyemO2VmOuKlCDrsKnrspU=&enc=utf8&section=kin.qna&rank=10&search_sort=0&spq=0', 'description': '<b>공부 잘 하는 방법</b> 좀 알려주세요..,. 이제 중간 준비도 해야하는데 뭐 부터 시작해야할지 모르겠어여ㅓ.. 특히 수학이요..!! 공부를 잘하는 방법은 각자의 성향과 방법에 따라 다를 수 있지만, 일반적인 팁을 알려드릴게요. 1. 계획 세우기... '}
# ========================================================================================================================

# %% [markdown]
# 지역 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/local.json?display=5&query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 광교
# {'title': '<b>광교</b>신도시', 'link': '', 'category': '행정지명>신도시', 'description': '', 'telephone': '', 'address': '경기도 수원시 영통구 이의동', 'roadAddress': '', 'mapx': '1270625926', 'mapy': '372900951'}
# ========================================================================================================================
# {'title': '<b>광교</b>호수공원', 'link': 'http://www.gglakepark.or.kr/', 'category': '여행,명소>도시,테마공원', 'description': '', 'telephone': '', 'address': '경기도 수원시 영통구 하동 1026-1', 'roadAddress': '경기도 수원시 영통구 광교호수로 165', 'mapx': '1270696711', 'mapy': '372826145'}
# ========================================================================================================================
# {'title': '아쿠아플라넷 <b>광교</b>', 'link': 'https://www.aquaplanet.co.kr/gwanggyo', 'category': '관람,체험>아쿠아리움', 'description': '', 'telephone': '', 'address': '경기도 수원시 영통구 하동 1017-4 갤러리아 광교 파사쥬 지하 1층', 'roadAddress': '경기도 수원시 영통구 광교호수공원로 300 갤러리아 광교 파사쥬 지하 1층', 'mapx': '1270585155', 'mapy': '372843235'}
# ========================================================================================================================
# {'title': '스타벅스 <b>광교</b>SK뷰레이크41F점', 'link': 'http://www.starbucks.co.kr/', 'category': '카페,디저트>카페', 'description': '', 'telephone': '', 'address': '경기도 수원시 영통구 하동 1016-1 광교 SK VIEW Lake 41층', 'roadAddress': '경기도 수원시 영통구 법조로 25', 'mapx': '1270603992', 'mapy': '372870016'}
# ========================================================================================================================
# {'title': '더유로피언 <b>광교</b>본점', 'link': 'http://www.instagram.com/theeuropean_official', 'category': '음식점>양식', 'description': '', 'telephone': '', 'address': '경기도 수원시 영통구 이의동 1296-13', 'roadAddress': '경기도 수원시 영통구 센트럴파크로128번길 26', 'mapx': '1270571587', 'mapy': '372959995'}
# ========================================================================================================================

# %% [markdown]
# 오타변환
# API를 호출하면 오타를 변환한 결과를 리턴하고 오타가 없으면 빈 문자열을 반환한다.

# %%
searchText = input('문장 입력: ').split()
result = []
print(searchText)
for text in searchText:
    targetSite = 'https://openapi.naver.com/v1/search/errata.json?query=' + text
    response = requests.get(targetSite, headers=headers)
    searchResult = response.json()
    # print(searchResult.keys())
    errata = searchResult['errata']
    if len(errata) == 0:
        print(text, end=' ')
        result.append(text)
    else:
        print(errata, end=' ')
        result.append(errata)
print()
print(' '.join(result))
# Out:
# 문장 입력: 아릉다운 이땅에 긍수강산에 단군하라버지가
# ['아릉다운', '이땅에', '긍수강산에', '단군하라버지가']
# 아름다운 이땅에 금수강산에 단군할아버지가
# 아름다운 이땅에 금수강산에 단군할아버지가

# %% [markdown]
# 웹문서 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/webkr.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 단군
# {'title': '<b>단군</b> - 나무위키', 'link': 'https://namu.wiki/w/%EB%8B%A8%EA%B5%B0', 'description': '<b>단군</b>신화에서 등장하는 고조선(<b>단군</b>조선)의 초대 군주 또는 토착 고조선의 군주들이 세습했던 군주의 호칭으로 추정되는 말이다.'}
# ========================================================================================================================
# {'title': '김의중 - 나무위키', 'link': 'https://namu.wiki/w/%EA%B9%80%EC%9D%98%EC%A4%91', 'description': '대한민국의 e스포츠 캐스터, MC, 인터넷 방송인. 기본적으로 캐스터나 진행을 맡지만, 나겜 시절에는 해설이나 옵저버를 소화하기도 했다. 닉네임은 <b>단군</b> 혹은 김<b>단군</b>으로 불린다.'}
# ========================================================================================================================
# {'title': '<b>단군</b>(檀君) - 한국민족문화대백과사전', 'link': 'http://encykorea.aks.ac.kr/Article/E0013538', 'description': '<b>단군</b>() <b>단군</b>은 초기국가시대 고조선의 제1대 왕이다. 재위 기간은 BCE.2333년부터 BCE.1122년까지이며 <b>단군</b>왕검·단웅천왕이라고도 한다.'}
# ========================================================================================================================
# {'title': '<b>단군</b> - 위키백과 한국', 'link': 'https://ko.wikipedia.org/wiki/%EB%8B%A8%EA%B5%B0', 'description': '<b>단군</b> (檀君, 壇君) 또는 <b>단군</b>왕검 (檀君王儉)은 한민족의 신화적인 시조이자 고조선의 창건자로 전해지는 전설적인 인물이다. 한민족의 역사에서 시조로 추앙받았으며 대종교 등의 종교에서는 신앙의 대상이기도 하다. <b>단군</b>은 직책으로 보이며 왕검, 왕험(王儉) 등으로도 알려져 있다. 한국의 역사서 중에 하나인...'}
# ========================================================================================================================
# {'title': '<b>단군</b> 신화(檀君 神話) - 한국민족문화대백과사전', 'link': 'https://encykorea.aks.ac.kr/Article/E0013553', 'description': '<b>단군</b> 신화() 내용은 7개의 이야기토막으로 엮어져 있다. ① 환인(桓因)과 그 아들 환웅(桓雄), 그리고 환웅의 아들인 <b>단군</b>에 이르기까지의 삼대에 걸친 가계.'}
# ========================================================================================================================
# {'title': '<b>단군</b> : 티나는 쇼핑, 티몬', 'link': 'https://search.tmon.co.kr/search?keyword=%EB%8B%A8%EA%B5%B0', 'description': '스콜라스 만공한국사 고조선 - <b>단군</b>신화와 고조선 건국 · 5,500원 · 24개 구매 ; 나혼자생활 문구 모나미 한정판 본입 세트 곰 볼펜 용품 호랑이 <b>단군</b>신화 · 27,490원 ; 만들기대장 마스크걸이만들기 <b>단군</b>신화 · 5,100원 ; 만들기대장 마스크걸이만들기-<b>단군</b>신화 · 13,800원'}
# ========================================================================================================================
# {'title': 'Dangun - 위키피디아 영어', 'link': 'https://en.wikipedia.org/wiki/Dangun', 'description': 'Hangul <b>단군</b>왕검 Hanja 檀君王儉 Revised Romanization... ɡʌm] Dangun or Tangun (<b>단군</b>; 檀君; [tan.ɡun]), also known as Dangun Wanggeom (<b>단군</b>왕검; 檀君王儉; [tan.ɡun...'}
# ========================================================================================================================
# {'title': '<b>단군</b> 신화 - 위키백과 한국', 'link': 'https://ko.wikipedia.org/wiki/%EB%8B%A8%EA%B5%B0_%EC%8B%A0%ED%99%94', 'description': '<b>단군</b> 신화 (檀君神話)는 한민족 최초의 나라인 고조선의 건국 신화이다. 상고자의 《삼국유사》나 《제왕운기》 등 고려 시대에 저술된 역사서에 처음 나오며, 《조선왕조실록》, 《응제시주》 등 조선 시대 여러 문헌에도 같은 내용이 있다. <b>단군</b>신화의 내용 《삼국유사》(三國遺事) 기이(紀異) 제1편에는 《고기...'}
# ========================================================================================================================
# {'title': '<b>단군</b>', 'link': 'http://dangoon.com/', 'description': '남친룩 코디는 <b>단군</b>이 만들어 드릴께요'}
# ========================================================================================================================
# {'title': '<b>단군</b>기원 - 위키백과 한국', 'link': 'https://ko.wikipedia.org/wiki/%EB%8B%A8%EA%B5%B0%EA%B8%B0%EC%9B%90', 'description': '<b>단군</b>기원 (檀君紀元) 또는 단기 (檀紀)는 한민족의 역사가 시작되는 시점인 <b>단군</b>의 고조선 건국 연대를 기준으로 하는 상징적인 기년이다. 그레고리력을 기준으로 기원전 2333년이 단기 1년으로, 서기 2023년은 단기 4356년이 된다. (<b>단군</b> 기원 = 서력기원 + 2333년) 전근대 한민족의 조상들이 오랜 역사와 전통을...'}
# ========================================================================================================================

# %% [markdown]
# 이미지 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/image.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 파이썬
# {'title': '그누보드 QA - 파이썬 django 질문이 있습니다. 파이썬 django 질문이 있습니다. > SIR', 'link': 'https://sir.kr/data/editor/2301/thumb-32542730_1674155964.3354_650x672.png', 'thumbnail': 'https://search.pstatic.net/sunny/?type=b150&src=https://sir.kr/data/editor/2301/thumb-32542730_1674155964.3354_650x672.png', 'sizeheight': '672', 'sizewidth': '650'}
# ========================================================================================================================
# {'title': '[Selenium] 파이썬 셀레니움을 이용한 카카오맵 크롤링', 'link': 'http://post.phinf.naver.net/MjAyMzA4MjNfMTgy/MDAxNjkyNzY0MDkwOTEw.K-gBR7QtnIaHyD8ZE1EyEoymDJHQC2cHM2tBWrgBRdYg.bNbzOYVmnplObh1rse2eNogN8FSclLtkB7kC4jrU34gg.PNG/I-iWQ9hdJv11-OoFS-QaP6X2vK3k.jpg', 'thumbnail': 'https://search.pstatic.net/common/?type=b150&src=http://post.phinf.naver.net/MjAyMzA4MjNfMTgy/MDAxNjkyNzY0MDkwOTEw.K-gBR7QtnIaHyD8ZE1EyEoymDJHQC2cHM2tBWrgBRdYg.bNbzOYVmnplObh1rse2eNogN8FSclLtkB7kC4jrU34gg.PNG/I-iWQ9hdJv11-OoFS-QaP6X2vK3k.jpg', 'sizeheight': '838', 'sizewidth': '798'}
# ========================================================================================================================
# {'title': "파이썬 코드를 C로 컴파일하는 '사이썬 3.0' 공개", 'link': 'http://imgnews.naver.net/image/092/2023/07/19/0002299120_001_20230719084101158.jpg', 'thumbnail': 'https://search.pstatic.net/common/?type=b150&src=http://imgnews.naver.net/image/092/2023/07/19/0002299120_001_20230719084101158.jpg', 'sizeheight': '285', 'sizewidth': '638'}
# ========================================================================================================================
# {'title': '파이썬을 공부해야하는이유? - kakaoTV 파이썬을 공부해야하는이유?', 'link': 'http://t1.daumcdn.net/tvpot/thumb/vc440MUwTtMDXJlDmmITmW9/thumb.png', 'thumbnail': 'https://search.pstatic.net/sunny/?type=b150&src=http://t1.daumcdn.net/tvpot/thumb/vc440MUwTtMDXJlDmmITmW9/thumb.png', 'sizeheight': '480', 'sizewidth': '854'}
# ========================================================================================================================
# {'title': 'MS, ‘파이랜스(Pylance)’ 공개··· VS 코드용 새 파이썬 확장 기능 ', 'link': 'http://imgnews.naver.net/image/5177/2020/07/06/0000026835_001_20200707041008645.jpg', 'thumbnail': 'https://search.pstatic.net/common/?type=b150&src=http://imgnews.naver.net/image/5177/2020/07/06/0000026835_001_20200707041008645.jpg', 'sizeheight': '483', 'sizewidth': '724'}
# ========================================================================================================================
# {'title': '파이썬 업무자동화, 사무자동화 코딩 교육해 드립니다. | 150000원부터 시작 가능한 총 평점 0점의 직무역량 레슨, 프로그래밍 레슨, 웹·앱... ', 'link': 'https://d2v80xjmx68n4w.cloudfront.net/gigs/I6PpH1648716935.jpg', 'thumbnail': 'https://search.pstatic.net/sunny/?type=b150&src=https://d2v80xjmx68n4w.cloudfront.net/gigs/I6PpH1648716935.jpg', 'sizeheight': '1080', 'sizewidth': '1920'}
# ========================================================================================================================
# {'title': '[레시피즈] 플라스크로 시작하는 파이썬 웹 서비스 개발 - 온오프믹스 :: 모임문화 플랫폼 [레시피즈] 플라스크로 시작하는 파이썬 웹 서비스 개발', 'link': 'https://cfile1.onoffmix.com/images/event/59741', 'thumbnail': 'https://search.pstatic.net/sunny/?type=b150&src=https://cfile1.onoffmix.com/images/event/59741', 'sizeheight': '1181', 'sizewidth': '1181'}
# ========================================================================================================================
# {'title': '프로그래밍 기초로 파이썬을 추천하는 이유', 'link': 'http://post.phinf.naver.net/MjAxNzAxMThfMTUx/MDAxNDg0NzAxNDM3Njky.UwyFHezJnVpyA014k4mJ2bAnwrI7uG2FKk8exUfqySEg._iXkEYrKQIKaikhg9AnXgbV8hCnaaIDA7uqXjalncYog.PNG/I9zDP47SayMMVjMpG-hw9C_A8PEM.jpg', 'thumbnail': 'https://search.pstatic.net/common/?type=b150&src=http://post.phinf.naver.net/MjAxNzAxMThfMTUx/MDAxNDg0NzAxNDM3Njky.UwyFHezJnVpyA014k4mJ2bAnwrI7uG2FKk8exUfqySEg._iXkEYrKQIKaikhg9AnXgbV8hCnaaIDA7uqXjalncYog.PNG/I9zDP47SayMMVjMpG-hw9C_A8PEM.jpg', 'sizeheight': '290', 'sizewidth': '1143'}
# ========================================================================================================================
# {'title': '파이썬 프로그래밍 입문 온라인 코딩 수업 코딩캠퍼스 학원 : 코딩캠퍼스', 'link': 'http://shop1.phinf.naver.net/20220802_38/1659418784073tmLhJ_JPEG/60554629789374689_1862945172.jpg', 'thumbnail': 'https://search.pstatic.net/common/?type=b150&src=http://shop1.phinf.naver.net/20220802_38/1659418784073tmLhJ_JPEG/60554629789374689_1862945172.jpg', 'sizeheight': '1000', 'sizewidth': '750'}
# ========================================================================================================================
# {'title': '[Transformers] Table QA 모델로 파이썬 검색 챗봇 만들기', 'link': 'http://post.phinf.naver.net/MjAyMzA1MTBfMTk5/MDAxNjgzNjg1MDQwNzU2.x57H-74ivYf7axND_5rXIvmo3pY-V24RN9NZi0758P0g.Oea726gHKwuVrfCY8g0DJKXka3VrOphlwL2ol6EJlXMg.PNG/Ibl_5xirHhRAiYW8rleVR74_XHvs.jpg', 'thumbnail': 'https://search.pstatic.net/common/?type=b150&src=http://post.phinf.naver.net/MjAyMzA1MTBfMTk5/MDAxNjgzNjg1MDQwNzU2.x57H-74ivYf7axND_5rXIvmo3pY-V24RN9NZi0758P0g.Oea726gHKwuVrfCY8g0DJKXka3VrOphlwL2ol6EJlXMg.PNG/Ibl_5xirHhRAiYW8rleVR74_XHvs.jpg', 'sizeheight': '349', 'sizewidth': '800'}
# ========================================================================================================================

# %% [markdown]
# 쇼핑 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/shop.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 위글위글
# {'title': '<b>위글위글</b> 우드 장우산', 'link': 'https://search.shopping.naver.com/gate.nhn?id=43030359096', 'image': 'https://shopping-phinf.pstatic.net/main_4303035/43030359096.20231005152412.jpg', 'lprice': '25245', 'hprice': '', 'mallName': '네이버', 'productId': '43030359096', 'productType': '1', 'brand': '위글위글', 'maker': '', 'category1': '패션잡화', 'category2': '패션소품', 'category3': '우산', 'category4': '자동우산'}
# ========================================================================================================================
# {'title': '[<b>위글위글</b>] 리유저블 쇼퍼백(M) - Teddy Bear', 'link': 'https://search.shopping.naver.com/gate.nhn?id=42222197302', 'image': 'https://shopping-phinf.pstatic.net/main_4222219/42222197302.jpg', 'lprice': '10965', 'hprice': '', 'mallName': '29CM', 'productId': '42222197302', 'productType': '2', 'brand': '위글위글', 'maker': '', 'category1': '패션잡화', 'category2': '여성가방', 'category3': '숄더백', 'category4': ''}
# ========================================================================================================================
# {'title': '[<b>위글위글</b>] 리유저블 쇼퍼백(M) - Hound Tooth Check', 'link': 'https://search.shopping.naver.com/gate.nhn?id=40499761466', 'image': 'https://shopping-phinf.pstatic.net/main_4049976/40499761466.jpg', 'lprice': '10965', 'hprice': '', 'mallName': '29CM', 'productId': '40499761466', 'productType': '2', 'brand': '위글위글', 'maker': '', 'category1': '패션잡화', 'category2': '여성가방', 'category3': '숄더백', 'category4': ''}
# ========================================================================================================================
# {'title': '[<b>위글위글</b>] 리유저블 쇼퍼백(L) - Teddy Bear PWIKR550117', 'link': 'https://search.shopping.naver.com/gate.nhn?id=42279077461', 'image': 'https://shopping-phinf.pstatic.net/main_4227907/42279077461.jpg', 'lprice': '14900', 'hprice': '', 'mallName': '무신사', 'productId': '42279077461', 'productType': '2', 'brand': '위글위글', 'maker': '위글위글', 'category1': '패션잡화', 'category2': '여성가방', 'category3': '숄더백', 'category4': ''}
# ========================================================================================================================
# {'title': '노티드 스마일 반자동 투명 우산 (캐릭터 경량 우산)', 'link': 'https://search.shopping.naver.com/gate.nhn?id=84577371132', 'image': 'https://shopping-phinf.pstatic.net/main_8457737/84577371132.jpg', 'lprice': '15500', 'hprice': '', 'mallName': '노티드 스토어', 'productId': '84577371132', 'productType': '2', 'brand': '노티드', 'maker': '위글위글', 'category1': '패션잡화', 'category2': '패션소품', 'category3': '우산', 'category4': '자동우산'}
# ========================================================================================================================
# {'title': 'CU <b>위글위글</b> 젤리백 수영 비치 가방 옐로우 핑크 블루 퍼플 오렌지 레드', 'link': 'https://search.shopping.naver.com/gate.nhn?id=86010226310', 'image': 'https://shopping-phinf.pstatic.net/main_8601022/86010226310.2.jpg', 'lprice': '47400', 'hprice': '', 'mallName': '리치앤리치몰', 'productId': '86010226310', 'productType': '2', 'brand': '위글위글', 'maker': '위글위글', 'category1': '패션잡화', 'category2': '여성가방', 'category3': '토트백', 'category4': ''}
# ========================================================================================================================
# {'title': '<b>위글위글</b> <b>위글 위글</b> 소프트 자동차 키케이스 키링 열쇠고리 4 자동차 MD-FRPVCKEYCA', 'link': 'https://search.shopping.naver.com/gate.nhn?id=39451901426', 'image': 'https://shopping-phinf.pstatic.net/main_3945190/39451901426.20230419150459.jpg', 'lprice': '5980', 'hprice': '', 'mallName': '네이버', 'productId': '39451901426', 'productType': '1', 'brand': '위글위글', 'maker': '위글위글', 'category1': '패션잡화', 'category2': '패션소품', 'category3': '키홀더', 'category4': ''}
# ========================================================================================================================
# {'title': 'CU <b>위글위글</b> 젤리백 핑크 옐로우 블루 퍼플', 'link': 'https://search.shopping.naver.com/gate.nhn?id=85693348190', 'image': 'https://shopping-phinf.pstatic.net/main_8569334/85693348190.jpg', 'lprice': '39800', 'hprice': '', 'mallName': '루비샵', 'productId': '85693348190', 'productType': '2', 'brand': '위글위글', 'maker': '', 'category1': '패션잡화', 'category2': '여성가방', 'category3': '토트백', 'category4': ''}
# ========================================================================================================================
# {'title': '[<b>위글위글</b>] 피크닉백(L) - Smile We Love', 'link': 'https://search.shopping.naver.com/gate.nhn?id=41578109754', 'image': 'https://shopping-phinf.pstatic.net/main_4157810/41578109754.jpg', 'lprice': '10285', 'hprice': '', 'mallName': '29CM', 'productId': '41578109754', 'productType': '2', 'brand': '위글위글', 'maker': '', 'category1': '패션잡화', 'category2': '여성가방', 'category3': '토트백', 'category4': ''}
# ========================================================================================================================
# {'title': '[<b>위글위글</b>] 투명우산', 'link': 'https://search.shopping.naver.com/gate.nhn?id=40772519548', 'image': 'https://shopping-phinf.pstatic.net/main_4077251/40772519548.jpg', 'lprice': '11050', 'hprice': '', 'mallName': '29CM', 'productId': '40772519548', 'productType': '2', 'brand': '위글위글', 'maker': '', 'category1': '패션잡화', 'category2': '패션소품', 'category3': '우산', 'category4': '자동우산'}
# ========================================================================================================================

# %% [markdown]
# 전문 자료 검색

# %%
searchText = input('검색어 입력: ')
targetSite = 'https://openapi.naver.com/v1/search/doc.json?query=' + searchText
response = requests.get(targetSite, headers=headers)
searchResult = response.json()
items = searchResult['items']
for item in items:
    print('{}'.format(item), end='\n' + '=' * 120 + '\n')
# Out:
# 검색어 입력: 머신러닝
# {'title': '<b>머신 러닝</b>을 활용한 이<b>러닝</b> 학습 환경에서의 학습자 성취 예측 모형 탐', 'link': 'http://academic.naver.com/article.naver?doc_id=562143631', 'description': 'Exploration of Predictive Model for Learning Outcomes of Students in the E-learning Environment by Using Machine Learning 본 연구는'}
# ========================================================================================================================
# {'title': '<b>머신 러닝</b> 방법과 시계열 분석 모형을 이용한 부동산 가격지수 예측', 'link': 'http://academic.naver.com/article.naver?doc_id=561655472', 'description': 'Predicting the Real Estate Price Index Using Machine Learning Methods and Time Series Analysis Model 본 연구의 목적은 부동산 '}
# ========================================================================================================================
# {'title': '<b>머신러닝</b> 기법을 이용한 대졸자 취업예측 모형', 'link': 'http://academic.naver.com/article.naver?doc_id=561716188', 'description': 'A Predictive Model for the Employment of College Graduates Using a Machine Learning Approach 본 연구는 <b>머신러닝</b>의 랜덤 포'}
# ========================================================================================================================
# {'title': '<b>머신러닝</b> 플랫폼을 활용한 소프트웨어 교수-학습 모형 개발', 'link': 'http://academic.naver.com/article.naver?doc_id=638269481', 'description': 'The Development of Software Teaching-Learning Model based on Machine Learning Platform 현대사회는 21세기 초반 지식정보사'}
# ========================================================================================================================
# {'title': '<b>머신러닝</b> 인공지능의 법 분야 적용의 현재와 미래 : 미국의 현황과 법조', 'link': 'http://academic.naver.com/article.naver?doc_id=233556606', 'description': 'Current Status and Future Developments of Machine Learning Artificial Intelligence in Law : Focusing the Cusp of Machine Learning in U.'}
# ========================================================================================================================
# {'title': '한국 초등학교 3학년 아동의 행복감 예측을 위한 <b>머신러닝</b> 알고리즘의 ', 'link': 'http://academic.naver.com/article.naver?doc_id=645882005', 'description': 'Application of Machine Learning Algorithm to Predict Happiness of Elementary 3rd Graders in Korea 본 연구의 목적은 <b>머신러닝</b> '}
# ========================================================================================================================
# {'title': '랜덤포레스트 <b>머신러닝</b> 알고리즘 기반 남·여 청소년의 자살생각 예측 ', 'link': 'http://academic.naver.com/article.naver?doc_id=645448765', 'description': 'A Predictive Model for Suicidal Ideation of Adolescents Using Random Forests Machine Learning Algorithm 본 연구는 <b>머신러닝</b>의 '}
# ========================================================================================================================
# {'title': '<b>머신러닝</b> 기반의 학업성취 예측 모형 탐색', 'link': 'http://academic.naver.com/article.naver?doc_id=841324260', 'description': 'Exploring a Model for Predicting Academic Achievement with Machine Learning for Off-line Courses in Higher Education 본 연구는 머'}
# ========================================================================================================================
# {'title': '다양한 종류의 예측에서 <b>머신러닝</b> 성능 비교', 'link': 'http://academic.naver.com/article.naver?doc_id=562527554', 'description': 'Performance Comparison of Machine Learning in the Various Kind of Prediction 현재 인공지능의 한 영역인 <b>머신러닝</b>을 적'}
# ========================================================================================================================
# {'title': '<b>머신러닝</b> 기반 메모리 성능 개선 연구', 'link': 'http://academic.naver.com/article.naver?doc_id=838552838', 'description': 'Study on Memory Performance Improvement based on Machine Learning 이 연구는 사물인터넷, 클라우드 컴퓨팅 그리고 에'}
# ========================================================================================================================
