# %%
import warnings
warnings.filterwarnings(action='ignore')
# %config Completer.use_jedi = False
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# %%
option = Options()
option.add_argument('--window-size=1890,1030')
driver = webdriver.Chrome('./chromedriver.exe', options=option)
driver.implicitly_wait(5)

driver.get('https://comic.naver.com/webtoon/detail?titleId=812354&no=22')
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# 전체 댓글을 연다.
# driver.find_element_by_xpath('//*[@id="cbox_module_wai_u_cbox_sort_option_tab2"]').click()
driver.find_element_by_css_selector('#cbox_module_wai_u_cbox_sort_option_tab2').click()
time.sleep(1)

# 더보기 링크가 더 이상 나오지 않을때 까지 반복하며 댓글이 더보기 버튼을 클릭해서 댓글을 표시한다.
while True:
    try:
        driver.find_element_by_xpath('//*[@id="cbox_module"]/div/div[7]/a').click()
        time.sleep(0.5)
    except:
        break
        
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

replys = soup.select('#cbox_module_wai_u_cbox_content_wrap_tabpanel div.u_cbox_comment_box span.u_cbox_contents')
print(len(replys))
for reply in replys:
    print(reply.text.split('\n'))
# Out:
# 1519
# ['비상금 주식 때려넣고 맘고생하기']
# ['맘고생하면,,, 스트레스로 빠지긴 빠짐ㅋ']
# ['남편이랑 3개월 끊어놓고 한번도 안감ㅋㅋㅋㅋㅋㅋ']
# ['술끊고, 야식 끊고, 라면 끊고 간식 끊고 밥 반공기로 줄이고 삼시 세끼 꼬박꼬박 챙겨먹으면서 2년동안 앞자리수 두 번 바꿨는데요. 지금은 술도 가끔 마시고 먹고 싶은 거도 먹고 삼시 세끼 꼬박 챙겨먹는 건 아니지만 유지하려고 노력중입니당. 그래도 야식 안 먹어용, 평생하는 거라 생각하시는 게 젤 좋아여...또르르내일부터 하자고 생각하면 망하는 지름길임다ㅠㅠ ']
# ['ㅋㅋㅋ']
# ['튀김에 있는 탄수화물은요...?']
# ['적당히 해요 ㅋㅋㅋㅋㅋㅋㅋ']
# ['킹장갓시경']
# ['현실: 1컷']
# ['???: 물만 먹었는데....(무엇을 물처럼 먹어 치웠는지 생각해 보시오.)']
# ['나쁜놈이네,,, 신랑이 저렇게 빼면 신부가 묻힌다규ㅠㅠㅠ']
# ['살어떻게 빼요? 청첩장 나눠주면서 술먹으면 찌던데ㅜ ']
# ['너 C야 T발?']
# ['냥군 진짜 대단한 사람이네요 의지도 대단하고..']
# ['운동 안해도 3키로 저절로 빠지던데ㅋㅋ']
# ['맞아요 다이어트 성공한 사람들은 대단한 것 같네요👍']
# ['ㅋㅋㅋㅋㅋ 표정 무엇?🤣']
# ['우선 그 과자부터 내려놓고 말하시죠?ㅋㅋㅋㅋ 🤣']
# ['냥군....멸치가 다 됐어....🤣ㅋㅋㅋ']
# ['표정 너무 웃긴거 아니냐고🤣']
# ['엄마:앗싸!~~']
# ['저는 예식당일 너무나도 부지런한 엄빠덕분에 식장에 일직도착해서 1층애 있던 햄버거집에서 햄버거 세트 야무지게 먹고 결혼식을 치뤘?는데 그날 .. 임신해서 결혼했냐는 후문을 참 많이 들었지요.. 그나마 햄버거막었단 핑계가 있어서 다행 원래도 복부비만인디요 팔다리가 얇아 숨겨왔던 ㅋㅋㅋㅋ ']
# ['마루야 ..']
# ['날잡고 결혼식날까지 6킬로가량 뺐어요 그럼뭐해 결혼하고 1년만에 도로 다 쪘는데....']
# ['맞아 지금 재수중인데 6월에 시간의 촉박함을 느끼고 아점저먹는시간을 전부 공부시간으로 바꿨더니 이때 8월에는 15키로 빠져있었음 (두달 내내 굶은거 아님)(7월부턴 다시 잘 먹기 시작했는데 양이 줄어서 그럼)']
# ['저도 이지은,신지니 다해봤지만 결국 덤벨들고 중량하는게 진짜 효과직빵이더라구요!']
# ['살찌면 투뿔되는건 틀린 얘긴 아니긴..하죠 ㅜ']
# ['아 배고파']
# ['저희 아버지도 뚱뚱하셨는ㄷ지긍은 다이어트 하셔서', '날씬해짐']
# ['체중계 "우와" ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['샹크스 다이어트법팔을 자르면 몸무게가 수 kg 가벼워진다', '', '플로지스톤 다이어트법', '죽으면 2g정도 가벼워진다고 했던거 같다']
# ['우와Kg 이시구나•••!!!!!']
# ['네 저는 1년간 최고 몸무게로 식에 올라갔답니다 핳핳핳']
# ['헐 ']
# ['이게 이렇다니까요...? ㅋㅋㅋㅋㅋ']
# ['지금의 나.. d-21 ㅜㅜ']
# ['쭈그렁 한거보소']
# ['난 이제 앞자리가 1로 고정인데....']
# ['아 빵터짐 ㅋ']
# ['우와 제 프사가 여기 있었네요...!!']
# ['나의 시험을 바라보는 표정']
# ['냥군이뺀거 자까님한테갓네ㅋㅋ']
# ['성공했다가 요요...']
# ['치킨은 밀가루..']
# ['결혼 전 3개월 운동해서 10키로 근손실 없이 빼고 20키로 요요 왔어요 요요요요요지경세상']
# ['INTJ 같음']
# ['지방분해주사 + 승모근보톡스']
# ['뼈 때리네ㅠㅠ']
# ['결혼식 바로 전날 신랑이랑 친구들이랑 호프집에서 신나게 술먹다가 친척한테 걸렸어요 ㅋㅋㅋ 하 벌써 10년전이네요..^^']
# ['고3때 한창 수능공부할때 스트레스 받기도하고 급 다이어트 삘이 꽂혀서 공부하면서 12키로 넘게 뺌 물론 1년넘게 유지중 ㅎㅎ 진짜 초절식하면서 뺐네여']
# ['자까님 결국 다이어트 성공햇다는 말은 없는거냐구요ㅋㅋㅋ 연출상으로도 이건 했다~ 이만큼은 성공했다~같은 말이 단 한마디도 없네ㅋㅋㅋㅋ']
# ['와.. 진짜 결혼하기 전 내모습이랑 똑같아서 소름돋았어요']
# ['있어요 저 3개월에 20kg 뺐는데 파인애플+요거트 최고조합이었죠. 산성분이 들어 지방 분해해주는 레몬 파인애플같은 과일과 장운동 활발히 시켜 내장지방 빼주는 요거트의 조합은 효과 빠르죠']
# ['땡볕에 농구하면 살 금방빠짐...근데 까매짐']
# ['에어팟 현실반영 제대로네ㅋㅋ']
# ['뱃살을 얻으면 세상 너그러워짐내가 초 예민한 사람인 줄 알았는데 살쪄보니 너그러워짐']
# ['49>43 일주일만에 빼봤는데1.5km 매일 뛰다가 걷고 하루에 1000kcal미만으로 먹음', '근데 너무 보기 안좋아서 46으로 찌우고 유지하다가', '지금은 48이네요....ㄸㄹㄹ 잘먹고 건강한게 최고인듯해요']
# ['제동생도 미술입시할때 60키로꺼지 쪘다가 대학1학년되고 야작하고 과제에 치여거 48키로까지 빠졌읍니다..대학가서 빠진단게 사실이었음']
# ['자까님 커엽다']
# ['중3때 이후로 12년간 몸무게 앞자리 변화 없이 대체로 유지 중이에요 중간에 찌고 빠지고는 있지만 앞자리 수가 줄면 줄었지 절대 늘진않더라구요 ']
# ['8. 운동은 처음에는 기초체력을 기르기 위해 걷기나 유산소 운동부터 시작해서 ( 저질체력이래도 5분~10분짜리부터 차차 시작하면 됨. ) 차차 늘려나가면 됨. 단 익숙해질 때마다 강도를 서서히 올려야 함.워밍업( 동적 스트레칭)- 무산소 운동- 유산소 운동- 정적 스트레칭 ', '9. 폭식했다 해도 망했다면서 포기하지 말길. 며칠간 유산소 운동 강도 늘려서 하고 식이요법 병행하면 됨.', '10. 생리증후군 때 폭식하는 습관 끊어야 함. 그리고 생리 기간에는 가벼운 운동이나 요가 정도만 하던지 푹 쉬어야 하고 생리가 불규칙적이면 똑같이 운동해도 안 빠짐.', '11. 굶지마라. 두 번 말한다. 굶지 마라. 굶으면 몸이 비상사태 모드로 지방을 축적해서 결과적으로 전보다 더 살이 찜.', '12. 아침도 가볍게라도 챙겨먹는 게 나음. 13. 술 좋아하면 술도 자제하길. 복부비만의 원인이 됨.', '', '이렇게 해서 80kg 가까이 나갔다가 지금 61~63 유지 중( 정체지 ) 이다.']
# ['3. 가급적 날짜가 바뀌기 전에 자고 7~8시간씩 자기. (10시쯤 자면 금상첨화임. ) 4. 저녁은 잠들기 4시간 전에 먹기. 5. 일반식은 밥  2/3 공기 or 반 공기 + 짠 반찬은 조금만 + 국물은 건더기만 약간 건져서 6. 당 함량이 높은 음식, 기름진 음식, 짠 음식은 적게 먹거나 가급적 안 먹기. ( 치팅데이의 경우 두 달 후 주 1회씩 가졌음. ) 7. 외식할 경우 김밥, 비빔밥, 샐러드, 샐러드 파스타, 서브웨이 샌드위치, 샤브샤브 ( 소고기 150g +야채위주 ) , 쌀국수, (  본죽 비빔밥 추천함.)']
# ['졸업하고 두 달 지나서 다이어트 시작했음. 다이어트는 생활습관을 바꾸고 더 나아가 평생 동안 지속할 수 있는지를 고려해서 식이요법과 운동을 병행해야 함. 물론 고도비만의 경우 처음부터 운동을 하면 관절이 상하기 때문에 식이요법만 해서 지방을 덜어내는 게 좋음. 1. 밥 먹고 바로 눕지 말고 2~3시간 후에 눕기. ( 4시간 후에 눕거나 안 누우면 더 좋음. ) 2. 세 끼 식사 외에 간식, 야식은 금지. 정 먹고 싶으면 아메리카노, 차, 저지방 우유, 블루베리, 딸기, 채소 중 하나로 대체. 배고프면 물 중간중간 마시기. ( 물은 매일 최소 1리터에서 최대 2리터씩 마셔야 함. 나 같은 경우는 1.5리터씩 마셔줌. )']
# ['과제...']
# ['입이 대빵만큼 나왔는데요?']
# ['와 저 지금 안성탕면 부셔먹으면서 보는데 깜놀 ㅋㅋㅋㅋㅋㅋㅋ']
# ['청첩장 돌리고 인사하고 매일같이 약속 잡으니까 살이 저절로 빠졌음..']
# ['개아련해 ㅋㅋ']
# ['ㅋㅋㅋㅋㅋ티답변 너무 웃겨']
# ['근데 운동진짜 안한사람들은 그럴체력조차없기에 조깅부터 하는거 추천...지짜 건강도 있을때 챙기는거고 운동도 할 체력이있을때부터 해야함', '', '', '', '(침대에서 뒹굴거리며...']
# ['체중계 우와 ㅋㅋ']
# ['그래서 앞컷엔 실제로 한 말을 붙인거군']
# ['장염다이어트']
# ['167cm 현 대3인데 고3때 코로나 시작이였어서 62kg찍었다가 대1때 가족들이랑 걷고 식단해서 54kg까지 빼고 다시 쪄서 58kg 되었다가 대2 여름에 대면 풀리고 헬스장 다니면서 55kg까지 뺏다가 현재는 다시 59kg 으로 돌아오니 발목이 원래 약한데 발목이 점점 아파져서 강의로 생활체육1도 들으면서 운동하기로 했고 생활관 사니깐 학교 체단실 가서 운동도 할 예정']
# ['나도안다고...']
# ['고1이 되기까지 몸무게 50넘은적업ㅂ슴...']
# ['특정부위 살빼는 운동은 없습니다.. 림프절을 폼롤러로 조지라는분들 림프절 조지는게 지방빼는거랑 무슨관련이 있나요..  아예 가슴빠질 각오하고 유산소 하루 3시간씩 조지던가, 아님 지방흡입 하는게 제일 좋습니다.']
# ['ㅌㅊ ,ㅌ']
# ['두달 동안 70에서 49까지 빼봄  운동 3시간하고 삼시세끼 클린식 저염집밥 먹으면 빠짐ㅋㅋ..']
# ['아 기여워']
# ['스튜디오 촬영이 아닌 본식 촬영은 뽀샵은 없다고 보면 됩니다. 그래서 정말 각오하고 살빼야 본식때 잘 나옵니다. 실제로 본식까지 두달간 6kg뺐습니다. 충격요법이 좋긴 하더라구요.']
# ['한가지의 방법으로 팔을 옆구리에 붙이지말고 살짝 띄우라고 들었어요. 그럼 덜 퍼져보인다구요.']
# ['와 진짜 마음먹으면 뭐든 해내는 사람 ㄷㄷ']
# ['EMS스파, 지방 흡입 등']
# ['재섭써']
# ['다이어트는 몸이 아파보면 가능. 108에서 68까지 40키로 빼고 9개월째 유지어터중. 108때 당뇨초기 혈압 186 통풍 족저근막 등등 만신창이 되고 병원에서 사형 직전 선고 받고 하게됨. 입으로는 쉬운데 아프면 몸으로 하게됨. ']
# ['ㅋㅋㅋㅋㅋㅋ 이만화 오ㅑㄹ케 웃기냐..ㅠㅠ ']
# ['결혼식에서 신랑보다 몸무계많이 나가는 신부는 진짜 역겹다']
# ['이럴땐 면사포가 최고의 방어템인데..ㅎ']
# ['3달동안 토마토랑 닭가슴산만먹고 10kg뺐는데 지금보니까어케한건지 모르겠다 ㄷㄷ']
# ['ai 클로바 탑제 체중계.살찌면 욕함.']
# ['맞긴해, 2조각정도만 먹는다면 말이지']
# ['ㅍㄸㅅ']
# ['피부관리 하나도 안했는데 본식 한달전에 팔뚝 조지는 주사 맞음 비싸지도않고 효과 개쩔ㅎㅎ']
# ['제로콜라에서 탄산수로 탄산수에서 물로 바꾸는중.. 탄산끊기 너무 힘듬\U0001f979\U0001f979']
# ['그래서 전 늘3개월치씩만 끊어욥.. 장기간으로 끊으면 내가 자꾸 귀찮아서 안가게 됨...']
# ['저는 그냥 안했어요 ㅎㅎ 통통한편인데 의지가 강한편도 아니고 행복하게 먹을거 다 먹었어요ㅋㅋㅋ  진짜 몇십키로 뺄거 아니면 여리여리하게 될것도 아니라 굳이? 라는 마음이 더 컸던거같네요 ㅋㅋㅋㅋ']
# ['이제 결혼 하시고 한 1~2년 쯤이면 다시 돌아옵니다. 정확하게는 최고를 찍죠. 네...집밥이 최고긴 합니다.']
# ['너 T발 C야?']
# ['여러분 제로콜라 말고 비건콜라 드세요~ 이게 순수 0칼로리입니다. 맛있어요']
# ['결혼 한달전 단식원..?']
# ['기숙학원에서 재수했을 때 일년동안 12kg 빠졌더라구요.. 근데 그건 스트레스 + 근육이 빠진거라 살이 빠졌는데도 보기에도 안좋고 팔뚝은 얇아졌는데 똥배는 나와있고 그래서 수능 후 건강하게 운동하면서 다시 몸관리했네요 ㅎㅎ 다이어트는 건강하게 하세요!! ']
# ['부위별로 운동하니까 빠지던데...?']
# ['<- 한 컷인데요']
# ['.']
# ['GLP-1 antagonist도 있죠...^^;']
# ['솔직히 저는 점심시간 바쁘면 40분 , 안바쁘면 50분 , 더 안바쁘면 60분인데요. 그 시간안으로 밥 빨리먹고 바로 앉다보니까 살이 찔 수 밖에 없더라고요. 왜냐 저는 밥을 먹으면 2~30분 걸려서 산책할 시간도 없네요']
# ['포기하고 신부입장한 사람 여기 있습니다.  그래도 다 되긴 되더라구요']
# ['t발 c야?']
# ['시간 가는 줄 모를만큼 그만큼 시간을 알차게 잘 사용하셨다는 뜻..']
# ['미친ㅋㅋㅋㅋㅋㅋ']
# ['탄수화물 무시하면 근육 절때 안늠']
# ['어우.. 긁히네;']
# ['질량보존의 법칙']
# ['전,,, 다이어트포기하고 신부마시지로 등허리만 냅다 조졌어여 ㅋㅋㅋ']
# ['근데 일반적으로 남자가 기초대사량이 더 높아서 똑같이먹으면 여자쪽이 더 살찌는게 맞는거 같습니다']
# ['제로콜라 이야기가 왜.. 작가님은 콜라라고 한적없는데.. ']
# ['헬스인으로써 일단 꾸준함과 재미를 찾는걸 추천드립니다 (물론 그게 제일 빡셈)']
# ['여러분 무엇을 물처럼 마셧는지(드셧는지) 생각해보시기 바랍니당']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 이거..저희 이야기인가요... 저희는....둘다 앞자리를 바꾸지못했습니다..']
# ['그쵸...우리의 뇌는 포도당만을 에너지원으로 사용해서 단백질만 먹으면 슬프게도 머리가 잘 돌아가지 않죠..', 'ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ']
# ['대장내시경 진짜 최고에요. 피티쌤이 그렇게 식단 하고 운동하고 그럴거면 맨날 빋으라고....절대 두번 안하겠다는', '의지로 양념안한 닭가슴살, 두부로 일주일먹음']
# ['저는 1년만에 34키로 뺐어요...']
# ['진돌님 실연 다이어트 영상 생각나네ㅋㅋㅋ']
# ['약 마시면서 뿔고 아웃풋후 인풋만큼만 빠졌던 불편한 진실..']
# ['하... 그걸 내가 했었는데 스밥..... 16키로 뺐었는데 몇 개월 뒤에 정신차리고 나니까 9키로가 도로 찜...^^!']
# ['배댓 되면 살빠짐']
# ['우와 ㅋㅋㅋㅋ']
# ['저도 결혼식 앞두고 청첩장 돌린다 어쩐다 식사 자리도 많아서 오히려 살빼기가 더 힘들더라구요. 그래서 마지막 5일동안 바나나 세개 먹고 5키로 빼고 식장 갔습니다 ㅋㅋ 짧고 굵게']
# ['저는 결혼하기전에  포켓몬고에 빠져서 포켓몬 찾아 하루에 2시간 기본으로 걸었던거 같아요 그래서 결혼식까지 6키로 뺐습니다 (3달동안) 포켓몬고의 힘!']
# ['와ㅋㅋㅋ너무공감ㅠㅠㅠㅠ저두 결혼할때 인생최대몸무게ㅋㅋㅋㅋㅋ영혼빠진 저눈 너무 잘그렸다 꼭 거울같아요']
# ['쳐는 묵음이야♡ (쳐)맞는 말']
# ['저도 정싱체중이 63인데 72넘긴거보고 어이가없어서 다이어트 시작하고 8개월쯤되니 63과 64를 왔다갔다 하게되었습니다. 대충 먹는걸 조금 줄이고 주말에 자전거 100km만 타면 빠지더라구요 다이어트 하시는분들 화이팅']
# ['저건 운동이 아니라 재활치료아닌가요ㅋㅋㅋㅋㅋ']
# ['나도 앞자리 두 번 바꾸긴 했는데..올라가긴했지만']
# ['와..지금 내 모습이다..다이어트해야지 하면서 누워서 과자먹고 이거 보고있음..']
# ['애 낳고 굶으며 살뺐는데.. 면역력 약화로 알러지만 생김요ㅠㅠ ']
# ['팔뚝살은 괄사나 폼롤러로 혈액순환해주고 말린어깨를 펴주기 시작해야 빠집니다~~~~']
# ['자까님 입 댓발 나옴 ㅋㅋㅋ']
# ['저도 실패했습니다 후회는 없습니다']
# ['박명수']
# ['치킨 의외로 다이어트 야식임단, 굽네치킨 로스트 아님 전기구이통닭만 가능']
# ['이거 캡쳐하게해줘...!한컷만...!']
# ['1년반동안 76->62까지 빼고 이후로 조절없는데 아직도 62~65로 유지중임. 허리디스크 때문에 시작했는데 정신차려보니 바지가 34에서 28~29사이로 입는거 보면서 숫자보단 눈바디나 인바디가 최고란걸 느낌...진짜 걍 밥,라면 등등 뭐든 다 반으로 나눠서 2끼로 드시고 대신 생야채로 채워보세요. 식욕은 그대로인데 나중에 입짧아져서 못먹고 스스로 ???하며 인지부조화 오게 됩니다.']
# ['댓글수 처참하다 구라일기 ㅋ']
# ['유콘이랑 남편콘 같아...']
# ['아 ㅇㅈ 순식간에 2키로 빠짐 그리고 한시간만에 회복!']
# ['ㅎㅎㅎ나랑 남펀은 결혼식 바로 전날에 치킨먹었는데.....^^.. 나도 다이어트 할줄알았는데 의지가.... .ㅠ']
# ['올해 두달간 다욧 해서 8킬로 뺐어요 . 밥 안먹고 라면 끊고 떡볶이 끊고 빵 끊고 ㅠㅠ 복근을 얻고 바프 찍었어요 .  ㅠㅠ ']
# ['대장에 병걸려서 강제다이어트하고 6킬러 뺐습니다.근데 뱃살은 안나가고 꼭붙어있네요. ㅠㅠ']
# ['내가 이 합리화로 결혼식 전전날에 치킨을 시켜먹엇읍니자']
# ['커피랑 햄버거는 끊었는데 과자랑 음료를 못끊겠어요...']
# ['역대급 몸무게 찍고 비만으로 결혼...']
# ['한번 다이어트 성공해 본 사람이 다시 다이어트 하는게 제일 어려운듯...난 한 번 독하게 맘만 먹으면 성공할 수 있어!', '이딴 생각 때문에 아무렇게나 먹어댐 ㅋㅋ', '근데 저 생각때문에 오히려 독한 마음이 잘 안먹어짐ㅜㅜ']
# ['예식 끝나고 연회장에서 신부신랑이 돌면서 인사 나누는대 보통 무슨 이야기 들을 하나요?']
# ['맥주 극혐이라 안마시는데 그래서 덜 찌나보다']
# ['그래서 헬스장에 기부하느니 매달 동물보호소에 정기후원 합니다.. ']
# ["엄청 비만에서 20키로 빼는거랑 보통에서 5키로 빼는건 아주 큰 차이가 있음ㅋㅋ 살집이 좀 있으셨나본데 뱃살까지 좋아했다니 '찐'사랑이네"]
# ['그냥 타고난 체형은 안변해요.. 부위별 살빼기 그런거 없음. 얼굴도 콧대 마사지한다고 찰흙마냥 올라가는게 아니듯이 인위적인 시술말고는 안변해요드레스를 디자인을 딴걸로 바꾸면 되지 옷에 나를 맞추는거 힘들음ㅋㅋ']
# ['개노답 도태된 여시페미들이랑 다르게 자까님은 능력도 좋고 노력도 엄청나고 애인분을 잘이해하네ㅋㅋ페미들은 ㅂㄷㅂㄷ ㅋㅋㅋㅋㅋㅋ']
# ['신규 간호사샘들 대학병원 가면 한달에 10키로씩 빠진다던데.....']
# ['지금도 퇴근하고 낮술하고있는나,,, 제법 글러먹었어요']
# ['구운치킨으로 합의봅시다...']
# ['기엽다']
# ['60->50까지만 뺐는대 생각보다 몸이 안이뻐서 43까지 빼고싶은데 식욕이 넘쳐나서 못빼는중 ㅠㅠ']
# ['허리가아파 재활피티하면서 결혼하려고 10키로뺐습니다 먹는거로요...ㅠㅠㅠ풀+계란+닭가슴살+간단한 과일(방토,바나나등)', '만먹었어요', '그리고 결혼후10개월 원상복구했네요ㅎㅎㅎㅎ', '행복ㅋㅋ']
# ['다이어트는 의외로 할만합니다. 유지가 힘들지... ㅠㅠ ']
# ['마져요 다요트성공은 인생승리인듯!! 전 5개월동안 3kg 뺏는데 3kg 늘 빠졌다 찐다고 더 빼야된다고 ... ㅜ.ㅠ 몸무게 앞자리 바꾸는게 목적이라 일단 열운중요 다요트하시는 모든분들 화이팅요!!^^']
# ['아는 것과 실천하는 것은 다르다']
# ['의지박약;;']
# ['먹는양 안줄이셔도 되요 가장어려운 밀가루 먹지말고 하루에 1만보만 걸으셔도 됩니다 제가 그렇게해서 3주만에 10kg을 감량햤거든요 한끼에 밥 두공기씩 먹어도']
# ['저는요 다이어트 하다가 어 그 몇키로 쪘냐 어 아그 37키로가 5년 동안 쪄서 그냥 단식원에 들어갔습니다.....']
# [' 헬스안다니고 신지니로만 6kg빼고 결혼했어요! 허벅지안쪽살, 팔뚝살, 뱃살 지옥버전 진짜 직빵이에요 추천!55.5 > 49.5 까지 찍고 이쁜사진 남겼답니다!!']
# ['체중계에 우와 적혀있네 ㅋㅋㅋㅋ ']
# ['진짜 지난번에 드레스 선택하는 편보고 등신대사이즈자까님 캐릭터가 현실드레스입은게 꿈에까지 나왔는데 드레스만이라도 제발 언젠가 보여주시면 안될까요ㅠㅠㅠㅠㅠㅠ']
# ['우리는 팁이고 나발이고 다 알고있습니다단지 안할뿐이죠 ^_ㅠ', '왜요? 제가 그래보이세요?', '정답']
# ['크리스마스 삼갤남음... 나는 빚이나는 솔로']
# ['-10+10', '이렇게 두 번?']
# ['이게 살빼는게 맞는데 다른건 머가있죠..?']
# ['비싸게 돈줘도 한달이 최고임 돈아까워서 한달 꾸역꾸역 다녔는데 조금 싼 가격으로 두달 끊으니까 귀신같이 안가더라ㅠ']
# ['고3때 62찍고 대학교 입학하기 전 두세달 정도 저녁 안먹고 운동해서 6키로 빼고 입학했는데 가서 보니 살찐축에 속해서 슬펐고 무기력했다. 왜냐면 최선을 다해 유지중이었고 더 안빠졌거든. 몸에 무리 안가는 정상적인 방법으론 절대 날씬해질 수 없다는 걸 깨닫고 유지를 게을리 함. 세월이 20년 정도 흘렀는데 체중이 56 임. 쪘다 빠졌다 해도 결국은 56이 됨. 신기함. 직장다니다 언젠가 검사해보니 기초대사량이 너무 낮더라. 그래서 죽어라 안빠졌던거']
# ['저러니 서울대 의대가나보다....']
# ['냥군 나이대면 병원일 바쁜말할듯']
# ['생라면 맛있지~']
# ['주2회 체대입시학원', '먹고싶은거 다 처먹고 저녁 단백질만 먹기', '', '놀랍게도 한달만에 7kg이 빠짐']
# ['저는 식단으로 3달만에 16키로를 뺐었죠... 물론 운동도 했었구요 진짜 식단이 8할입니다 ']
# ['드레스를 못입으면...?']
# ['처음 가는 길 투성이인 인생에 가족, 사랑하는 사람처럼 함께 걸어줄 사람이 있다면❤️']
# ['8->7->6 인가보네ㅋㅋ']
# ['다이어트 해야지....생각만 6개월가지고 전날밤까지 삼겹살 먹고 새벽에 웨딩드레스 입고 나갔습니다 ', '전 F입니다. 먹으라고 한번만 권유해도 먹습니다 ', 'ㅋㅋㅋㅋ', '']
# ['T다....']
# ['보면서 너무 웃겨서 계속 웃으면서 봤어욬ㅋㅋㅋㅋㅋㅋ']
# ['현대의학기술최고......결혼식은 역시 승모근주사와....지방흡입........']
# ['200키로대에서 90키로대로 ㄷㄷ']
# ['내일 모레 야외촬영인데 치킨 먹는 중이에요 호호 저만 다이어트 실패한게 아니었네요 새삼 감사합니다…']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋ그만 물어보자ㅋㅋㅋㅋㅋ대장 내시경ㅋㅋㅋㅋㅋㅋ']
# ['경제활동 하면서 결혼식 준비하려면.. ㅠㅠㅠ 진짜 덜 먹으면 기력 없이 일하느라 회사에 눈치보이고.. 평소처럼 먹자니 살이 걱정.... 빨리 결혼식 지나가버렸으면 했음 ㅠㅠ']
# ['고3 때 헬스장에서 체중계에 올라갔을때 세자리수 직전까지 찍힌 거 보고 충격먹어서ㅋㅋㅋㅋㅋ첫 3개월에 10kg 감량 후 유지했다 빠졌다를 10년정도 반복하며 60키로대를 유지하다가 결혼 준비 기간에 pt를 받고 본식 당일 59kg까지 감량 후 본식 진행했습니다ㅎㅎ', '지금은 좀 쩠지만 적당히 관리하며 적당히 운동하며 감량 및 유지중입니다...ㅋㅋㅋ', '56이 바디프로필 몸무게라고 하는데 지방만 많고 근육이 없어서ㅠㅠ 회사 병행하면서 타이트한 식단과 운동은 힘들어서 나중에 퇴사하면 56 도전해봐야겠어요ㅎㅎ']
# ['같이 등록하묜 같이 안가게 되던데... ㅋㅋㅋㅋㅋㅋ']
# ['이거 저장각']
# ['안먹으면 3개월에 15키로 쌉가능']
# ['내가 진짜 빵만 끊어도 4n 찍는데.... ']
# ['교정기 끼면 강제 다이어트 됩니다^^... 저는 이렇게 한달만에 사키로가 빠졌어요']
# ['그런날있잖아... 다이어트중인데..치느님이 보고싶은날....']
# ['La donna e mobilequal piuma al vento,', "muta d'accento", 'e di pensiero.', '여자의 마음은', '갈대와 같이', '이리저리로 흔들린다오.']
# ['유산소랑 부위별 살빼기 같이하면 빠져요러닝머신 6km/h 한시간에 신지니 팔뚝살빼기 같이하면 짱']
# ['하지만 이젠 위고비가 있지 ㅎ']
# ['와 안성탕면을 생으로 먹다니 작가님 배우신 분이네']
# ['공복유지시간을 늘려보세요! 오전에는 공복유산소 운동이요! 아점 11시부터 오후5시 최소6시전까지만 먹기를 다짐한 후 저녁시간에 운동! 홈트같은 거요! 간식 먹지말기. 그리고 물 많이 마시기! 저는 이루틴으로 3일에 거의 1kg씩 빠지고 있어요..']
# ['포토샵..... 포토샵만 믿었습니다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 뭐 어차피 하객으러 온 사람들 다 아는 사람들이고 ㅋㅋㅋㅋ 나중에 자식들에게 엄빠 리즈때다~ 할 용이니... 포토샵으로 적당히 나같지만 이쁘게 ㅋㅋㅋㅋㅋㅋㅋ ']
# ['사람들이 저 먹는거 보면 생긴거와는 다르게 엄청 잘 먹는다고.. 근데도 살이 안찌는게 부럽다고 하던데.. 아마 제가 어릴때부터 저체중이고 집안 자체가 잘 안찌는 체질이라..']
# ['나도 술끊고 제펩 1박스사서 먹는듕ㅠ']
# ['제로콜라대신 탄산수를 마시면 될텐데']
# ['대장내시경이 획기적이긴하죠 ㅋㅋㅋㅋ']
# ['손가락이 하나가 아니라 두 개네']
# ['라면을 먹고 계시잖아욬ㅋㅋㅋㅋㅋ']
# ['제로음료는 신이야진짜 노벨상 줘야해']
# ['자까님 그냥 어머님 모시고 드레스카페라도 다녀오세요 반응만보면 어머님이 결혼하시는 것 같아요 ㅋㅋㅋㅋㅋ']
# ['탄산음료도 몸에 안 좋은건 마찬가진데...;']
# ['어떻게 이런 신박한 표현을 ㅋㅋㅋㅋ']
# ['27키로 감량한적 있음밥은 현미밥이나 잡곡밥 반찬은 단백질 위주', '간식,야식 안먹음', '운동은 걷기 2만보씩 이렇게 하니 3개월만에 빠졌지만', '극단적인 다이어트와 유지를 못한 관계로 요요가 왔음**']
# ['주사 꽝']
# ['단기간안에 빠지는 방법은 굶는거 뿐 아니면 위를 자르던가']
# ['빼는데 성공해도 곧 더 찌니~~']
# ['맥주가 진짜 뱃살주범']
# ['웨딩드레스를 신랑 입히면 이뿌겠다']
# ['구운 치킨 드세요.']
# ['요요가 더 무서워유ㅠ']
# ['앞자리 한번도 아니고 두번 ㄷㄷㄷ']
# ['f들 조질수있는 밈이 얼른 나왔으면함 저거볼때마다']
# ['드레스를 입기 위한 노오오력']
# ['결혼할때 다이어트했는데 그때가 최저 몸무게였어요.. 아주 잠깐이였지만 행복했다. ']
# ['9월17일 결혼하는 예비신랑 입니다. 만화를 보면 정말 제 모습을 보는거 같아서 너무 웃기고 공감이 잘되네요ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ모든사람들은 다 같지는 않아도 비슷한게 많은가 봅니다!ㅋㅋㅋㅋㅋ']
# ['단기간 제일 확실한건 편도 떼는 수술이요ㅋㅋ']
# ['저두 이번 대학교 종강하고 두달동안 107kg에서 92kg 까지 다이어트 성공했습니다!!']
# ['과연그럴까?']
# ['족발보쌈도 단백질이지']
# ['제로맥주?']
# ['그러게. Pt끊은건어쩌고?']
# ['하루에만걸음씩걸어봐. 살금방빠짐']
# ['결혼 해 본 ㅅ이 더~ 대단 한 걸로 느껴 지는 요즘.']
# ['요즘엔 투뿔보다윗단계도있음ㅋ']
# ['우와']
# ['그렇다고굶으면안된다?']
# ['이번에 못빼면 평생 못뺀다고해서 뺐는데....잠깐이였습니다 ㅋㅋㅋㅋㅋ']
# ['본식사진도 팔뚝보정 해주시던데요? 만족😊👍🏻']
# ['저도 결국 못빼고 팔뚝 가려주는 드레스로 골랐는데 본식 사진들이 다 잘나왔어요!ㅎㅎ 촬영기사님 최고!']
# ['그게 더 나빠']
# ['근데 대장내시경 ㅇㄱㄹㅇ']
# ['작가님은 찰지게 맞았다고 한다']
# ['고3 때 찐 살이 58에서 정체되어 있었는데 코로나 때 47까지 뺐어요 반년 정도 걸렸고 47~49 왔다갔다하며 유지중이에요 ', '결론: 술 안 먹고 야식 안 먹고 홈트하며 집밥만 먹으니 빠지더라...']
# ['85키로 여자였다가 67키로 여자됬는데요. 계단오르는거 좋아하고 야채 좋아하고 계란 매일 먹고 탄수화물 안먹었더니 67키로로 아무도 안보고 근육량이 남자랑 비슷해요... 야채맛을 몸에서 알면 그거 못끊어요... 장이 너무 편해...']
# ['같이 가주는 스윗한 냥군..']
# ['오븐구이는 그나마 괜찮아요사실 치킨 3~4조각 괜찮아요  근데 우리 그럴거 아니잖아요  치킨실컷 콜라맥주도 맘껏 먹고 싶은거잖아요 ㅠㅠ']
# ['얼굴은 모자이크 하더라도 드레스 입은 사진은 궁금하네요. 얼마나 잘 어울렸으면.^^']
# ['가슴에 손을 얻고 곰곰히 생각해봅시다. 내가 뭘 물처럼 먹었는가?']
# ['고2때 좋아하는애 생겨서 1년간 42까지 18키로를 뺐죠..']
# ['아니 제발 님들아 특정 부위만 살을 빼는 운동이나 방법은 없어요.... 그냥 다이어트입니다. 제발 비과학적인 운동정보에 더이상 속지 마세요.']
# ['군제대후 사제음식에 취해서2달만에 23키로를 찌우는 전설을 만들고', '혈압과 간수치가 20대인 몸에서', '50대까지 나오는 기염을 토하며', '눈물의 다이어트를 결심', '첫째로 라면을 6개월 끊으며 ', '예전의 몸무개로 돌아가는데 1년이 걸렸다는', '전설을 간직하고있습니다ㅋㅋ']
# ['지방이 같아요 ㅋㅋㅋ']
# ['표정 넘 웃겨 ㅋㅋㅋㅋ 누운 것도 ㅋㅋㅋㅋㅋ']
# ['클룹 청사과 떫은맛안나고 개꿀임']
# ['예전에 투잡뛸때 평일에 14시간 일하고 하루 두끼 먹으니까10키로 빠지더라구요']
# ['그래서 담배끊은 사람하고 다이어트 성공한 사람하고는 상종하지말란 말도 있잖아요~ 독해서...']
# ['뭔가 지금 달면 베댓 될거같은데 뭐 써야되지?']
# ['내시경약 꼭 알약으로 드세요!!!가루약 물타먹는거 느낌이 포카리에 콤부차타서 소금 넣었는데 농도는 가래느낌임', '근데 아침내시경이면 새벽에 비몽사몽으로 그걸 또 먹어야됨 ', '살은 4키로 빠지던데 끝나고 밥먹으니까 2키로찜']
# ['여자들이란.. ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 플래너 기여워ㅜ']
# ['맞아요!!!! 포토샵 사랑해요!!!!!']
# ['체중계에 우와 써져 있는 거 귀엽다 ㅋㅋㅋㅋㅋ']
# ['탄수화물 반으로 줄이는 대신 그 자리를 >>양념되지 않은<< 단백질로 채우세요 .. 먹는 양은 같지만 살이 빠지고 근육은 붙고 포만감도 있는 방법입니다 ']
# ['결혼 생활하시면 맞는 말만 하시다가 맞는 수가 생길 수 있으니 빠른 눈치와 센스 스킬을 얻어 평안한 결혼 생활이 되시길 바랄께여 헷~']
# ['최고의 다이어트는.. 슬픔 다이어트입니다.. 감정에 지배되면 2주만에 5키로가 빠져요..']
# ['평생 고도비만이었는데 아프자마자 40kg 뺐습니다...^^* 모두 할 수 있어요... 우리 다같이 건강해져요... 저는 제 쇄골을 처음 봤거든요....']
# ['ㅇ우리에겐 좋은 지방 분해주사라는게 있는걸요... 팔뚝살만 좀다듬어 줍니다']
# ['너 T발 C야..?!']
# ['아 킹받아 ㅋㅋㅋㅋㅋㅋㅋ 진짜 동갑내기 모먼트']
# ['체질적으로 살이 안쪘었는데........결혼하고 아이 둘 낳고 나니 찌더라 나이 드니 또 나이살도 오더라 팔뚝 배애 붙은 살 보면 스트레스인데 그렇게 또 운동은 작심삼일이네,.......']
# ['저희남편도 식전에 살빼서 맞춰둔 예복 줄였는데 결혼식끝나자마자 다시 쪄서 못입고있어요^^... 결국 경조사용 하나 더 삿숩니다']
# ['팔뚝살 빼고 싶으신 분들!!팔뚝살 운동말고 차라리 허벅지쓰는 운동을 하되, 한세트당 15회이상으로 잡아서 근력+유산소를 병행하는 느낌으로 운동하는게 낫다고 생각해요. 다리근육쓰는게 칼로리 소모할 때 제일 좋아요. 팔뚝쓰는 운동한다고 팔뚝살이 빠질거였으면, 평소 40키로라는 몸무게를 지탱하며 항시 운동하고있는 우리들 다리는 군살 하나 없는 학다리였어야해요...', '.', '팔뚝살 운동하면 근육이 잡아준다는 분도 계신데, 그렇게 근육 생기기 정말 쉽지 않으실거에요. 근육은 정말 열과 성을 다하고 최선을 다해 무게를 쳐야 겨우 붙어요..ㅠㅠ 저는 여자라 그런지 외관상으로 조금 티날 만큼 근육 키우는게 너무 힘들더라구요']
# ['본식사진은 어차피 안보는거지만 친구들이 찍어주는 폰카에 뽀샵이 안된다는게 제일 큰 부분임...결혼축하한다고 사진 막 보내주는데 그때 충격 받고 싶지 않으면 살빼야해여ㅠ']
# ['ㄹㅇ ㅋㅋ(2년째 다이어트 성공 못함)']
# ['진짜 시험기간만 되면 5,6키로는 찌는것같음..또 끝나면 빼고..반복']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아이곸ㅋㅋㅋㅋㅋ']
# ['와미친']
# ['선생은 앞으로..아 ..아닙니다']
# ['그림이라닠ㅋㅋㅋㅋㅋ 상상도 못했닼ㅋㅋㅋㅋㅋㅋ']
# ['근데 다이어트 성공하면 진짜 앞으로 어떤 고난이 와도 다 이겨낼거 같음', '다이어트가 최고 고난임...']
# ['전 본식 앞두고 2달 반만에 11kg 감량 성공.... 본식 끝나고 다시 돌아온게 함정ㅋ;']
# ['김지은 다이어트 와드']
# ['와 할미개가 보여 ㅠㅠ']
# ['한우 투플이야? ㅋㅋㅋㅋㅋㅋ']
# ['뻘하게 드는 생각인데 배경 그라이데이션 색깔 이쁘네요 자까님']
# ['제 와이프는 결혼식 전에 입덧으로 20kg을 넘게 빼던걸요. ']
# ['안경은 가운데 손가락으로 올려야죠']
# ['사진이었어ㅋㅋ']
# ['다이어트에 성공해도 유지가 생각보다 힘듭니다... 15키로를 두번이나 뺐는데 .. 유지 실패...휴..']
# ['12살인데,,운동을 넘 좋아하구 먹는걸 좋아하지 않아서', '1월엔 163cm)55kg였는데,,', '지금(8월)엔 169cm)46kg에요,,', '솔직히 3학년때부터 스트레스덕분에(?)', '조금 통통 했엇는데 건강검진하니까', '그래프에 정상보다 쭈우우욱 올라가 있더라구요..', '이름 예쁘다구 칭찬을 들엇었는데', '지금은 키크다고 칭찬을 받네요오♥']
# ['ㅋㅋ 제 생각 나네요~ 저희는 결혼식 날짜를 잡고 더 신나게 부어라 마셔라 했어요... 심지어 다이어트를 하겠다는 저에게 맛있는 음식(이지만 술안주)들을 들이밀며 유혹(?)하는 바람에, 인생 최대의 몸무게를 찍고 드레스를 입었답니다...하.하.하...독하지 않으면 절대 할 수 없어요...😭']
# ['지금 13살인데 2달정도만에 20kg뺐어요! 하루종일 운동하면서 아침이랑 점심으로 사과하나, 우유만 먹었더니 빠지더라고요 ㅋㅋ😎😎좋아하는 배구를 하면서 하니까 생각보다 할만했어요! 전에는 156에 63kg이였는데 지금은 162에 42kg!']
# ['바베큐치킨 먹으면 그나마 괜찮']
# ['팔뚝살 ㅇㄷ']
# ['구운치킨ㄱㄱ']
# ['스윽 중지승천']
# ['임신']
# ['아~~그 내 모든걸 다 빼낸다는 그거요~~~^^']
# ['와! 코가 대단한 얼굴!']
# ['기초대사량 차이 때문에 남녀가 똑같이 먹으면 여자가 살찝니다 ^^']
# ['많이먹어서 살이찌는게 아닙니다. 쉬지않고 먹어서 살이 찌는겁니다.']
# ['자까님 총몇명 닮았어욬ㅋㅋㅋㅋ']
# ['아 새로운 다이어트짤이다']
# ['30대 되니까 더 빼기 힘들고 더 안빠지더라고요.... 꾸준히 관리하던 사람들 아니면 진짜 나잇살이라는거 무시못함..ㅠ']
# ['스포하셧어...']
# ['t맞네ㅋㅋ']
# ['냥군...의 어쩌면 큰 그림이었을지도']
# ['먼가 너 t야 다음말이 생략된거 같은데 ㅋㅋㅋ']
# ['연애하면 호르몬 작용으로 살빠짐']
# ['결혼식장에서 수근수근 이수근 듣기 싫으시다면 운동.. 해야겠지?']
# ['근데 꼭 공감을 해야함?? 인생 참 피곤하게 사네들 -지나가는 t가-']
# ['아니 형수님 ~ 팔뚝살만 빼는 방법은 없어요옹!!']
# ['패폭']
# ['난 아껴뒀던 아래쪽 사랑니를 양쪽으로 뺐지2주동안 간신히 죽만먹으며 4kg가 빠졌던가.. 왠지 억울한데 8kg였나..? 어쨌건 숨겨졌던 턱선 부활']
# ['나다... 첫날 무리하고 이후에 안 간다...']
# ['시험을 앞둔 우리의 모습.jpg']
# ['마감 안 한 지금의 나다...']
# ['나도 라면 뽀사먹을까근데 집에 신라면 밖에 없는데 신라면도 뽀사먹음 맛있음?? 안성탕면으로만 먹어봤엉']
# ['맘고생하니까 절로 쑥쑥 빠져서 결혼당일 성인된후 최저 몸무게 찍... 하지만 결혼후 다시 +a 됨ㅋㅋㅋㅋㅋ 애낳고 +aaaaa됨... ㅠㅠ']
# ['포토샵이 해줘요 ㅋㅋㅋ']
# ['진짜.. 다여트 그거 어케 하는건데.. 판타지 아니냐며..']
# ['왜 계속 우린만 안보여줘요']
# ['왜 저 안경을 올리는 장면을 보면 가운데 손가락으로 잡는 장면만 연상이 되는걸까...']
# ['웬 조랭이 떡이']
# ['웬 감자 한 개가 있지']
# ['실제로 대장내시경으로 8kg뺀 사람 여깃습니더괜히 문제 생길끼봐 밥도 잘 안드가더라구요', '그렇게 한 3달까진 유지했습니다만 술을 먹는 순간부터....쪄서 5kg 찐....', '그래도 원래보다 3kg 뺏으니 만족하고 있습니다']
# ['너T발C야?']
# ['자까님 저는 인생 최고 몸무게로 식 올렸어욬ㅋㅋㅋㅋ 저 같은 사람도 있답니다 호호']
# ['뜬금 없지만 승마요. 일주일 두 번 2시간 씩만 했는데 1달에 10키로 빠졌어요. ', '다리 근육이랑 체력이 없어서 몇 번 땅으로 처박힘 -> 살려고 운동함.', '하고 나면 온몸에 진이 빠짐 -> 안 먹고 잠. 입맛이 없어짐.', '물론 1년 하다 팔 부러져서 때려치우긴 했는데^^ 했던 운동', '중에 살 빼고 운동되는 데는 최에에고 였어요....', '']
# ['진짜 T 그잡채 ㅋㅋㅋㅋㅋㅋㅋ']
# ['다이어트는 장기프로젝트에요 ㅜㅜ']
# ['역시 단기간은 힘들어요 서서히 하는 수 밖에요']
# ['부부 사이에도 질량 보존 법칙이 적용되나 보네요!']
# ['전 결혼식자체가 스트레스였어서 스트레스땜에 저절로 다요트됐는데 그때보다는 살이 있어도 자세가 더 바른 지금이 몸이 더 예뻐보여요!! 자세 꼿꼿 중요!!']
# ['그치 아는것과 하는것은 다르지']
# ['소식(다양한음식을 적게..균형잡힌 음식을 적게..)과 걷기운동이나 과하지 않은 아무 운동..', '빨리 빠지진 않지만 빠져요... ', '길게보고 건강하게 다이어트 해요~~']
# ['저는20키로 빠졌어요!']
# ['자까님이 살이 찐 이유는 냥군과 같은 양을 먹고 (똑같이 먹고) 움직이지 않았기 때문입니다.']
# ['와 남편말투 가부장적이네 이혼감이다']
# ['금연 다이어트 공부 꾸준히 오래 해야해서 힘든 3가지 ']
# ['쿠...쿠팡?']
# ['쉬워요. 먹는걸 줄이세요 ;)']
# ['인정']
# ['두달반동안 30키로 빼고 바로 40키로를 얻어버린 나자신..']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['저는 아무리 먹어도 살이 안찌는 채질이라 ㅎㅎ']
# ['좋아하는 운동을 만들면 잘 빠지더라']
# ['아 ㅋㅋㅋㅋㅋㅋㅋㅋ 뚜까 맞았네']
# ['87에서. 76까지 감량해ㅛ어요..한달남아서 7키로 빼는중이예요 ㅠㅠ']
# ['맞아요 저도 다이어트가 젤 걱정이었어요!! 전 먹고싶은 거 다 먹으면서 빼는 다이어트중이라 넘 좋아요❤️ 매일매일 모 먹을지 고민하는 게 일이네여 ㅎㅎㅎㅎ']
# ['아 앞자리가 줄었다 늘어났나봐']
# ['아 ㅆ 대장내시경 진짜 상상도 못했다 ㅋㅋㄹㅋㅋㄱㅋㅊㅋㅎㅋㅍㅋㅊㅋ']
# ['최고급 한우거 따로 없네 ㅎ']
# ['우와 개웃기네 ㅋㅋㅋㅋㅋ']
# ['아씽ㅋㅋㅋ나랑 남편이랑 똑같아욬ㅋㅋㅋㅋ짜증나 지만 빼!!!']
# ['잼버리가서 4키로 빠졌어요']
# ['제 아내는 할 수 있다고 외치더니 금방 포기하고 포샵 잘 해주실 거라고 하더라고요ㅋㅋ']
# ['아무리그래도 결혼 전 관리 안한건 최악이네.']
# ['벌크업이다']
# ['한달에 10키로 빼려면 간헐적 단식이 베스트죠']
# ['체중계 무게나오는 부분에 우와 적혀있는거 너무 웃겨욬ㅋㅋㅋㅋㅋ 센스']
# ['11년전 재수 끝내고 1년동안 110에서근 50키로 뺐엇는데 지금 다시 100키로 가까이됨.. 역시 다이어트는 끝이없다 ㅋㅋㅋ... 근데 이젠 청춘도 다 가고 그때만큼 뺄 의욕도 별로 안 들어서 더 문제 ㅋㅋㅋㅋ ㅠㅠ']
# ['가슴살 튀김만 도려내고 먹으면 단백질']
# ['조심해야해..늙어보일수도...']
# ['그러다맞아요...ㅋㅋㅋㅋ']
# ['근데 그 방법만 빼고 다 함 ㅋㅋㅋ']
# ['근데 그 방법만 빼고 다 함 ㅋㅋㅋ']
# ['돈을 많이 내고 PT를 하면 됩니다..힘든데 안할수가없음..아까우니까']
# ['80인거보고 충격먹고 러닝이랑 자전거만 미치도록 했었는데 식단은 평범한 가정식으로 먹고 하다보니까 57찍음ㅋㅋㅋㅋㅋ문제는 계속 운동을 하다보니까 어느샌가 운동을 안하면 내 몸이 불안해하는 운동중독 지경까지 왔음ㅋㅋㅋㅋㅋㅋ']
# ['두달만에 5키로 감량 ..탄수화붛 x 하루 10키로 걷고 막판에 줗넘기 2000개 ㅋㅋㅋ']
# ['유잼']
# ['온갖 음해를 당했습니다. 여러분 이거 다 거짓말인거 아시죠?']
# ['ㅋㅋㅋㅋㅋ 훅들어오네']
# ['저도 날짜받고 드레스 다 골라놓고 예식당일날 살쪄서 다른드레스입고 결혼식 치뤘어요. 나는 결혼을 일찍한편이라 살도 안먹으면 빠지고 먹으면찌고 했는데 지금은 에효ㅜ 지금은 수영으로 건강챙기면서 운동해요. 수영은 초보들은 바로 살빠져요']
# ['왜 이렇게 수박 같으시지']
# ['결혼준비를 한 1년쫌 넘게 했는데 짝꿍이랑 연애하면서 너무 먹고다녀서 인생 최고몸무게 찍엇다가 촬영전에 빼야지 그리고 드투할때 입고싶은 드레스 입어야지 하면서 15키로 정도뺐었어요(3년이 넘은 지금은 다시올랐습니다..\U0001f972) 운동은 뭐 제대로 해본적없는 초보라 먹는양 줄이면서 땅끄부부님 유투브로 다이어트 성공했었어요 독하게 마음먹으면 되긴되더라구요 이제는 임신을 위해 다이어트중인데 나이먹으니 잘안빠지네요😫 다이어트 하시는분들 모두 화이팅입니다!!']
# ['너무해요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ ㅠㅠ']
# ['난 원래 살이 별로 안찌는데?']
# ['ㄱ네치킨: 아아 이리로 오라....! 여기에 빛과 고기가 있노라...!!']
# ['헬스장 다닌지 5개월차 헬린이... 주3회 상체 하체 상하체 루틴 돌리고 유산소 20분씩하니 체지방률 쭉쭉쭉 빠졌어요! 다른건 모르겠지만 일상생활 하는데에 활력이 돌더라구요 운동 추천추천!']
# ['아낰ㅋㅋㅋㅋㅋㅋ같은 T가 봐도 극T야ㅋㅋㅋㅋㅋㅋ']
# ['자까병.. 직업병...']
# ['포샵 심해서 웃음벨인 경우 많음 ㅋㅋ']
# ['결혼식 준비 중에 다이어트 따윈 1도 생각 안 한 신부 여기 있어요~ 그냥 있어도 살이 빠지던데요-']
# ['저랑 남편의 모습이네요..😇ㅋㅋㅋ 남편은 다이어트 열심히 하고 전 거의 포기했었는데😂ㅋㅋㅋㅋ']
# ['근데 저는.. 본식사진은 포샵 안해줬더라구여…\U0001fae0\U0001fae0\U0001fae0\U0001fae0\U0001fae0\U0001fae0\U0001fae0\U0001fae0\U0001fae0\U0001fae0']
# ['두번 바꾸는 거면 676이렇게 바꿀수도 있는거 아니야 그럼']
# ['단기간 다이어트는 크로스핏이 직빵이더랍니다']
# ['남자 잘만났네 살뺄수있는사람은 뭘해도 잘할거같다담배도 술도 필요하면 끊겠지~', '살못빼는사람은..  뭐 뻔하지..']
# ['공감추 진짜']
# ['했다가 요요와소 94->57->80 ...^^']
# ['키 181에 96키로에서 71키로까지 뺐습니다.1. 주 3회 50분 러닝머신(화목토)', '2. 주 3회 스피닝 50분(월수금)', '3. 주 3회 pt(월수금)', '4. 주 3회 개인 근력운동(화목토)', '5. 식단: 하루 1500kcal 미만 섭취 및 저탄고지', '6. 일요일 하루 치팅데이', '', '이렇게 7개월해서 25키로 감량했고 8개월째 몸무게 유지 중입니다. 말이 쉽지 지금 생각해보면 힘든 순간이 많았고 정체기도 2번 찾아왔었는데(89에서 한번, 82에서 두번) 지금 제 몸을 보면 뿌듯해서라도 꾸준하게 운동하며 유지하고 있습니다. 결코 쉽진 않지만 살이 빠지고 변하는 나를 보는게 정말 뿌듯하다고 말씀드리고 싶어요. 다이어트 하시는 분들 모두 화이팅!']
# ['intj?']
# ['81k에서 69kg 된듯 ㅋㅋ']
# ['네. 맞아요']
# ['귀에 에어팟ㅋㅋㅋㅋ']
# ['마! 날씬한 녀석이 욕심도 많다이~~! ㅋㅋㅋㅋ']
# ['136키로에서 103까지 뺀 사람입니다 물론 지금도 정상체중은 절대 아니지만 여러분들도 할수 있습니다 저도 했잖아요?']
# ['90kg대 에서 70kg대로 갔을듯']
# ['전혀 울컥해보이지 않는다']
# ['이래서 당근마켓 같은 데에 헬스장 등록권이 많구나']
# ['저도 이제 본식이 한달남아서 다이어트 중인데 진짜 다이어트 진짜 어려워요ㅠㅠㅠㅠ 왜 안빠지냐고 ㅠㅠㅠㅠㅠㅠ']
# ['진짜 100kg 넘었던 건 아니겠지..?']
# ['T인데 못빼는데요']
# ['😛😛😛']
# ['치킨은 살 안쪄요 살은 내가 쪄요']
# ['몽골여행...ㅎㅎㅎ ']
# ['벌크업 하시는 분들도 대단..']
# ['다이어트에는 장염이죠 ㅋ']
# ['작가님..결혼하시는구나..!']
# ['뭐야 지금의 난디']
# ['우와 ㅋㅋㅋㅋㅋ']
# ['저도 다이어트 오로지 유산소 운동만으로 18키로 뺐습니다.']
# ['저는 먹고싶은거 먹고 결혼식 2일 전까지 크로스핏했어요.. 그래도 가봉한 드레스를 입고 앉으면 숨이 안쉬어져서 사이즈를 약간 늘렸어요..']
# ['100에서 80이 됐나']
# ['그냥 하루 두끼 식사 제때제때하고 간식 안 먹고하루에 5세트 나눠서 버피 50개 줄넘기 1000개씩만 해도 빠지던데', '살 빼니 마니 물어보는건 이유가 뭐임']
# ['단백질과 야채위주 식단. 밥은 현미밥 반공기 or 단호박 반개 물론 라면햄버거치킨피자술음료수 금지. 가끔 치팅데이로 마라탕. 당면빼고 야채랑 고기로. 물론 밥,국물X 어묵이나 크래미도 탄수화물이라 안됨. 햄도 안됨. 매일 근력운동 1시간+유산소 최소 20분', '2달에 지방만 8키로 뺐어요. 나름 할만해요! ']
# ['운동을 하지 않은 과태료라고 치자']
# ['제 결혼식 한달전 모습 그리신것같은데요 ..결국 실패했습니다 !(당당)']
# ['체중계에 와우 ㅋㅋㅋㅋ']
# ['우와']
# ['T발 C야?']
# ['ㅋㅋㅋㅋ 저도 결혼식이 다가오고있는데 이러는중이네요']
# ['하루 15분 달리기.하루 2000칼로리 이하로 먹기', '근력운동 30분.', '이걸로 2달해서 13키로 빠졌습니다']
# ['저는 결혼하기 2년전부터 치아교정을 해서 팔뚝 포토샵 안하고 결혼사진 찍었습니다 하하하 장기프로젝트']
# ['다른 사람이 찍은 내 본식 사진에서의 내가 뚱땡이면 싫을 듯😂']
# ['팔뚝살 빼는 운동이 좀 웃김 그럼 그거하면 나머진 다 뚱뚱한데 팔뚝만 빠지나?']
# ['아는 사람은 알겠지만...진짜 작정하고 먹는 거 기록하면 알게 됩니다.', '우리 정말 많이 먹습니다 ㅋㅋㅋ']
# ['성시경?']
# ['살뺄때는 운동이 두번째로 중요하고 첫번째는 식단조절인듯ㅎㅎ']
# ['여러분 크로스핏 하고 저녁만 안먹고 4일만 해도 1.5키로 빠져용 해봐서 압니닷!']
# ['구운치킨 드셔야죠']
# ['미친듯이 안 먹어서 3달만에 -35kg 뺐었었네요ᆢ']
# ['나 전에 무슨 깊티 있어서 난생처음 제로콜라 마셔봤는데 마시는 순간은 ㄱㅊ은데 입에서 없어지는 순간 맛이 너무 이상해서 토하고 싶었음 입에 찝찝하게 남는 듯한 느낌…원래 탄산음료 잘 안 마시고 마셔도 콜라 말고 사이다를 마셔서 그럴수도… 아 근데 제로콜라 너무 역겨웠음 아까워서 좀 더 마셨지만 반절도 못 먹고 버림 ㅜㅜ 차라리 그냥 콜라가 이상하게 입에 안 남는 거 같음']
# ['다이어트하는 방법 이론상으론 어떠한 의사 박사보다 빠삭하다구 실행히 힘들뿐이라구 ㅠㅠ']
# ['본식은 포샵 없는 라이브...']
# ['29년못뺀살 첫째임신때 입덧 30주하고 처음 중딩때몸무게찍고는 계속 못먹어서 52개월째 유지중입니다... 못먹는게 제일 살빠짐.... 물논 근육만빠짐 ㅠㅠ']
# ['단기간에 부분적으로 지방을 빼고 싶다면 사실 시술이 직빵이긴해요 지방추출하는거 해봤는데 꽤나 드라마틱하게 빠져요 물론 한달정도는 멍에 붓기에 힘들긴한데그래도 어지간한 지방분해주사보단 확실해요 ', '저는 복부했는데 갠적으루 팔뚝이 더 사람이 날씬해보일듯 ']
# ['결혼식 4개월앞두고 급 다이어트했어요..단백질? 계란만먹었고 탄수화물아예안먹었습니다...방울토마토..샐러리..당근..오이..비트..콜라비만 먹엇어요...음료수? 술? 절대입에도대지않았고 물이랑아아만 마셨어요ㅋㅋ 사람이 굉장히 예민해집니다..그리고 눈밑이막떨리고 좀만움직여도 식은땀이나요ㅋㅋㅋㅋㅋ4개월동안 밥,면,술,고기,음료,간식 전부끊고 총 16키로뺏어욬ㅋㅋㅋㅋㅋㅋㅋㅋ하지만 결혼식끝과함께 다이어트도끝~~~현재 앞자리6입니다ㅋㅋㅋㅋㅋㅋㅋ킼킼...']
# ['진짜야,,,  정신차리면 입장하고있어요🤣']
# ['살찐게 더 귀여워서?']
# ['저맘때 저도 58에서 52키로까지 줄여서 결혼했었네여 지금은 못할듯 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋ 저도 드레스는 너무 이쁜데 팔뚝밖에안보였엇는데 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 공감ㅋㅋㅋㅋㅋ']
# ['ㅋㅋㅋ2달남았는데, 피부과가서 팔뚝지방환생패키지 등록하고왔어요. 지금 2주차인데 조금 변화가보여요 ㅋㅋ']
# ['입이 코보다 앞으로 튀어나온거봐 ㅋㅋ']
# ['네 여기 시간과 돈과 건강을 쏟아부어 다이어트하다가 대상포진와서 입원한 신부입니다!결혼 끝나고 다 요요왔어요~~~ 지금은 임신 12주차라 걍 개깁니다ㅋㅋㅋ 다이어트 먹는건가']
# ['지방흡입?']
# ['몸이 안따라줌.이해.']
# ['평생 다이어트 안 해보고 산 나는 축복받은 체질인덧ㅋ 근데 남들보다 입짧고 식욕이 별로 없어서 그런듯 간식 안먹고']
# ['매우 신선한 제품이네요^^']
# ['저도 결혼식 두달앞두고 다이어트해서 11키로 빼고 식 올라갔는데 결혼하고 몇달지나니까 식욕과 뱃살이 올라오더라구요..ㅡ']
# ['체중 포동의 법칙']
# ['.']
# ['전 다이어트 실패해서 인생 최대 몸무게로 결혼식 했는데 ㅎㅎㅎ 그리고 그게 최대 몸무게일 줄 알았어요ㅠㅠ']
# ['방문고리를 밖에서 열고 잠구게끔 바꾸고 배식을 넣어주면 살이빠짐']
# ['안돼....나중에 예복 늘려야돼.... 너무 빼지마']
# ['제 신랑이랑 똑같네욬ㅋㅋ 밥을 코딱지만큼 먹고 살빠져서 결혼했어요. 결혼식 당일날 신랑 왜케 살빠졌냐며 다들 놀람....(정작 저는 신랑이 남긴 밥까지 먹음)']
# ['원래 결혼식 한달전, 이주전부터가 젤 많이빠져여. 발등에 불떨어졌거든']
# ['그게 나쁜거임']
# ['오늘로 결혼이 딱 한달 남았고 4일뒤 드레스피팅입니다ㅠㅠ 열심히 16대8 간혈적 단식에 아침은 무조건 그릭요거트에 과일로 점심만 일반식 하고 저녁은 굶어서 한달에 지금 4-5킬로 뺏어요 ㅠ 빼서 과체중 되었지만 아직도 갈 길은 먼데 날짜가 다가온다!!! ㅠ 결혼식 무서워영']
# ['포토 ㅋㅋㅋㅋㅋㅋ']
# ['양념 껍질 벗기면요 ']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['걷지말고 달이라고 ㅋㅋㅋㅋ']
# ['ㅋㅋㅋㅋ. 왜 당연한데 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['오 맞는말 이네']
# ['맞는말이 처맞는말이 될수도 있어요 조심하세요 ㅋㅋ']
# ['오히려 일반탄산보다 제로음료가 더 살찐다는 연구결과도 있던데']
# ['F는 많이먹고를 처먹고로 듣는다 메모.']
# ['대장내시경ㅋㅋㅋㅋㅋㅋ작가님 작품 항상 진지하게 보는데 이컷은 좀 웃고갈게요 죄송합니닼ㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['검 ']
# ['두번이요 ???  최소 11에서 최대 20까지 뺀거라고 ???']
# ['전컷 : 역시작가님.!!이번컷 : 사스가.작가 사마...', '', 'ㅋㅋㅋㅋ']
# ['몸무게가 1등급에 투 뿔이라니.. 소띠세요?']
# ['웨딩 촬영때도, 결혼식 때도 다이어트 안했는데 임신하고 강제 다이어트 중입니다 ㅋㅋㅋㅋㅋ 아기에게 안좋은걸 물려줄수 없다는 의지로 버티고잇어요ㅠㅋㅋ']
# ['헬스장 1년 36만원 할인! = 1회 36만원 겁나비쌈']
# ['본식날 다른사람이 찍은 내사진은 보정이안되거든요\U0001f972']
# ['어맛 이건 꼭 사야 돼 자세에서 그대로 경악하는 자세로 바뀐게 너무 웃겨 ㅋㅋㅋㅋ']
# ['팔뚝살은 3*5M*']
# ['팔뚝은 지흡이 최고......']
# ['저도 팔뚝 너무 신경쓰였는데 탑 드레스로 선택했어요. 애매하게 오간자 레이스나 볼레로 걸쳐서 팔뚝라인 숨기려고 애쓰는 것 보다 차라리 소매없이 시원하게 오픈하니까 오히려 팔뚝에 시선이 안가고 가늘어 보이더라구요.']
# ['대장내시경에서 박장대소ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['두자리 바꿀 정도면 살집있긴 하셨나바여']
# ['너C야? T발']
# ['65로 시작해서 46까지 1년 반 걸렸어요!! 열심히 한 나자신 칭찬해!!👏👏']
# ['체중 보존의 법칙ㅋㅋㅋ']
# ['지금대장내시경하려고 대기하고있어요... 그리고 인바디제고 충격먹어서 이참에 다이어트나 하려구요ㅠㅠ']
# ['매 달리기']
# ['한번 빼고나면 잘 안쪄서 오히려 편해요앞자리 바뀌고서 오히려  다시 안찌더라고요']
# ['흐어...웨딩촬영 2달 남겨놓고 다이어트 안되서 고생중인데....흐엉ㅠㅠㅠ 여러분 저 살 어케 빼여ㅠㅠ 진짜 쫄쫄 굶어야댈까요ㅠㅠㅠ']
# ['ㅋㅋㅋ저희 언니도 최근에 결혼했는데 올 1월부터 9개월동안 20키로 감량...ㄹㅇ 사람이 달라보임']
# ['아침 케일 오이 사과 등 갈아넣은 주스 혹은 사과1알 삶은계란2개 두유하나점심 닭가슴살 곤약볶음밥 + 닭가슴살 100g', '저녁 현미밥210g + 닭가슴살 100g + 각종 야채', '피티 20회', '4개월 뒤인 지금 약 7~8kg 빠졌습니다', '응원해주는 예신님 덕에 청첩장 모임 나가서 와랄ㄹ라 먹고 들어와도 유지 잘 하고 있습니다']
# ['근데 사진이랑 실물이 너무 다르면 너무 멋이 없긴해요']
# ['ㅋㅋㅋ 그렇게 들렸을 뿐']
# ['다이어트 결혼 드레스']
# ['본식 때는 하객들의 핸드폰에 자비 없이 찍힌다는 생각으로 다이어트를 했었더랬죠....']
# ['팔뚝은 람스하세요.. 무조건 본식 3달전에 팔뚝람스하세요아님 다른건 다 답없어요']
# ['29살 결혼식전..3개월정도 퇴근후 조깅하고 술만 좀 줄였는데 살이 쑥 쑥 빠져서 5키로 뺐지요. ..결혼후 출산하고 수유하면서 또 살이 왕창 빠졌고 그후 몸무게는 빠지는일이 도통 없더니 죽어라 애를 써도 안빠지더니 40대 중반,진짜 죽도록 운동을 해도 살이안빠지더니 작년에 피부병으로 채식위주 식단에 술을 끊었더니 15키로가 빠짐.  세상에...술이 범인이었다.']
# ['아기 낳고도 또 빼야 합니다 ㅠㅠ']
# ['맥주 거하게 마시고 안주는 멸치에 김만 먹으면 난 야위어있던데맥주 마실땐 배불러서 저런거아님 안주 못먹겠던데 치맥이 더 대단함', ' 치킨도 배부른데 맥주가 어디로 들어가는겨..']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['전 코로나 걸려서 앞자리가 바꼈습니다... 죽음의 코로나 다이어트.... 정작 결혼식땐 다이어트도 안했어요...']
# ['물만 먹어도 살이 찐다면무엇을 물처럼 먹었는지 생각해보자']
# ['결혼하기 전에 엄청 뺐는데 결혼하고 나서 10키로 이상 찐 사람 나,,,']
# ['본래 체중이 어떻게 되셨던 거에요']
# ['얼마전에 전설의 결혼식 포토샵 사진 굴러댕기던데']
# ['하트를 누를수 밖에 없었다']
# ['개아련 ㅋㅋㅋ']
# ['저도 지금 결혼 1년전이라 다이어트하고있는데..3개월간 7키로 빼고 약간 헤이해졌어요 ㅠㅠ 앞으로 15키로는 빼야하는데 ㅋㅋㅋㅋㅋ ㅠㅠ 1년이니까 천천히 빼려구요헤이해질때매다 와서 댓글볼거야🔥🔥']
# ['독립 일기 때 잠깐 PT 다니시지 않으셨어요?']
# ['작가님 임신 축하드려요^^']
# ['제로 콜라에 들어있는 단맛은 설탕이 아니고 단맛과 쓴맛이 있는 화악적 물질. 검정고무신에서 나온 사카린 같은 겁니다. 이 화악물질은 영양가도 없고 칼로리가 없지만 그래도 과하게 섭취를 하면 당뇨가 오죠ㅎ( 근데 펩시 제로는 ㄹㅇ JMT )']
# ['체중계에 우와 적힌거 뭐얔ㅋㅋㅋㅋ']
# ['전 살빼니까 임신성공했어요ㅋㅋ 보는사람들마다 살이웰케 빠졌냐며....그전에 엄청 도ㅐ지였었나봐요']
# ['친구가 VR기기 사고 살을 엄청뺏는데 조카가 부수고 나서 다시 푹 찜']
# ['굽네치킨오리지널-다이어트 국룰']
# ['아나 작가님 이런 그림체 처음봄ㅋㅋㅋㅋㅋ 개웃김ㅋㅋㅋㅋㅋㅋ']
# ['의사다운 답변 ㅋㅋㅋ😆😆😆']
# ['웊!  😏\U0001f92d\U0001f92d\U0001f92d\U0001f92d\U0001f92d\U0001f92d\U0001f92d\U0001f92d']
# ['깔깔깔 표정봐 대박 깔깔깔 깔깔깔 깔깔깔 깔깔깔']
# ['전 결혼식전날에도 소주를 갈겼어요 죤맛']
# ['와 나 세상에서 제일 대단한 사람됨']
# ['나태하게 살다가 건강 생각해야겠다고 다짐한 뒤,독기와 오기로 약 45kg 감량했습니다', '거의 사람 한명이 빠져나간 수준이라 저도 빼고나서 놀랐네요.', '최근엔 매일매일 헬스장 가는게 습관이 될 정도로 운동에 빠져 살고 있습니다.', '여러분도 운동에 재미 한 번 들리시면 빠져나오기 힘드실거에요. 화이팅입니다!']
# ['ㅋㅋㅋ 저도 이제 곧 웨딩촬영이라 공감되어 처음으로 댓 남겨봅니다 ㅠ 다이어트 저도 성공하고 싶어요(...) 는 이미 늦음포토샵 다이어트라도 잘 성공하길(?!)']
# ['.... 고딩... 통학러 12키로 뺐습니다... 학교가 겁나 산에다가 운동부 들어가서 ㅎㅎ 여러분 탁구 치세요 직빵입니다 ']
# ['맨날 살 쪘다고 스트레스 받아하면서 운동은 안하고 먹기만 하던 전여친이 생각나서 PTSD 온다...그럴거면 찡찡거리지나 말던가 다 큰 성인이 뭐하는건지']
# ['제목 보고 " 안 쪘는데 " 라고 생각한 순간 옆에있는 풍선자까님 썸네일']
# ['친구들만나서 청첩장주다보니 살이 찌더라구요ㅋㅋ 같이 먹고 마시고ㅋ']
# ['단백질이야 있죠. 하지만 지방이…']
# ['허허 전 근 1년간 10키로를 뺐답니다!여러분도 할 수 있어요! ', '']
# ['본식 한달 남은 예비신부.  다이어트가 얼마나 빡치냐면요, 예랑이랑 호수공원 걷다가 토스트 냄새에 울었어요.나도 저거 먹고싶다고ㅠㅠ예랑이가 놀라서 사줄까! 오늘은 먹을까!  하는데 아냐 먹으면 안돼ㅠㅠ근데 먹고싶어ㅠㅠ현재진행형입니다 흑흑']
# ['오 그치']
# ['난 7키로 빼고 식장 들어감 ㅋㅋㅋ 주위에서 포토샵으로 다 처리해주는데 왜그렇게 독하냐 하는데 하객들 눈을 포토샵할수는 없는거 아님?? ㅋㅋ그래서 독하게 뺐어요!! ㅋㅋ']
# ['헤헤 자까님 기ㅜ여워']
# ['포토샵 다 해줘요.... 단지.... 모든 하객들이 사진을 찍는다는게 문제죠^^ 심지어 버진로드가 위쪽에 있다보니 아래에서 위로 찍은 턱살 그득한 사진을 찍어서 인스타 박제나^^ 많이들 보내준답니다 하하']
# ['찝니다.. 쪄요..']
# ['2컷 웹툰 만화 ㅋㅋ']
# ['지나가는 T 입니다. 지나갑니다.']
# ['냥군의 남긴 음식을 대신 먹은 부모의 마음 ㅋㅋ']
# ['저도 다이어트 할땐 논알콜 맥주 쟁여놓습니다ㅋㅋ']
# ['저랑 남편 결혼할때 살 쫙~뺐었어요. 예복 당연히 줄이고 드레스도 살 너무 뺐다고 잔소리 들은;;; 결혼 7년차 남편은 현재까지 거의 유지중... 저는 신행다녀오자 마자 첫찌 생겨서 결혼식용 다이어트였습니다... 지금은 둘째 육아휴직중으로 무럭무럭 몸무게 갱신중ㅠㅠㅠㅠㅠㅠㅠ']
# ['저도 지금 저 상태로 있다가 벌써 본식 일주일 남았네요..']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋ부인한테 맞는 말!!!']
# ['치킨 겉에 붙은게 탄수화물... 전기구이 텅닭이면 인정해야하나?']
# ['탄산수도 좋아요!:)']
# ['겨터파크 오픈~']
# ['모 분이 웨딩 촬영한 곳에서 골반 풍성하게 만들어준다고 한 기억나네ㅋㅋㅋㅋㅋ']
# ['차라리 나쁜말 해ㅋㅋㅋㅋ']
# ['치아교정기 차니까 강제로 못먹어서 그런가 빠진다는..?ㅠㅠ']
# ['자까님도 앞자리 바뀌신 건....아..아닙니다..행복하세요~ㅋㅋ']
# ['큐티프리티']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋ정답']
# ['제로라도 탄산으ㅡㅁ료 살 많이 찌니깐 탄산수 드세요..']
# ['귀여웤ㅋㅋ']
# ['다이어트 잘 챙겨드세요....25kg 빠졌는데 저혈압 씨게 와서', '응급슬 함 갔다 왔습니다....ㅠ']
# ['말은 이렇게 해도 다 빼셨을거 알아요 ']
# ['결혼식의 장점. 이영자도 다이어트 한다']
# ['자까님, 치킨을 뭘로 튀겼죠?']
# ["'우리가 아는 보편적 지식으로 말하고 행할수있다면 우리는 모두 현자 일 것입니다'", '-작가 와 나와 우리가 사실은 사람이고 ', '-그들은 언제나 열심히 살앟습니다-', '', '에세이', "'작가는 평범 합니다'", ' 에서 발최', '', '']
# ['맞아요. 저도 최종 드레스 고르러 갔는데 새로운 디자인 보여주셔서 그걸로 골랐네요.']
# ['솔직히 제로먹을바엔 기본이 짱임 ']
# ['치킨은 지방 콜레스테롤입니다 여러분.']
# ['왜냐면 팔뚝 빼고는 다 보완이 가능해서요. 뽕을 넣거나 허리를 조이거나 다리를 가리고 굽을 높이는 등 화장도 하고 다른 부위는 다 괜찮은데 팔은 그게 안됍니다']
# ['다음컷 예상:3일만에 관뒀다.']
# ['별의 커비같아 ㅋㅋㅋㅋㅋㅋㅋ']
# ['본식 사진은 뽀샵 안해줍니다.앗 자까님 본인이 하시려나 ㅎ']
# ['요즘 주사 맞으면 진짜 금방 빠진다던데요!']
# ['ㅎㅎ 본식날 더이어트 안하고 결혼식 하는 사람도 많아요 ㅎㅎ 저도 그냥 입장 원래가 42kg ']
# ['생활패턴이 안좋아 져서 15kg 쪘다가 20kg 뺐습니다 하핫']
# ['회원님 이두랑 삼두조져보실까요?']
# ['걷기부터 부지런히 하다 달리기도 시작,  수영도 하고 그러면서 식단도 줄였는데 저도 작가님처럼 극단적인편이라 안하다가 할 땐 독하게 했거든요. 살 너무 심하게 빼서 -17kg 찍고 코로나 백신 3차까지 맞고 백혈병 걸려서 항암하며 - 10kg 더 떨어져서 피골이 상접을 경험하고 암투병 중에는 살이 안찌더라고요. 먹고 싶은 것도 음식도 잘 안넘어 갔지만 먹고저고 계속하니 확실히 살은 잘 찌더이다. 다시+15입니다 ㅠ']
# ['기름']
# ['그건 놓고 이야기해주실수 있나요?']
# ['이렇게 빼서 산 예복은 결혼식 이후로는 다신 입을 수 없었다는 제 남편 이야기 ㅋㅋㅋ ']
# ['이럴때는 포케가 짱이지!!!!']
# ['맞아 정확한 판단은 탄수화물에서 나온댔어']
# ['체중계에 우와라 써져있음ㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['나도 2달 만에 앞자리 두번 바꿈ㅋㅋ 걍 하루 닭가슴살 한번만 먹음 되던데?? 간식은 단백질바']
# ['냥군 직업이 궁금해요옹']
# ['낮선 그에게서 정겨운 T가 느껴진다']
# ['진짜 술과 액상과당 들어간 음료수 끊는게 다이어트 핵심입니다.이것만 지켜도 상당히 많이 빠지죠']
# ['저도 1년만에 8에서 6으로 앞자리 바꿨는데 결국 식습관 바꾸는게 답입니다.점심 마음것 먹고 저녁 6~7시 사이에 일찍 먹은 뒤 다음날 점심까지 간헐적단식.', '처음에 적응이 좀 힘들땐 9시쯤 견과류 20알 미만으로 진짜 야금야금 먹으면 좀 버틸만 하고 일주일 정도 지나면 적응되더군요.', '일주일에 한번은 그냥 마음것 먹었고(보통 술약속) 지금은 목표체중에 도달하고 삼시세끼 다먹어도 다시 찌지 않더군요.']
# ['푸바오 이기셨나요']
# ['처음에 100-90-80인거면 쉽다던데.. 그리고 원래 남자들은 날씬해야 정상이래요 근육량 등이 달라서.']
# ['근데 작가님 살 안찌셨을듯,,, 기만이야 ㅠㅠ']
# ['운동 같이 하시는 분들은 탄수화물도 충분히 챙겨먹어야 합니다~!! 운동하고 탄수화물 안먹으면 근육 쪽쪽 빠져요ㅎㅎ 라면 이런게 아니고 밥+닭가슴살 이런식으로 드세유']
# ['다이어트는 간단합니다.하루 천칼로리 이하로 먹고', '더 많이 움직이세요.', '탄산은 제로라도 안녕~']
# ['나도 앞자리 두번바뀜 8>7>8 남자']
# ['다이어트하려면 꼭 몸챙겨가며 하세요... 굶고 숫자에 집착하다 거식증 오고 인생 조진사람 여깄습니다']
# ['하체운동이 진짜 짜증나는게 운동을 한 날에는 안아픈데 그 다음날이 진짜 겁네 아픔 ']
# ['그 예복은 이제 계속 장롱 속에만...']
# ['난앞자리 4번바꿈 8-7-6-5']
# ['살면서 다이어트 한번도 성공 못하다가 결혼식 전에 처음보는 몸무게로 버진로드 입장 성공....그리고 신혼여행 6일만에 4키로 찌우고 나머지 6키로는 1년만에 다시 다 찌웠어요 ㅋㅋㅋㅋ모두가 신랑신부만 쳐다보는 결혼식 정도가 아닌 이상 그정도 의지가 다시 생길 일은 없을듯...']
# ['먹는 양 줄이면 식비도 줄이고 살도 빠지고 일석이조']
# ['전 살 빼겠다고 마음먹고 한 달만에 체중 앞자리 수 바꾸는 기염은 토했는데, 이 후 체질이 바꼈는가 먹어도 먹어도 되려 점점 살이 빠지더니 또 체중 앞자리 수 바뀌고 현장 압축 근육 뼈해골이 되어버렸습니다. 제가 여성이었다면 하늘의 축복이었겠지만 몸으로 먹고 사는 놈이라 이것도 나름 골때립니다ㅠ']
# ['마른남자 별로']
# ['zzzzzㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 말랑말랑']
# ['멋있다!!']
# ['간헐적 단식으로 9kg 빼긴 했는데,, 먹는 양이 너무 줄어서 억울해요.... 배부른데 더 먹으면 탈 남. 몸이 화내는 느낌.. 찔 수가 없는 몸이 됐습니다,,']
# ['3일 단식이요,, 3일 동안 3키로 빠짐.... 근데 보식 제대로 해야해요']
# ["운동이 필요할 정도로 심각한 '침대 중독증' 입니다"]
# ['아 냥군 귀여워']
# ['105에서 70까지 폭식-다이어트 반복으로 총 세번뺐습니다.다이어트로만 100키로를 넘게 감량해봤네요', '키가 커서 이 밑으로는 뺄생각없고, ', '한약+초절식(하루500칼로리이하),2.5개월', '초절식+운동,50일', '탄수,당줄이기외에 제한x+주2-3회 1시간운동 , 1년이상', '몸은 ㄱㅐ쓰레기가돼서 일반식이래봐야 남들만큼 먹지도못하고, 먹으면 찝니다.', '운동을 1년했지만 늘어진 살은 돌아오지않고, 동그랗게 늘어져있으며', '이전에 망가진 위는 여전히 경련이찾아옵니다', '저역시 숫자로 어필했지만, 다이어트는 숫자로 하지마세요', '목표를 크게잡지 마세요.. ', '평생 그렇게 살 자신 있는.. 그정도의 강도로만 하세요..', '초절식은 아무리 유지하는거같아도 다시찝니다.', '근육량 키운다 생각하고 다이어트하세요', '어차피 진짜 비만은 체지방은 무조건빠져요..오히려 보디빌더처럼 식단하고 운동해도 타고난거에 따라 근량이 같이 줄수도있습니다..', '~~했는데 안빠지신다는분들, 그냥 적정체중이신거예요.. 저는 다이어트를 후회합니다..']
# ['투쁠 자까']
# ['냥군님..대체 뭘 어떻게 하신겁니까']
# ['왜 벼락치기하는 내 모습이 보이지']
# ['진실의 미간']
# ['갈대 3명이 모이면 벌어지는 일']
# ['맞는 말이 아프다면 나쁜 말입니다']
# ['ㅋㅋㅋㅋㅋㅋ저도 그래서 먹는거 좀 바꾸고 줄이고 운동은 ..음..쬐끔..만했는데 다들 막 역대급으로 살빠지고 이뻐졌다고 ㅋㅋ 선의의거짓말인줄알았는데 요요로 살이 최고치를 찍은 지금에서야 진실인걸 알았습니다..하하 이제는 그정도로해선 안빠질거같은데 ㅠㅠ']
# ['동생은  청첩장 돌리면서 이사람 저사람 만나서 축하받으면서 오히려 찌더라구요 ㅋㅋㅋㅋ ']
# ['다이어트란.....미쳐버리죠.... 전 결혼식 2일 남았어요ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['저는 결혼앞두고 한약으로 바싹 뺐는데 본식 끝나자마자 한달도 안되서 원상복귀되고 두달째땐 뺀거에서 2배 요요옴😂']
# ['한달 안에 7kg 빼본 적 있는 사람으로서 하는 말인데 가장 필요한건 식단 + 의지 + 운동입니다.....평소에 먹던 것보다 덜 먹기만 해도 빠집니다....저 같은 경우는 아침,저녁은 밥을 먹지만 반공기만 먹고, 저녁은 방울토마토 5개로 연명했습니다....그리고 운동같은 경우는 윗몸 일으키기 30회부터 시작해서 나중에는 100회까지 늘리며 했고, 다리는 박봄의 다리운동 영상 보면서 살 뺐습니다.']
# ['먹는양 줄이는게 기본이긴한데, 똑같이먹어도 누군찌고, 누군 안찌는거보고 체질이 무섭긴 하더라...']
# ['한달즈음 남았을때는 오히려 피팅에 맞춰서 그냥 유지하는분들만 많던데']
# ['팔뚝']
# ['저 결혼할때는 신부가 마차타고 내려오는게 유행이었어요신부입장 마차타고 내려오는데 중간에 음악끊기고 마차 멈춰버리고 우여곡절끝에 내려와서 신부행진하는데', '핼퍼분이 치마잡는걸 알려주지않아 계속 치마밟으며 가다서다 행진ㅠㅠ결혼식 끝나고 예식장 나오니 비바람에...', '전쟁같은 식을 치루고 평화같은 가정을 꾸리며 살고있어요', '식 끝나고 머리핀 하나하나 뽑으며 현타가 왔었지만 ', '한번씩 힘들때마다 영상보면 와 진짜 촌스럽고 어색하지만', '젊은 부모님도 보이고 보고싶은 분들도 보이고', '조금이라도 어린 내 모습도 보여요...', '결혼준비 하시는 모든분들 행복하세요!!!', '', '']
# ['우리 사회쌤이 고3때 두달만에 15kg를 뺐다셨지...']
# ['남편분 인턴하시나']
# ['중3때 입시하느라 28kg뺀거 생각나네']
# ['저두..겨론식때 더 쪘...']
# ['저는 살 뺼 때 입맛 떨어지는 것들을 생각하면서 식사량을 줄였어요 그렇게 59키로를 감량했습니다!']
# ['할미개 같아서 그리워요 ㅠㅠㅠ 댕댕이별에선 잘 지내고있지 할미개..']
# ['자까성님과 같은 거창이라 자랑스럽읍니다...']
# ['포화지방덩어리죠']
# ['본식은 포토샵 많이 안해주더라구요... 스튜디오는 눈코입빼고 다해주던데 ㅠㅠㅠㅠㅠ']
# ['본식에서 프레임 단위로 보정이 가능하다면...']
# ['최종본최종본1', '자까의 최종본', '자까의 최종본1', '자까의 최종본 1', '자까의 진짜 최종본', '자까의 진짜 최종본1', '진짜 마지막', '진짜 파이널리 마지막', '자까의 드레스', '자까의 드레스 수정', '자까의 드레스 수정1', '자까의 드레스 수정 최종본', '자까의 마지막 드레스', '마지막 드레스', '진짜진짜 마지막', '찐막 드레스', 'the end 웨딩드레스', 'The End 웨딩드레스', 'The End 드레스', 'END DRESSES', 'finally dressed', '드레스', 'ㄷㄹㅅ', '.', 'img3.downloads.file.102u251u18882.jpg', '']
# ['굽네는 먹어두 됩니다! 근데 고추바사삭 시키면 아주 주옥되는거야..']
# ['한 분은 찌고, 한 분은 빠졌으니 됐죠 뭐~ 잘 어울리는 한쌍 ㅎㅎ']
# ['ㅋㅋㅋㅋㅋㅋ 석사논문과 겹쳣던 결혼식은 ㅋㅋㅋㅋㅋㅋ 생애최저몸무게로 나를 결혼하게 해주었죠 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ맘고생이 최고다 ㅋㅋㅋㅋㅋㅋㅋ']
# ['개싫다']
# ['안 먹고, 많이 움직이는 것. 말로만 보면 아주 쉬운데 못하는 사람이 너무 많죠.. 의지로 본능을 이겨낸다는 것은 정말 어려운 것 같습니다😅']
# ['웅녀가 되어가는중']
# ['결혼 전엔 다이어트가 그렇게 안 되더라구요ㅠㅠ 대신 돌잔치때 빡쎄게 해서 성공!!! 근데 지금 요요로 더 찜 ㅋㅋㅋ']
# ['ㄷㄷ']
# ['작가님 댕댕이가되신건가요...? 순간적으로 곰인줄..']
# ['200 명중에 요요없이.찐으로 다욧 성공하는 사람이 한명이래요.  그 0.5% 사람 대부분은 다욧이랑 밥줄이랑 직접적으로 연관된 사람이라는 통계가...   꾸준히 할수있는것들로 노력해서 요요없이 다욧합시당']
# ['인생 최대 다이어트당한 건 코로나 후유증 (으로 추정) 으로 내리 앓아 23kg 날려버린 거긴 한데 건강도 같이 날려버려서...종아리 근육 나름 있다 싶은 사람은 식단조절+1시간스피닝 추천합니다 주에 1kg 이상 사라지는 기적']
# ['ㅋㅋㅋㅋ 아 맞네~']
# ['단백질이든 탄수화물이든 많이먹으면 찌는건 똑같습니다']
# ['큐티?']
# ['팩트는 보통 아프다']
# ['3달동안 15kg빼고 2년동안 10kg찌고 다시 2달동안 5kg뺌.. 아직 현재진행형중,,']
# ['30분 뛴 인간 고증 ㄷㄷ']
# ['다이어트보다 더 대단한건 요즘세상에 아이키우는 일..']
# ['우와kg']
# ['저도 개인적으로는 당일에 보여주는게 멋지다 생각함']
# ['다이어트 성공은 힘듭니다.  하지만 살빠진 그 상태를 유지하는건 갑절로 더 힘들어어어어어어어어어어엉엉엉  ㅠㅠ']
# ['베댓님 정답 알려드릴게요', '아는 것과 하는 것은 다른 것이다', '', '물어보는척 알고 계신걸 하면 됩니다']
# ['난 저녁만 굶었는데 4개월동안 9키로빠짐..ㅎㄷ']
# ['위 절제술 ㅋㅋ']
# ["살찐 사람들 특.  난 물만 마셔도 살이 쪄!! 라면서 허구한날 입에 먹는거 들어가고 있음. ㅋㅋ '이건 살코기니까 살 안쪄!  이건 제로 칼로리니까 살 안쪄!' "]
# ['저도삼개월끊고 한달정도(매일출석도아님) 나가고 안나갔더랬죠...']
# ['어? 노빈슨자까']
# ['나는.. 너무 나가서.. 뺐는데 15키로 뺐음..']
# ['최근에 20키로 정도 뺏는데 그냥 덜 먹고 빠르게 걷기 뛰기 반복했어요ㅋㅋㅋㅋ']
# ['ㅋㅋㅋㅋㅋ 싫어요 0인거 봐']
# ['맥주 러버 다이어터인데.. 진짜 맥주와 식단 둘 다 포기 못하는 광기의 다이어트 진행자들분께 산토리니 맥주향 강추 드립니다..슈거고 알코올이고 몽땅 제로에 향만 낸건데 저는 취해요🌟 ps. 사무실에서 먹기 싹 좋음']
# ['저희남편은 그렇게하고 결혼후 더 쪄서 예복으로 맞춘 비싼양복을 못입는.....ㅜㅜ']
# ['게임,영화,애니,웹툰만 미친듯이 보면 밥생각안남']
# ['와 결혼준비 하느라 근 두세달을 하루도 집에서 못쉬고 매일 뚜벅이로 하루종일 돌아다니고 신경쓰다보니 자동으로 고난의 행군 다이어트 돼서 본식날 역대최저 몸무게 찍음... 바빠서 끼니도 어쩔수 없이 거르고... 하객분들이 살빠져서 예쁘다가 아니라 너무 말라서 살좀쪄야겠다는말 제일 많이 들음 ㅜㅜ']
# ['예?']
# ['본식 때 살이 더 쪄서..이모님께 엄청 혼났죠.. 드레스 입혀주사느라 고생많으셨습니다 ㅠㅠ흑흑']
# ['다이어트보다 더 어려운 네이버 정식연재를 꾸준히 하는걸 이루신 분입니다.']
# ['둥글해지니 지방이랑 비슷하게 생겼네 ㅋㅋㅋ']
# ['다이어트 하신분들 정말 존견합니다']
# ['T T 내맘 모르고 너무해~!']
# ['제로도 너무 마시지 마세요 지금 우리가 실험용임 주로 당뇨병 환자를 위해 개발 되었던 대체 감미료들이 과연 일반인에게 좋을까']
# ['아무리그래도 작가님은 마르셯을것이다..']
# ['이 커플은 무조건 모 아니면 도 임ㅋㅋㅋㅋㅋㅋ']
# ['운동 안 하던 사람이 30분을 달릴 수 있다니..ㄷㄷㄷ 자까님 기초 체력이 좋으시네요ㅋㅋ']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['세 달동안 20kg 뺐었는데.. 맨날 편의점 들리고 집에 단 게 다 떨어지면 설탕 물에 녹여먹고 누텔라 1시간만에 다 퍼먹고 먹고 먹고 또 먹었다가 간식 다 끊고 급식도 국 안 먹고 정말 조금 먹거나 닭가슴살이랑 사과 싸가고 집 와서 소고기 200그램이랑 고구마 먹고 4시간 동안 고강도 운동 집에 와서 절대절대 아무것도 안 먹었습니다 설령 초코 하나라도 먹게 되면 펑펑 울다가 새벽에 집 밖에나가서 한참 뛰다 오고 뭐가너무너무 먹고 싶으면 유튜브에서 고강도 유산소 해서 0.3키로 수분 빼면 먹을 수 있는 규칙을 만들었어요 근데 운동하면 식욕이 떨어짐 확실히']
# ['아ㅋㅋ 다이어트는 내일부터지ㅋㅋㅋㅋ']
# ['30분..?이게 된다구요..?']
# ['마지막기회라 생각하고 본식 일주일전 하루 달걀 2개만 먹고 아침 저녁으로 수영 1시간씩 했습니다. 본식날 웬 좀비가 나타났습니다. 다행히 머메이드 드레스가 잘 받는 몸이 만들어졌지만, 속엔 속히 퇴마가 필요한 영혼 하나가 들어있었죠.']
# ['음해해']
# ['아야...']
# ['오 나도 1년 동안 두 번 바꿔본 적 있는데 +2n...']
# ['ㅋㅋㅋㅋㅋ']
# ['여러분 사실 앞자리 두번 바꾸기는 그리 어렵지 않답니다?일단 죽기 살기로 앞자리를 한 번 내리세요', '그리고 자신의 행복만을 추구하다 보면 어느새 앞자리가 또 바뀌어 있을 거에요><']
# ['istj?']
# ['결혼식 전에 저절로 살 빠지던데 결혼식이란게 스트레스라서..ㅜㅜ']
# ['이것저것 준비하다 보니 수능은 코앞으로 다가와 있었다어느새 100일도 안 남았어 ', '이제 진짜로 공부 해야 하는데...', '언제 이렇게 시간이 지났지?', '이러다 진짜 정신 차리면 수능 치고 있겠어']
# ['전 반대로 살이 안 쪄서 고민이었어요. 플래너없이 결혼 준비 혼자 하느라 확 빠졌던. 가슴이 넘 빈약해져서 뽕넣어도 부자연스러웠던 흑흑']
# ['주 3회 운동 시작한 지 2달 반 됐는데 운동 열심히 하고 나면 운동한 게 아까워서 살 찌는 인스턴트는 피해서 먹고 간단한 아침 + 건강한 일반식 한끼는 제대로 먹으면서 살고 있어요 처음엔 평소에 먹던 음식 참기가 힘든데 나중엔 점점 쉬워져서 가족이 먹어도 별로 먹고 싶다는 생각이 안 들 정도가 되니 다이어트 잘 실패하시는 분들께 조금만 참아보시라는 말씀 드리고 싶어요!']
# ['10대; 덜먹으면 빠진다20대; 덜먹고 운동하면 빠진다', '30대; 덜먹고 운동해야 유지된다', '40대; 되면 알아볼게요']
# ['43키로 뺐어요. 97에서 54인데 목표까지 6키로 남았네요 ㅎ... 처음에는 죽었다 생각하고 독하게 뺐는데 이제는 건강관리겸 천천히 빼고있어요']
# ['결혼식 1년 3개월 정도 준비하면서 86-> 70이에요 이번주 토요일 결혼합니당 ', '', '원래 65-68로 들어가는게', '목표였는데 2주전에 교통사고로 10일 입원하면서 ', '퇴원하고오니까 2키로 쪄있고 ', '결혼식 1주일 남았네요 흑흑', '운동도 못하고 급한대로 무식하게 저녁 굶고 있습니다... ', '', '지금 70이에요 ㅠㅠ']
# ['맞는 말만 하시긴 하네요...']
# ['그래도 냥군이라 대답해주넹.. 저 모냥으로 친구가 저런말 하고 있으면 어..? 하고 걍 하던 운동 함 ㅋㅋㅋㅋㅋㅋㅋ']
# ['저는 결혼식때 살빼려고 플라잉 요가를 했는데.. 벌크업이 되어서 팔뚝에 근육이 그냥 막 붙어서 우람해졌었죠 ㅜㅜ']
# ['61kg➡️58kg 된 사람입니다... 물론 노동하는 내내 몸을 움직이고 무거운 거 들고 댕기느라 빠진 거지만요😂 쉬는 동안 운동하면서 키운 근육까지 같이 빠젔읍니다...']
# ['단식원가시는줄ㅋㅋㅋㅋㅋㅋㅋ']
# ['아 우리 남편 같아서 킹받네 ㅋ']
# ['이 감성 오랜만']
# ['운동없이 한약+식단으로 반년만에 80kg -> 58kg 만들었어요 현재진행형 다이어터 입니다!! 운동안해도 충분히 가능해요 귀차니즘 여러분들 화이팅!!']
# ['아이래서 결혼식날 본 신부와 그다음에만난신분님들이 다른모습이었구나..']
# ['홀']
# ['너무너무너무재밌다... 진짜 재밌게 정주행함']
# ['어느새 두 달 정도 남았어이제 진짜로 밀린 거 해야 하는데..', '언제 이렇게 시간이 지나갔지?', '이러다 진짜 정신 차리면 수능 끝나있겠어..', '-수능을 준비하는 D-70 고3의 자세....는 나....']
# ['스튜디오는 포토샵 덕택으로...본식은...청첩장돌리면서 먹은 음식덕에 포동포동 살 올라서 찍고...그 살은 지금까지도 안빠지고...']
# ['저거 은근 괜찮은데 ']
# ['결혼식때 다이어트는 1도 하지 않았고... 예쁜 신부 아니고 그냥 엄청 행복해보이는 신부였습니당.....ㅎ']
# ['정답']
# ['저는 오늘이 딱 10kg 감량한 날이예요.. 넘 힘들었ㅠ 다이어터들 진짜 화이팅입니다ㅠㅜㅠ 살안찌는 체질인 사람들이 제일 부럽다요..']
# ['이게 다이어트지. ㅋㅋ']
# ['포샵.. 현명...']
# ['겨드랑이 봐..']
# ['맞잖아 ㅋㅋㅋㅋㅋ']
# ['솔직히 살이랑 근육 동시에 빼는건 너무 쉬워요.. 오히려 살찐거 유지하는게 힘들죠. 그래서 뚱뚱한 사람보면 넘 신기함. 근육건강<<이상태가 가장 힘든거고']
# ['우와 앞자리가 1인데?']
# ['휴우... 남일 같지 않네요 ㅠㅠㅠㅠㅠㅠㅠ']
# ['~냥군 음모론~']
# ['아는데..아는데..']
# ['뱃살빼는 운동했다가 이틀째 근육통에 시달리는 중... 앉았다 일어나면 죽어요 저']
# ['자까님:냥군, T발 C야?']
# ['결혼한다고 청첩장 건낼 때 밥사는 자리에서 생각없이 처묵하며 자리 즐기다보면 살 찔수있음 주의']
# ['한우인가요 1++등급이라니']
# ['내일 본식드레스 고르러 가는데 제 미래겠네요 🤣🤣']
# ['하하 전2달동안 닭가슴살먹고 킥복싱다녔더니 겨우 3키로빠지던군요 하하하']
# ['체중게에 우와 ㅋㅋㅋㅋㅋ']
# ['T인데 사회생활용 F를 장착하면 다이어트가 쉽진 않죠 정도로 말하고 맙니다']
# ['튀김만 아니면 돼요 닭고기 사다가 집에서 삶거나 구워드시거나 에어프라이기로 조리해 드시는 것을 추천합니다. 가슴살 외에는 살찐다는 것도 오해입니다. 그냥 편하게 닭다리 드세요.']
# ['(지방흡입)']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['f야 fact']
# ['어쩜 우리 이야기와 똑같을꼬']
# ['아. 나도 군대가서 5kg찐거 빼야하는데 정말 어렵네.운동더 하고 밥 적게 먹어야하는데...']
# ['대장내시경 빵 터졌음 ㅠㅠ ㅋㅋㅋㅋㅋㅋㅋ 이잌']
# ['장해요']
# ['ㅁㅊ?']
# ['자까만보']
# ['언성탕면']
# ['성공한 다이어트 vs. 성장한 등급']
# ['운동 안하고 식단부터요 ㅎㅎ 운동하면 보상심리가 작동하니까 ㅡㅡ; 식단으로 몸을 가볍게 한 후에 적응이되면 끝자락에 운동 ㅎ 식단만 하면서 빈둥빈둥 누워있으면 ㅎㅎ 이렇게 안움직이는데 먹으면 안되지 ㅡㅡ 싶음 ㅋㅋㅋㅋㅋ']
# ['아야']
# ['지방 흡입이요']
# ['최종 셀렉하러 가면 신상 보여주더라구요 ㅋㅋㅋ 신상은 무조건 이쁨..']
# ['81에서 69로?']
# ['맞는 말임 쳐 맞는말😡']
# ['포토샵다여트.중요하죠^^♡']
# ['자취하는 중에 세끼 다 안 챙겨먹고 한끼만 먹으면 자동으로 다이어트 되더라고요ㅋ근데...본가 오면 즉시 요요 옵니다ㅎ그런고로 저의 다이어트는 자취방에서만☆']
# ['살이 고민이면 전통혼례하면 됩니다. 한복이 다 가려줌요 ㅎㅎ']
# ['전 결국 실패하고 그냥 결혼했는데 지금 진짜 후회중이에요ㅠㅠ사진이 너무 안이뻐요ㅠㅠ그래서 쳐다보지도 않아요ㅠㅠㅋㅋ']
# ["자까님께 '세상에서 제일 대단한 것 같은 사람'이란 칭호를 받기 위해 오늘도 내일도 계속되는 다이어트..."]
# ['뭐야 저 억울한 말티즈']
# ['냥카모토입니다만']
# ['술이랑 밀가루, 야식 평소에 많이 먹는 편이었는데 딱 끊으니 5kg 빠짐 요새는 하루 한 끼, 탄수화물 자제, 많이 걸어다니기 하며 허기를 달고 사니 살이 죽죽 빠집니다요 (개인 차 있음) 근데 왜 공복인데 다음 날 되면 살쪄 있는지 의문']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ너무 극공이다 진짴ㅋㅋㅋㅋ']
# ['무조건 포기만 안하고 하면 됩니다 저같은 경우엔 16살인데 5달째 운동해서 19키로 뺐습니다 무조건 튀긴거, 단거 제외하곤 다 드셔도 됩니다. 삼겹살같은거나 고기류도 적당량 먹으시면 좋고요 그리고 다들 유산소를 중요시 하는 분들이 많이 계시던데 헬스장 가실거면 무조건 근력운동 먼저하고 유산소 하세요 200칼로리 정도 소모하시면 잘 빠집니다 다이어트 식단이랑 운동강도로 결정됩니다. 진짜 못할거같을때 한번 더 하고 진짜 숨찰때 조금만 더 뛰세요 그렇게 3달만 해도 많이 변합니다']
# ['닭가슴살만 먹으면 ㅇㅈㅋㅋ']
# ['걷지말고 달리라고ㅋㅋㅋ 아ㅋㅋ 티비틀지 말라꼬ㅋㅋㅋㅋ']
# ['대장내시경ㅋㅋ ㄹㅇㅋㅋ 순간적이지만 몇키로 빠짐ㅋㅋㅋ']
# ['냥군 극한의 T네ㅋㅋㅋ 팩력배ㅋㅋㅋ']
# ['누구나 할 수 있으면 다 성공했겠지']
# ['여러분은 다음컷을 보고 다시 이 컷으로 돌아오게 됩니다.']
# ['ㅁㅊ 밝기 최저로해놔서 배를잘라서 지방을꺼내먹는줄알앗음']
# ['님들 먹고 나서 바로 양치 하면 입맛 사라져서 좋아염']
# ['다이어트는 먹는 게 90프로임 나쁜 음식 대신 좋은 음식으로 배를 채우는 게 핵심입니다 경험상 제일 좋은 게 검은콩임 ㅎ 그리고 식후 30분 내로 간단한 유산소 운동을 해주면 최곱니다 산책정도 수준이라도 좋아요!!']
# ['단식원 한달']
# ['???:난 왜 바보인거지???:공부를 안 하니까', '???:너 T발롬이지']
# ['제로로 바꾸고 8키로뺌 ㄹㅇ']
# ['저도 한달가량 남았는데 지금 콩나물국에 스팸에 밥 두공기에 쏘맥 마시고 있습니다....아아아규ㅠㅠㅠ']
# ['와 앞자리를 두번ㄷㄷ']
# ['주치의 드립을 이길자신이 없네ㅋㅋ']
# ['와 그래도 자까님 드레스 탑이 잘 어울리는 것만으로도 팔뚝살 없으실 거 같아요!!']
# ['나락도 락이지?']
# ['괜찮으세요.......?']
# ['행복한 돼지가 최고다~.....최고지...']
# ['미국 미신중에 신부의 드레스차림을 예식 전에 보면 부정탄다는 게 있어서 본식때나 그 모습을 볼 수 있다던데... 신부 입장 하자마자 냅다 우는 남편들 영상 귀여워']
# ['6개월동안 식단과 운동으로  67 -> 43 으로 24키로 빼봣는데', '생사를 오가는 기분이었죠...ㅋㅋ']
# ['둘째낳고 둘째돌잔치때 신랑보다 뚱뚱하길래 충격받고 간혈적단식했어요.. 하루2끼 정해진시간에 먹고픈거 몽땅 그렇게했는디  3개월간 12kg빼고나니 드는생각이 정말 생각없이 ㅊ먹었구나 .... 규칙적으로 먹는게 중요하다 느꼈네융 토탈 15kg 감량후 2kg올랐지만 유지하려 노력합니다  아이들이크면 운동과함께  6kg더 감량하는게 목표랍니다!!화이팅~!!']
# ['체중계에 우와 너무 귀엽닷ㅋㅋㅋㅋㅋ']
# ['지방흡입?']
# ['탄산같은 액상과당도 안 좋아요...']
# ['질량 보존의 법칙']
# ['진짜 노답이다..... 결혼하는데 그거 컨트롤을 못하냐?']
# ['아니 t, f 를 떠나서 저거 말고는 답이 없자나 ㅋㅋㅋ']
# ['어떻게 내가 살 안뺄 수 없게 날 우와우와하게 만들어줘']
# ['팔뚝 굵은거 ㄹㅇ 꼴불견....']
# ['왜 혼자했어 ..']
# ['간식 끊고 저녁 메뉴 상관없이 반 만 먹고 매일 줄넘기 천개해서 한 달 반 동안 3kg 빠짐 근데 운동 쉬니까 요요 오더랑 그래도 근육 늘어서 몸무게는 1kg 정도 차이나는디 예전만큼 안쪄보임! ']
# ['  ^   ^( ㅁ-ㅁ)', ' ㅡㅣㅡ', '    /  \\']
# ['살빼시려면 모든 튀김류와 기름진 음식은 멀리 하셔야됩니다. 야채를 튀겨 먹어도 살쪄요. 정 힘들면 고기를 구워드시더라도 튀김은 자제하세요.']
# ['재수하면서 15kg 빠졌었는데 ㅋㅋㅋㅋ']
# ['다이어트의 주적이 과잉 당분과 탄수화물인걸 생각하면 치킨 의외로 괜찮을지도?튀김옷이랑 콜라가 문제지']
# ['아는것과 실천하는것은 다르다ㅏㅏㅏㅏㅏ']
# ['백수일 때.... 탄산 끊고 아침7시에 등산 나가서 12시까지 운동하고.... 밥 먹고 조깅 나가서 6시에 들어와서 저녁 먹은 다음 10시까지 조깅했는데 비 오는 날 빼고 그렇게 꼬박 6달을 했더니 20키로정도 빠지더라구요 다이어트 힘내세용']
# ['팔뚝에 그래도 근육이 없진 않아서 힘 딱 주면 딴딴해져서 안 출렁이는데 힘 푸는 순간 할말하않']
# ['근데 솔직히 간식 안먹고 평소에 먹는거 절반씩만 먹으면 알아서 살빠지던데4달 동안 82>74 감량']
# ['대장내시경 찐입니다 하기전 식단조절하면서부터 못먹고 내시경할때 싹비우고 용종발견해서 시술하면 한달간 금주에, 죽부터 먹어야하고 고기 못먹어서 살 4키로 빠져요 진짜확실하면서 건강한 방법임 ㅋ 참 참고로 저도 냥군처럼 t입니다 intj']
# ['네 제가 이상태로결혼햇어요 남편은빠지고 저는찌고...']
# ['식중독 걸리면 3일만에 3키로 빠지는 마법을 경험할 수 있긴해요']
# ['14개월 걸려서 30kg 감량해봤는데 생각보다 힘들지 않음 꾸준함만 있으면 가능한 거라... 극단적인 식단 하는 사람들이 힘든거지 적당히 먹는 양 줄여가면서 하루 2번 운동하면 건강하게 빠져요 츄라이츄라이~']
# ['마음고생.....']
# ['내가 120kg 군대 공익갈만큼 돼지였고 자존감이 바닥이여서 진짜 이악물고해서 6개월 만에 30kg뺌 ', '아침 공복유산소, 점심먹고 뒷동산 왕복, 저녁 근력운동, 대중교통 안타고 따릉이타기 했음', '식단은 양을 줄이는거부터 시작했고 점차 닭찌찌, 현미밥으로 바꿔갔음', '이러니까 초반에는 하루에 1kg씩 빠졌어요 다이어트하는분들 응원합니다']
# ['맘고생 하니 6-7주만에 10키로가 빠졌더군요,,']
# ['근데 팔뚝살 아얘 안 빠지진 않아요. 저 한 달 넘게 피티 받고 팔뚝살도 빠졌거든요. 피티 받는 날도 자유운동에도 팔운동은 거의 안 했는데(해봤자 런닝머신 뛸 때 아령 들고 팔 움직이는 정도?) 왜인지는 모르겠지만요...']
# ['다이어트 성공? 그게 뭐죠']
# ['96에서 75 다이어트 성공 우마이']
# ['인클라인 추천함 빨리움직이는것보단 덜힘든거 같고(느낌)  살은 잘빠짐(사실)']
# ['치킨 살 안찌게 먹는 방법!1. 치킨을 시킨다', '2. 닭가슴살을 따로 분리한다', '3. 따로 분리한 닭가슴살의 튀김 껍데기를 때어낸다', '4. 먹는다']
# ['너 T발 C야??']
# ['종건밖에 안떠올라 난...']
# ['개아련 표정 추억이닼ㅋㅋㅋㅋㅋㅋ']
# ['웨이드 닮았다']
# ['와..']
# ['중2때 96.6kg이였던거 운동만해서 1년만에 68.6kg까지 뺐던 적이 있었습니다. 한번 빼면 잘 안 찌더라구요! 다이어트 끝난지 2년 지나가는데 지금 70kg에요ㅎ']
# ['한참 등산에 맛들려서 쉬는날마다 산 가니까 살이 쪽쪽 빠졌다가 하산하고 소비한 칼로리만큼 채우니 도로아미타불 관세음보살크업 ']
# ['큐T 프리T']
# ['저희 학교에서 웨딩 쪽도 배워서 교과선생님께서 알려주시기를,  결혼식에서 찍은 사진은 포토샵을 해주지 않는다고 하네용']
# ['장염']
# ['찐T 모먼트 ㅋㅋㅋ']
# ['조혜련 태보 ㄱ']
# ['자만보']
# ['실시간으로 댓글이 늘고있어...']
# ['약간...낢님부부가 생각나네여 이과장님은 운동 열심히 하시고 낢님은...(이하생략']
# ['얼마 전 건강검진에서 100명 중 몸무게만 4등이라고 욕 들어먹은 비만인으로서 정상 체중을 유지하는 것 자체가 대단한 일이라는 걸 새삼 느낍니다...아 나 진짜 빼야되는데']
# ['나는 기말과제할때 1주일동안 기본 5키로씩 빠지던데... 너무 바빠서 못먹고 못자서ㅠ']
# ['아 귀여우셔라...♡']
# ['세상에 누구나 방법을 알지만 하지 못하는게 공부와 다이어트']
# ['웨딩촬영 2일전인데 순대국 택배와서 술사들고  신나서 집가는중 ']
# ['저는 소화기관이 안좋아서 조금만 먹어도 얹히는 기분이 들었는데, 꼭꼭 씹어먹는 버릇을 들였더니 자연스럽게 먹는양도 줄어들고 소화도 잘돼서 살이 빠졌어요 근데 그런 습관을 들이고나서 몇달 이후에 소식좌 방송이 인기를 타게되면서 그거 따라한다는 오해를 많이받는 바람에 짜증나서 와구와구 먹고싶은데 이미 줄어버린 위장과 베어버린 식습관을 고치기가 힘들어서 그냥 살고있어요 몸무게는 2년째 유지중입니다']
# ['제로라고 홍보하지만 그것도 설탕은 어느정도 들어가있습니다..']
# ['(((((끄덕끄덕)))))']
# ['튀김옷 : ?']
# ['그야 뭐... 틀린 말은 하나 없긴 한데...']
# ['어머!! 이건 사야X 입어야 해!!O']
# ['자까님 탄산음료는 간에 좋지 않아요...맹물을 먹는게 힘들면 레몬즙을 1L에', '1숟갈 넣으면 맹물보단 그럭저럭 나아요']
# ['혹시 여기 허벅지살 빼는 요령 아시는분 계신가요? ㅜㅜ']
# ['저기 탄수화물을 안먹어도 지방이....읍!!!!']
# ['다이어트... 1년 정도 해서 18키로 정도 빼고 현재 9키로 불었슴다 이대로 가다간 그대로 찔 것 같다는 불안감에 나름 조절하고 있어요 빠지지는 않아도 유지는 되더군요...ㅎ 다이어트 성공한 사람도 대단하지만 더 대단한 사람은 유지한 사람이라는 거ㅠㅠ']
# ['암요.. 재밌겠죠 ㅋㅋ']
# ['펩si제로 그것은 신이 내린 땀방울이다']
# ['무슨 뛰면서 국토대장정이라도 하고 오셨는지요...']
# ['질량보존의 법칙. 냥군의 질량이 자까님의 질량으로 보존되었습니다']
# ['1년하고 1달하고 같냐? ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['이제 다음날 근육통이..']
# ['스트레스성 폭식증으로 인하여 매년 플마 20키로씩 왔다갔다 하는 사람입니다 냉정하게 살 빼는 건 하나도 안 대단하고요 애당초 수십키로그램씩 안 빼도 되겠금 유지하시는 분들이 저는 세상에서 제일 대단합니다']
# ['입덧다이어트로 8키로 빼고 결혼했어요~~내생에 가장 날씬했을때가 임신했을때라니..']
# ['튀김껍질 뜯어서 버려야 단백질']
# ['이보시오 낭군 양반~']
# ['때리는게 아니라 그냥 명치를 뚫어버리네  ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['대장내시경ㅋㅋㅋㅋㅋㅋㅋㅋ 아 개 웃기네']
# ['에너지저장과 소모가 비효율적으로 느껴질수밖에 없는 이유: 배부르게 먹을수있게 된건 100년 정도라서... 근데 그 이전 1000000년동안 인류는 굶주렸음ㅠ']
# ['갈대같은 마음이라고 나와있는데 오타가 나신걸까요?']
# ['라면 뽀개먹는 건 진리인데...']
# ['그렇게 아이돌 다이어트를 하게 되는데...']
# ['탈진해요 ㅋ']
# ['앞자리를? 두 번이요?내가 무슨 건국 신화를 보고있나', '형님 저도 알려주시면 안 됩니까']
# ['ㄴ너 T야?']
# ['우리 뇌는 정말 까다로운 녀석이라 탄수화물만 취급한답니다... 걍 주는대로 먹을것이지']
# ['대장 내시경ㅋㅋㅋㅋㅋ']
# ['뭔가 되다 만 노각 느낌']
# ['냥군 제발 비법 전수해주ㅑ여']
# ['난 다른 의미로 두 번 바꿨는데 하... 냥군']
# ['자까니까.']
# ['방법은 아는데... 방법만 알아서...']
# ['작가님 결혼사진 보고싶당']
# ["'신발 보관 서비스'"]
# ['몸무게가 우왘ㅋㅋㅋㅋㅋㅋㅋㅋ 말 그대로 "우와" 라고요']
# ['역시 뺄려면 안 먹는 수 밖에...']
# ['잠만보']
# ['전방에 팩폭다발구역 입니다. 안전에 유의해주세요 ']
# ['대장내시경ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 혁신적이다']
# ['난 작가님이 1g도 사라지는게 싫어요..ㅋㅋㅋㅋㅋㅍㅋㅋㅋㅋㅋㅋ 내가 말하고도 오글거리네']
# ['체중계에 우와 ㅋㅋㅋㅋ']
# ['무념무상']
# ['폭풍 다이어트!']
# ['개이쁠거같음']
# ['아니 반응만 보면 어머님이 드레스 입으시는 것 같은데요 ㅋㅋㅋㅋㅋㅋ']
# ['이거 다른 웹툰에서 봤는데 말이지']
# ['새 삶 살자는 생각으로 5개월 반 정도 걸려서 50키로 뺐습니다. 하나하나 칼로리 계산하며 먹는 습관, 아무리 못해도 주 3회 유산소(처음에는 걷기로 시작, 익숙해지면 인터벌 2시간), 근력운동하는 습관, 음식을 음미하면서 배부르기 전까지만 먹는 습관만 들여놔도 살은 계속 잘 빠지더라구요. 습관을 들여놓은 덕에 유지도 스무스하게 잘 되어가고 있습니다. 그냥 덜처먹고 개힘들게 운동하는 것 외에는 살 뺄 수 있는 방법이 없어요. 다이어트가 끝난 뒤 체중계에 목표 몸무게가 뜨는 순간을 상상하면서 버티세요.']
# ['잘 챙겨드시되 6시전에 식사 끝내고 끼니마다 과식은 안되고 밀가루 술 야식 끊으면 운동을 못하더라도 살 쭉쭉빠짐다~']
# ['저는 결혼식 전에 급하게 뺏다가 신혼여행가서 아파서 2일도 못놀고 비행기탓어요....참고로 비행기 편도만 14시간... 왕복은...']
# ['저보다  나으신듯...처음부터 무리하기 싫어함 그렇다고 끝에 열심히 하는 건 아님 ㅜㅜ']
# ['냥군이 자까님 보다 더 의지가 좋은 겁니까? ㅋㅋㅋㅋ']
# ['저렇게 같이 등록해도 갈 사람만 가고 안 갈 사람은 안갑니다..네. 제가 안 가는 사람입니다. ㅋ']
# ['미래의 자까님: No!!! Stop!!! 안돼ㅐㅐㅐㅐ']
# ['제로 탄산음료는 탄수화물을 땡기게 해요 탄산수로 바꿔 드시는게 좋아요', '는 결혼식은 이미 끝났지만 건강을 위해..']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['지금 1달반동안 식이로만 10키로 뺐는데 저염식하고 밥 면 빵 떡 끊고', '과일 야채 고기 견과류 등 탄단지 그램 재서 챙겨먹으니 빠지더라고용 물은 미지근-따뜻하게 하루 2리터씩']
# ['친오빠 f인데 나: 나 살쪘지?', '오빠: ㅇㅇ 좀 빼야할 듯 너 지금 XX(몸무게)아님?', '나:안 재봐서 모르겠는데 재고 올게', '10초 후', '나: 휘바 진짜 XX.X(몸무게)인데 어떻게 알았음? 와 진짜 빼야겠네 어떻게 빼지..', '오빠: 굶을 생각하지말고 먹고 내가 운동하라는 대로 하셈', '이러고 다음날 못 일어나게 해주던데 솔직히 f라고 하는데 t랑 뭔 차이인지 모르겠음', '']
# ['자까님 8페이지 이모티콘으로 내주세옄ㅋㅋㅋㅋㅋ 완전 공감ㅋㅋㅋ']
# ['구운치킨은 괜찮습니다']
# ['기름은 지방이니 닭가슴살로 퉁쳐..']
# ['ㄷㄷ체력 개 좋으신데']
# ['대장 내시경 하면 그날 하루만 빠지는 거잖앜ㅋㅋㅋㅋㅋ']
# ['팔뚝살과 승모근은 신의영역같습니다..그래서 전 본식전에 의느님의 은혜를 받았고 7년이 지난 지금은 다시 은혜받기 전으루 돌아갔습니다ㅋㅋ']
# ['저는 1년 끊고 1년간 한번도 안나갔죠..그리고 그담해 쪽팔려서 다른헬스장 또 1년끊거 한번도 안나갔죠그리거 마지막으로 6개월 꾾고 2달 안나가다 이러다 안될거 같아 지금 매일 아침 저녁 한시간 나가고 있습죠 네네']
# ['사람 몸은 특정부위 하나만은 못뺌']
# ['진짜 여러번 때리시네...']
# ['네 ㅋㅋㅋㅋㅋ 저도 다이어트 어떻게하는건진 알아요...ㅋㅋㅋㅋ 내몸이안움직일뿐....😭😭😭']
# ['남자입니다. 결혼전에 20키로 빼고 결혼후 바로 다시 20키로 쪘으며 4년동안 추가로 20키로 더 쪘다가 ', '5개월동안 다시 20키로 빼서 ', '원래몸무게 유지중입니다 ㅠㅠ']
# ['교정하고위염걸려보세요 아무것도못먹어서 진짜쫙빠짐 ㅋ ㅋ ']
# ['거북목 교정법 알려 주실분ㅜㅜ']
# ['썸네일 보고 홀린듯이 들어왔습니더']
# ['스튜디오사진은 포샵해주고요 예식장 본식은 안해줘요 ㅋㅋ']
# ['보스톡']
# ['풍선 바람빠진것 같다...이제 다시 찌웁시다']
# ['소싯적엔 한달동안 6시에 저녁먹고 군것질안하고 9시에 취침 .. 요렇게 3키로 빠졌어요 잠을 일찍 자는 이유는 아시죠?']
# ['헐..  진짜? 신부가 아니라?']
# ['1년 하고 반년 쉬었더니 다시 제자리로 돌아감요ㅋㅋㅋ']
# ['저는 뭐든 끝까지는 하는 편인데 연장은 도저히 못하겠더라구요~']
# ['저는 다이어트하고 팔뚝주사(그아프다는 맞으면 피멍듬) 맞고 해서. 뺏는데 허리디스크로 스테로이드주사 맞고 도로묵되어서 그것때문에 울뻔...ㅠㅠ']
# ['1 저녁으로 식사대용 쉐이크 먹음2 퇴근후 9키로를 빠른걸음으로 걷기운동함', '3 1달후 몸무게 앞자리가 바뀜', '4 2달후 부터 매달 뒷자리가 바뀜', '5 5달후 옷을 다시 사야함 ㅋ']
# ['고급보디입니다만']
# ['대장내시경과 치질수술 추천드립니다. 왜 살이 빠지는지 저도 알고싶지 않았어요...']
# ['드레스 최종본 - 진짜 최종본 - 정말 진짜 최종본 - 변경없이 정말 진짜 최종본  ..  약간 이런 느낌으로 계속 맘에 드는게 나옴']
# ['저는 다이어트따위 하지않고 진행했죠ㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['와 안 지를 수가 없는 내용이다..']
# ['우와 두번이나 그래서 작가님은요?!']
# ['어맛 패완얼?']
# ['아무리봐도 웹툰에서 보이는 자까님이 제 신부님이랑 성향 넘 비슷해요ㅋㅋㅋㅋㅋㅋ (물론 다른사람이지만 성격이)']
# ['먹는 행복함이 얼마나 중요한데 ']
# ['2콤보는 좀 너무한 거 아니오 ㅋㅋㅋㅋㅋㅋㅋ']
# ['저는 쌀밥 끊고 현미밥으로 바꾼 다음 일반식도 하고 다이어트식으로 하고 주 5회 2시간씩 운동해줬더니 100일동안 -10kg 감량했어요 !!!!... 100일안에 치킨도 먹고 군것질도 했지만 과식하지 않고 적당히 먹으니 잘 빠져주더라구요... 다들 할 수 있어요 화이팅 ❤️']
# ['다음에 냥군 안경 올리기 컷에는 팟칭- 좀 넣어주세요 찰떡일 것 같아요']
# ['저도 결혼식전에 1달동안 12키로빼고 쓰러지는 기염을 토했지만, 결혼식때 입은 정장은 지금까지 한번도 못입어보고 옷장에 방치가 되었습니다... 비싼건데 ㅠ']
# ['귀여워 ㅜㅜㅜ 야구빠따로 줘 패고싶엉 ㅜㅜ']
# ['ㅎㅎ.. 뜬금없지만 저는 거의 40kg을 감량했답니다... 174/98이였었는데.. 1년동안 꾸준히 다이어트 해서 60키로까지 내려온.. 다이어트 하시는 분들 모두 화이팅..\U0001f979 우리가 앞으로 살아갈 세월들에 비하면 1,2년은 정말 잠깐인 순간들이니까요!!🔥🔥']
# ['우리 수학쌤도 본인 결혼사진 보여주시면서 살 개힘들게 빼셨다하심..ㅋㅋㅋ']
# ['ㅋㅋㅋㅋ 천재다']
# ['물만두인가요?']
# ['성공했다 다시 찌고 성공했다 다시 찌고...17키로 15키로 10키로 각각 빼본적 있어서 성공은 여러번 해봤고 비법도 아는데 성공 후 다시 살던데로 살면 몇년에 걸쳐 또 사부작 사부작 쪄서 도로 돌아가고...']
# ['다들 방법은 알고 있으시잖아여....']
# ['지방흡입..?']
# ['물만 먹어도 살찐다는 사람은내가 무얼 물처럼 먹었나 생각해보시기바랍니다']
# ['슬그머니 자랑을 하자면 저 3개월만에 14kg 뺐어요!! 이제 9kg만 더 빼면 돼요!!']
# ['여러분 안먹고 빼는 다이어트는 무리하게하시면 면역체계가 무너집니다.  급하게 빼면 요요온다고만 알았지 몸이망가지는건 몰랐어요. 무리하지 않는선에서 모두 건강하세요 ']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ몸무계 우오ㅓ']
# ['두달 다이어트해서 4kg 빠지고똥 많이 싼 날 1.7kg 뺐어요', '역시 대장내시경..?']
# ['와우ㅋㅋ 신박한데요??']
# ['햄버거를 드시면 굿']
# ['1++이라고...?']
# ['몸무게가 우와래']
# ['그치 그게말만쉽거든']
# ['금연하는 사람들보다 더 독해~~~~~']
# ['그냥...야식안먹고 간식 잘안먹고 그러니까 6개월만에 6키로 빠지던데....']
# ...
# ['배달음식 줄이고 안하던 운동하면 빠지긴 하는데 똑같이 살아도 유지가 정말 힘듬...ㅠ']
# ['저건 남자라서 된거지']
# ['겨땀 현실고증 ㅋㅋㅋㅋㅋ']
# ['냥군 헬창인 듯.. ㄷㄷ']
# ['어머! 이건 꼭 사야해!']
# ['저는 사람 1명 무게 빼는 데 몇 년 걸렸어요. 가장 간단하게는 식후 디저트 먹는 습관을 없애야 하고요, 밤에 드셔도 상관없지만 "야식"이 짜고 달기 때문에 그 야식이란 것도 끊으셔야 해요. 장기전으로 간다 생각하고 하나씩 실천해서 오랫동안 유지하는 게 제일 좋습니다. 치팅을 하더라도 다이어트용 식품을 양을 늘리는 쪽으로 하셔야 해요. (그렇긴 한데 요새 저도 2시간씩 헬스하느라 하루 1끼는 밥을 먹고 있어요. 헬스 시작하기 전에는 밥도 끊었습니다)']
# ['천국의 계단이란 이름을 가진 지옥의 계단 타세요 체지방 줄이는데 좋대요 대신 힘듦']
# ['정석은 군것질 안하고 반찬은 그대로 챙겨먹되탄수화물만 조금 적어먹으면서 천천히 빼는게 다이어트 근육증진 요요도안오고 좋아요 오래걸릴뿐..ㅠㅠ']
# ['우와']
# ['앜ㅋㅋㅋㅋㅋㅋ 이짤 평생소장각입니다😍😍😍']
# ['화난 수박']
# ['맞는말이 의미가많아요하면 맞는 말 or 쳐맞는 말 or 의미가 맞지만 그래도 넌 맞는 말 결론은 그냥 뭔말을 해도 맞음']
# ['대강굶고 스트레스 받음 알아서 빠지던데..']
# ['90kg--->취준 95kg --> 취직 후 교육기간 115kg---> 배치받고 다이어트 현재 105kg 찌는건 순식간인데 빼는건 너무 느려']
# ['저거 너무 많이 마시면 설사엔딩...']
# ['30분 이야 첫날부터 그러면 금방 하기싫어져요..']
# ['사실 이게 젤로 잘맞음..에 달리는게 문제지']
# ['헬스장도 잘보고 다니세요 요새 툭하면 먹튀폐업 하는데가 많더라구요..']
# ['그거랑 저거는 좀 다르자나요 ㅋㅋㅋㅋ']
# ['맞는말도 가끔 의도치않게 한대치더라구요..']
# ['맞아요 쳐먹고라는 말은 안쓰셨어요 ㅋㅋㅋㅋ']
# ['팩트 ㅋㅋㅋ 뭘 물같이 드셨으니까 찐게 아닐까요?']
# ['승리자다...!']
# ["(냥군님 외면) ('-') ('-') "]
# ['사실 이게 정답인데..']
# ['팔뚝은 얇은데 팔뚝빼고 다 쪘어요 이게 말이되냐고..']
# ['깔끔하게 포기...']
# ['찐 강아지가 되셨네..']
# ['누가 알면서 다이어트 안하래요 자까님..']
# ['단백질 맞지만...튀겼잖아요ㅋㅋㅋㅋㅋ']
# ['30분동안...ㄷㄷㄷㄷ']
# ['달리고 싶지만 걷고싶어요']
# ['결국 헬스장에 기부했다는 해프닝이...']
# ['대장 내시경ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['맞는 말 하셨네요... 등짝 맞는 말']
# ['음해하지말랰ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['비싼 돈 들여 힘들게 키운 내 소중한 살들을 비싼 돈 들여 빼다니....']
# ['건강하면 되는 거죠']
# ['....비법 좀 알려주세요']
# ['한달만에.......ㄷㄷㄷㄷㄷㄷㄷㄷㄷㄷ']
# ['엌ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 조용히 옆에섴ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['지옥 다이어트라도 무리에요']
# ['그 드레스가 최종합격이군요']
# ['결혼식날 드레스 입은 자까님 보고 여러번 반하는 거 아니예요???ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ']
# ['어... 식단 싹바꾸고..호밀빡 2쪽에 샐러드조금 닭가슴살 한덩이 일캐먹구', '매일 헬스 웨이트1시간 유산소1시간.. 해서 본식때까지 8kg뺏습니다..', '그리고 현제 요요☆', '더쪗어요 ㅋ']
# ['치킨이 젤로 살찔텐데']
# ['와...이걸하네']
# ['화면돌려본사람 ㅊㅊ   우와 라고써잇음']
# ['파워 겨땀']
# ['첫번째 두번째샾 오열ㅠㅠ']
# ['태생 비만이라 1년 전부터 준비하는데...그냥 닥쳐서 3개월만 해도 될거같은 느낌...', '장기전 너무 힘들다...건강히 빼고 운동도 배우고있지만....', '운동이 아직 내 삶이 아니야ㅜㅜ']
# ['ㅋㅋㅋㅋ체중계에 우와라고 적혀있음']
# ['무리한 다이어트는 몸에 해롭습니다 여러분 간헐적 단식+빡센 유산소로 4달간 30키로 뺐다가', '실려간 저라서 잘 알아요...']
# ['채치수..?']
# ['혹시 물 안마시셨나요']
# ['치킨을 튀길때 무엇을 묻혀서 튀기는지 다들 알거라고 생각합니다 ']
# ['정말 그럼 pt받았을때 템은 다 사놓고 체험 하고 안하신겁니까']
# ['아 제모보자 피식하고 웃으면서 쿠키 긁었습니다 아직 안봤는데  실패예상']
# ['초반에 탄수화물을 많이 줄이고. 단당류 다 패스 해야해요. 그래야 지방이 잘 줄어듬. 흰쌀밥 대신 현미밥. 고기먹을때 쌈장 고추장 다 패스하고 소금간 조금. (저는 힘들어서 두부쌈장먹음) 샐러드 소스 반으로 줄이기. 과자 빵 면 탄산음료 다패스. Gi지수 낮은음식 많이 먹었어요. (중요)']
# ['빅토리아 탄산수 + 콤부차 = 쥼맛 ']
# ['살빼실거면 인터벌로 꼭 하세요. 빨리걷기 5분 조금 속도롤려서 달리기1분 이런식으로요~ 여성분들은 스포츠용 압박되는 브라 꼭 착용해야 잃어버리지 않아요...\U0001f979 지방이기때문에 무조건 가슴 빠집니다\U0001fae0 남성분들은 언덕으로 올려서 하는걸 더 추천🤗 ']
# ['어른이 될수록... 강제성이 필요하다. 돈을 들여야한다. 뭐를? 운동을. 헬스장 등록하면 안가도, PT20회 라도 끊으면 3달은 열심히 하고 필라테스도 한번에 50회 끊으면 안갈수가없다 돈아까워서 ㅠㅠㅠㅠㅠㅠㅠㅠㅠ']
# ['퇴근후 헬스장 가기=영어단어 매일100개씩 외우기저는 학생들 한테 이렇게 알려줘요... 대결도 해요. 나도 수업끝나고 운동갈테니 너도 단어 외우라고 ㅎㅋㅋㅋㅋㅋㅋㅋㅋㅋ 둘다 안하면 엄청웃습니다']
# ['간헐적단식이 초반에 잘 빠지긴 해요. 근데 혈압이나 당뇨있으신 분들은 위험합니다']
# ['여러분 탄산수 드세요. 제로음료같이 대체 감미료가 들어간 것도 아닌 완전 무당에다가, 얼음 넣도 홍초 살짝 타 먹으면 카페에서 파는 에이드 안 부러움 ㄹㅇ']
# ['뼈가 바스러질 것 같아요']
# ['님편도 19키로 뺐어요. 진짜... 남자는 잘 빠지더라구요 😇 신부인 제가 더 안먹고, 운동 더하고, 더 기간을 길게 했는데 쨉이안되요. 15키로뺐나..? 여튼 근육량도 많고 기초대사량이 다르다는걸 이때 진짜 뼈저리게 느낌 ㅠㅠ 그래서 행복한돼지가 되려면 근육을 키워야해(?) 하는 결론을 내렸습니다. 먹는거 포기못해 ㅠ']
# ['탄수화물을 줄이면 배둘레가 달라집니다. 먹는양을 줄이면 몸무게 kg 차이가 나고요. 당을 줄이면 피부가 달라집니다. 셋다 하면? 완벽하죠. 하지만 성격이 달라집니다. 😭 초예민해져요... 그래서 일주일에 한번 보상 줘야해요. 옷이던, 음식이던지 힘내라고 나에게 주는 선물 필요합니다 😊 홧팅']
# ['이게 정석인데 팔뚝은 진짜 제일 마지막에 빠지는 곳이에요.. ㅠㅜ 최서 6~7키로 이상(지방만) 빠져야 얇아지더라고요. 근력운동 병행+림프절마사지 포함']
# ['겨드랑이 림프선 폼롤러로 마사지 조지세요. 꼭이요! 누워서 등도 폼롤러로 드르륵드르륵 하고요(브라끈 까지만 요추까지 아님) 승모근이 생각보다 아래까지 있어요. 어깨만 있는게 아니거든요 목아래부터 브라까지 꼭! 풀어주세요. 특히 거북목 있으신분들']
# ['여기서F는 뭐라말함?']
# ['와... 둘 다 에반데 둘 다 하래']
# ['처맞는말..']
# ['신부 드레스를 결혼식 당일 전에 보면 부정탄다는 미신이 있다던데 그게 미국인가요??']
# ['이거로 이모티콘 만들어주세요오']
# ['자릿수가 바뀌었네요']
# ['빚보증 다이어트와 이별다이어트가 가장 빨리빠지긴 하던데.... ']
# ['알아...안다고...탄수화물줄여야하는것도 알아...근데 그게 사는거냐!!!!']
# ['예전에 독립일기에서 자까님 수술 후 본가에서 지내니 어머님이 처먹고 자기만 하네라고 했던 게 기억나네ㅋㅋㅋ']
# ['훗 올것이 왔군........']
# ['조만간 엄마랑 모녀간 공주놀이 해봐야지']
# ['혹시 앞자리 하나가 추가 되었나요?']
# ['백숙 먹자고 해짜나']
# ['일반 콜라나 제로 콜라나 살 찌는건 똑같습니다 칼로리가 0이라서 안찌는거라고 생각하시는분들이 계시지만 설탕대신 감미료가 있어서 찌는건 결국 똑같이 찝니다']
# ['응애세력']
# ['저정도면 탈수기에 몇번 돌리신거 같은데요 말라 비틀어진 당근같아요']
# ['잘들으세요 환자분은 이제 음식을 안드셔야합니다']
# ['길막고 있는 잠만보같네요 피리가져와서 불면 비켜주시나요?']
# ['아침 단백질or적은 탄수화물점심 먹고싶은 메뉴: 대신 천천히 1인분 이하로 먹기', '저녁 단백질쉐이크or과일 1개or안먹기', '간식은 제로음료 위주', '끼니 규칙적으로 먹고 물 자주 마시기']
# ['무료되면 짤로 써야겠다']
# ['근데 살이 빠진거랑 포토샵이랑은 또 다름']
# ['조랭이떡자까님이다']
# ['인간승리지 이게']
# ['오이처럼생겻다']
# ['걷다 뛰는거 반복하는게 더 효율적이랬어요!! 이유는모름']
# ['(궁서체)']
# ['냥카모토입니다만']
# ['T: 역시 그렇지? 운동해야겠다']
# ['몸무게가 왜 한우 투플러스냐고ㅋㅋㅋㅋㅋㅋ']
# ['튀김옷 입는 순간 탄수화물입니다. 치킨 자체도 저탄고지가 아니라 저탄고단입니다']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ아이곸ㅋㅋㅋ 남편들 팩폭하면 와이프에게 혼납니다 ']
# ['와 두번ㄷㄷㄷㄷ최소 십몇키로']
# ['내 몸이 생각대로만 움직였으면 이미 한혜진 대두버전이겠지']
# ['이지은다이어트 옆으로 퍼진살 빼기신지니 팔뚝 밑살 지옥버전', '', '존나 강추ㅇㅇ']
# ['맑눈광 세분']
# ['깨알 어머니ㅋㅋㅋㅋㅋㅋㅋ귀여우셩']
# ['예쁜 드레스 입으려고 10키로 빼고 결혼했는데 (운동+식단) 그후로 8년간 꾸준히 늘어서 또 10키로 찐상태로 이어지다가 아이 초등들어가는데 이대론 안되겠다 싶어 에어로빅으로 10키로 빼고 유지중이에요 ㅎ 다이어트 실패분들.. 삶의 중요한부분을 노려서 이때는 꼭 빼야해!! 하고 꾸준히 3달만 해도 빠질껍니다 ㅎ']
# ['저도 지나가는 T입니다뼈맞아도 전혀 아프지 않네요', '그저 끄덕끄덕..']
# ['갑자기 생각난 건데, 한 사람이 앞에서 달리고 한 사람은 뒤에서 전동휠체어 타고 쫒아다니면 운동이 반강제로 잘 되지 않을까요?20분 뛰고 공수교대해서 역으로 쫒아가면 재미도 있고 번갈아가면서 운동도 될 것 같은데']
# ['생긴게 거의 지방이 수준인데 ㅋㅋㅋㅋㅋ']
# ['티네']
# ['vr로 운동하는거 보여주면 뇌가 운동한다생각하고 알아서 지방은 빼고 근육만들어주면좋겠다']
# ['뭐 제로 맥주도 나오는 세상이니...']
# ['"걷고 싶으면 경사를 20도 위로 올려라."']
# ['같이 헬스장 가주는거 왤케왤케임...']
# ['부분 지흡하는 사람들도 있더라구요']
# ['러닝 30분 뛰도 화이트아웃 와서 헬스장에서 누워보신분~?']
# ['포동포동하고 귀여우니 됐어요']
# ['ㄹㅇ 그냥 먹는 거 줄이고 운동 좀 해도 20키로 정도는 빠지더라...']
# ['거울의 내 모습이 존나 킹받아서 다이어트 하게 되더라고요. 키가 커서 살찌면 너무 그란데해져요....^^']
# ['다이어트 3일충들은 나가주그세요그냥']
# ['너무 아프다...그만패...이제 남은데없잖아.....']
# ['한우 1++등급이군요 최상급한우네요']
# ['그 정말 쉬운 방법인데 장염 걸리면 한 번에 훅 빠지긴 해요. 고딩때 장염 걸리니까 숫자가 바뀌더라구요 물론 그 뒤에 식욕 폭발해서 다시 찜']
# ['저도 다이어트해서 웨딩촬영 했는데 팔뚝살은 죽어도 안빠져서 포샵으로 줄여주신 기억이🤣']
# ['개아련.....']
# ['아니 ㅋㅋㅋㅋㅋ 체중계에 등급이 ㅋㅋㅋㅋㅋ 마블링인가요 ㅠ']
# ['맞는 말만 하긴 해바로 X 맞는 말']
# ['회사 쉬면서 술 끊고 식단 적게 먹다보니 반년간 약 7kg 빠졌어요.. 운동은 플랭크만 가끔 하고요.']
# ['반년동안 피티로 20kg 뺐어요근데 3년동안 10kg 다시 찜', '쨋든 -10kg니 어떻게든 됐구나 싶고(())']
# ['살이 옮겨갔네요']
# ['뼈 때려서 순살로 만들더니 냥군님도 안하셨군요..']
# ['저같은 경우는1. 라면 끊고, 탄산줄임(끊는건 도저히 못함ㅠㅠ)', '2. 하루 한끼는 과일+연두부로', '3. 오후 6시이후 금식 (아무리 늦어도 7시까진 먹음)', '4. 일주일에 피티 세번', '이렇게 하고 6개월동안 5키로 뺐네요ㅠㅠ']
# ["'처' 는 묵음이야♡"]
# ['지나가는 T입니다..냥군에게 화가 안나네요....', '근데 안성탕면 뽀사먹으면 진짜 맛있는데..!!!!!!']
# ['아련..']
# ['대학일기때부터 드시던 안성탕면 쌩라 !! ㅋㅋㅋㅋ']
# ['살을 찌우려면, 엄청난 노력이 필요하다. 배가 불러도 계속먹고 움직임을 줄이고 먹고나면 바로 누워서 몸을 불려야한다. 도대체 살을 찌우기위해 얼마나 많은 돈과 시간이 필요한지 ㅋㅋㅋㅋㅋ이 몸이 얼마짜린줄 아느냐!!!! ', '', '다들 사랑해요. ']
# [' ..........팔 들어올린 고양이 같아요. 형부......']
# ['저 그래서 결혼 1년전부터 다이어트+팔관리 받았습니다ㅠㅠ그래도 한계가 있더라구요. 안하는것 보단 낫지만...']
# ['다*어터라는 웹툰에서 헬스장 첫 등록은 짧게 하라고 했습니다.']
# ['팔뚝살을 빼고 싶다했는데...ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['탄단지 조합은 살찌기 쉬운 조합이에요!!!']
# ['액체로 된 음식(?)은 흡수가 빠르기 때문에 맥주든 탄산이든 살 찌는건 똑같습니다 목 마르시면 그냥 물 마시세요...']
# ['최소 12키로 ㄷㄷㄷㄷ']
# ['팔뚝살 진짜 어떻게 뺀담요..정보 공유 좀....ㅜㅜ']
# ['T발 너 C야?']
# ['저건 진심의 미간이다..맛있는거 먹으면 나오는 미간처럼 저건 진심이야..']
# ['실제로 다이어트 성공하는 사람은 100명중에 10명정도고 10명중에서 2년넘게 유지하시는 분은 1~2명 있을까말까라고 하더라고요 유지어터분들 대단하세요...']
# ['본식때 보시면 진짜 반하실거예요, 형부...자까님 이뻐요.']
# ['가까운 사람이랑 같이 뭔가 하게된다면 장점이 귀찮더라도 억지로라도 그 뭔가를 하게됨 근데 단점이 둘 다 안할 수 있음']
# ['힘들지.']
# ['다이어트 쿠키!']
# ['두분 신혼생활 하시면 자까님 부모님만큼 시트콤일것 같아요ㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['패폭을 하는 자를 가까이 둬야하는 이유']
# ['어떻게 살을 빼셨나요????:평소보다 덜 먹고 더 움직이면서 뺐습니다 ']
# ['독립일기 때에 pt도 받으셨잖아요ㅋㅋㅋ']
# ['저번에 등록한 pt는 그럼 무엇인가요 자까님??ㅋㅋㅋ']
# ['웨딩드레스 입을때 상체비만인 사람은 진짜 스트레스임 하체비만이면 기장 긴 원피스로 가릴수 있지만 팔뚝살 뱃살은 커버안된다ㅠㅠ']
# ['네~달리기~(라고 너가 말하고 있다) ㅋㅋㅋㅋ']
# ['구운걸로 드셔요']
# ['저도 수능 82일 남았는데 저래요 ㅎㅎ']
# ['냥군님 어머님보다 더하다']
# ['독립일기때 받던 피티 계속 받으셨더라면....']
# ['그.. 돈을 써서 지방분해주사 맞는 방법도 있드라그여...']
# ['은근히 법규까지 같이한거 같은데..냥군 심상치 않다']
# ['그래도 남편이랑 한 번도 같이 드레스 못 보면 조금 아쉬울 것 같은데 자까님 완죠니 긍정퀸...\U0001f979']
# ['내향성인 사람이 실내 실외 구분법 : 누울 수 있냐 없냐로 구분됨', '아무리 내 집이라도 손님이 와 있으면 누울 수 없으니 손님 와 있을 때는 집이라도 실외침...']
# ['와.............. 미친']
# ['내일 기준 127일 남은 올해^^ㅗ']
# ['이렇게까지 해야하나 하는 생각이 들면 잘 하고있는거고 그렇게 까지하면 성공함..-앞자리 4번바꾼사람..']
# ['2트만에 순살됨']
# ['나무위키에서도 나왔는데 웨딩드레스는 팔뚝이 길고 얇은 사람이 가장 잘어울린다고 합니다.']
# ['교과서 위주로 공부해서 대학가는거 다 알지만 못가는이유를 한컷에 설명하시는 자까님 대단해융']
# ['작은것부터 시작1.하루 한 끼. 밥 반공기 넘기지않고 먹음', '2.매일 2회, 15~20분짜리 요가나 스트레칭 함', '3.주 1회 수영다님', '', '근데 세달간 3키로 빠졌어요.', '작은것보단 큰게 필요한가봐요 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ']
# ['다음에는 다이어트 일기로 연재를 해주심이..']
# ['진짜 이게 어쩔 수 없음ㅜㅜ']
# ['일어나 운동해야지..']
# ['자까: isfj(f중 가장 t)vs', '냥군: intj(추정)(양모펠트마냥 팩트로 쑤시는 것에 능통함)', '이들의 말싸움 가슴이 웅장할 것 같다']
# ['어떻게 인생도 웹툰자까인생같지']
# ['코로나 2년간 찐 20kg...때문에 건강이 너무 악화되어서 1년만에 운동과 식습관 개선 곁들여 27kg을 뺐습니다 다이어트는 느리고 길게 보면서 하는게 좋은 것 같아요']
# ['독립일기때 갓태어난 기린 자까는어디가고..!이 독자는 매우 기쁘다']
# ['뛰는 시간만 30분이요???!! 그거 진짜 힘든데...']
# ['달려야지하면서 걷고있는 내모습']
# ['결혼식때 살빼고 그후 요요로 15키로 쪄버림.. 사람들은 애기가진줄알지만 사실 ..지방이에여!!!!']
# ['저탄고지']
# ['치킨 보내실때가 된것같습니다..']
# ['옷이 맘에 들면 내 신체 중 한부분이 뭔가 맘에 안드는건 불멸의 법칙...']
# ['이래서 줌결혼식이 필요해']
# ['베댓분 그 작은게 안되는데 어떡하죠']
# ['체중계에 우와라고 적혀있음ㅋㅋㅋㅋ']
# ['겨땀 진짜 개싫음.....회색티 입으면 겨땀 나온거 더 잘보여서 진짜진짜 싫음']
# ['왜 이렇게 겨땀에 집착을하는거야 자까쿤.!']
# ['덕후샾 들어가기 전 : 월급날도 한참 남았고 이번달도 꽤나 아슬아슬할거 같은데 근처 샾 근처에 지나가는거 그냥 물건 뭐 들어왔나 보기만 하자....', '덕후샾 들어간 후 : 어멋?!! 이건 사야해!!!']
# ['공주놀이는 언제나 재밌다는ㅋㅋㅋ']
# ['런닝머신을 걷다뛰다보면 종종 스스로가 쿠X런 쿠키처럼 느껴지는데 저만그런가요? 쿠키들도 열심히 달리기를하는데...']
# ['살빼기엔 먹을게 아직 너무많다']
# ['현실반영 제대로다']
# ['그말이 쳐맞는말일줄은 몰랐지..']
# ['맞긴해...']
# ['아니. 그거 아니야.']
# ['잘 보니까 체중계 앞자리가 1++인데...?']
# ['진짜 살 한번 찌면 빠지는게 너무 어려움 ㅠㅠㅠ 심지어 본인은 지방이 다 장기인가 뭐시긴가 내부지방인가 뭔가ㅠㅠㅠ']
# ['!!!!!!!!!!']
# ['누가 내 방 사진찍었노']
# ['탄단지 조합 훌륭하죠 👍']
# ['액상과당만 줄여도 살 빠져용']
# ['야생의 잒만보가 체중계에 올라있다..!']
# ['사장님 다음날 몸살 예약이요~']
# ['그치만 제로콜라는 신인걸..']
# ['진짜 운동 처음할때 의욕 활활 타올라서 완전 무리해서 타고.. 다음날 근육통으로 쓰러져서 다시는 안가게됨ㅋㅋ']
# ['헬스장은 1월달에 미친듯이 붐빈다죠']
# ['숙제하다가 자까님 웹툰보다가 현타온 내표정']
# ['달려라 자까']
# ['한달에 6키로 뺀 방법: 가끔 외식하고 평상시에 귀리밥 두숫갈+삶은 닭가슴살+양념장 이렇게 먹었습니다. 아니면 숙주고기볶음,,아님 배추고기야채찜,,,,, 나머지 한끼는 오트밀음료 아님 아몬드 브리즈,,, 찐으로 이것만 먹었어요 가끔 과일과 나물반찬,, 살 잘빠져요']
# ['남은 3개월은 제작진이 맛있게 먹었습니다 ^ ^ !']
# ['썸네일이 너무 강렬해서 결제할 수 밖에 없었다ㅋㅎㅋㅎㅋㅎ']
# ['헬스장 일주일가고 안가기 국룰ㅋㅋㅋ']
# ['어쨌든 앞자리 바뀌었네요']
# ['튀김옷은 탄수화물과 지방이에요^^']
# ['여유는 통장에서 나오고 인격은 당과 탄수화물에서 나온다는 말이 있죠']
# ['베댓이 없네']
# ['직업병ㅋㅋㅋㅋ']
# ['사촌언니 결혼식날 최고 몸무게 찍고 임신하고 입덧때문에 최저 몸무게 찍어서 농담으로 둘이 바뀌었다고 웃으면서 얘기해줬었어요 ㅋㅋㅋㅋㅋ']
# ['스튜디오 사진은 포샵이 되지만, 식장에서 하객들에겐 원본으로 보입니다!!']
# ['무엇을 물처럼 먹었는지 생각해봐라']
# ['pt받으셨잖아요?????']
# ['생라면은 못참치ㅋㅋ']
# ['등급 최고네요']
# ['오... 단기 다이어트엔 대장내시경... 메모']
# ['몸무게 우와 킬포ㅋㅋㅋ']
# ['따라읽었어요. 달.리.라.고.']
# ['치킨은 지방입니다']
# ['맞는 말(물리)']
# ['2000원 바싸지겠다순살되서']
# ['겨땀이 부각되어 보이네요']
# ['...결혼식이 왜 오래 걸리는지 새삼 깨닫기']
# ['원래 여자들은 허벅지랑 팔뚝살이 가장 나중에 빠진대요ㅠㅠㅠㅠ 진짜 안빠짐']
# ['"T발 너 C야?"']
# ['코끼리는 채식동물이라는 것을 기억하십시오 휴먼..']
# ['처먹다를 순화해서 때려 먹다라고 하는건 어떤가요?']
# ['다이어트 개쉬움. 돈이 궁할때가 있었는데 하루 한끼만 먹고다니니까 한달에 15kg 빠지고 식성도 돼지에서 멸치됨. 대신 체력이 박살남']
# ['저 예식 두달전부터 크로스핏해서(주3회)3키로 날리고 들어갔어요~!! 식사량 1도 안 줄였는데 허리랑 등은 좀 해결됐어요. 근데 팔뚝이.......']
# ['드레스투어 어무니 넘 좋아하시네ㅋㅋㅋㅋㅋㅋㅋ 초롱초롱']
# ['오...배탁 탐나는데?']
# ['아... 냥군님 친구분이랑 테니스 치기도 했었지']
# ['자까님 짱이당... 운동 하나도 안하던 사람이 러닝 30분 하려면 진짜 힘든데... 못하는게 뭐야 당신 사랑해요...']
# ['야생의 『잠만보』이(가) 나타났다!']
# ['ㅋㅋ몸무게에 우와 너무 귀엽다']
# ['명언이다 인생은 처음 가는 길 투성이.... ']
# ['나도 앞자리 바꾼 적 있음! (n)0키로에서 어쩌다보니 1키로 빠져서 (n-1)9키로 됨 ']
# ['그렇게 했으면 우리 다같이 서울대 갔고 비민도 없지 응 그치']
# ['단기 다이어트는 ㄹㅇ먹는양 줄이는게 중요하더라구요..요요고 뭐고..']
# ['제발 방법좀..........']
# ['작가님 이번 작품에서 왜이리 겨땀을 디테일하게 그리시나요...']
# ['뚜쁠']
# ['생각하는(척 하면서 녹아내리는)자까']
# ['말만쉽지']
# ['그치 국영수 위주로 하면 서울대 가는건 다 알지']
# ['....코끼리가 왜 뚱뚱한지 아실려나? ']
# ['이건 진짜 저장할 만한 짤이다']
# ['왜 팔빼고 빠지지']
# ['우..와...입술 끝에있더 말이 쏙 들어가네']
# ['-미국식-', '엄마: 우리딸 잘부탁해요~♡', '아빠: (철컥-)🔫 우리딸 잘.부.탁.해', '요-']
# ['??? : 수술은 잘 되셨습니다. 다행히 이 사진이 심장을 빗겨갔더군요.']
# ['이제 다음날되면 골골거리면서 못한다']
# ['운동을 다르게했잖아요']
# ['대장내시경 미친']
# ['어머니 회춘']
# ['이와중에 냥군 체중이 우와라고 써 있음ㅋㅋㅋ']
# ['에어드랍으로 자까님한테 갔나봐요']
# ['냥군님 친구분이랑 테니스도 치면서 헬스도 다녀요?']
# ['음해하지말래ㅋㅋㅋ']
# ['굽네 같이 구운 치킨이면 모를까... 튀긴건 뭐...^^']
# ['생활습관을 바꾼다는 마음가짐으로 다이어트 시작해야함..... 작은 거부터 바꿔나가기 ']
# ['먹는데 쓴돈 빼면 돈이 날아가는거여서 저장하는거에요 네 움직이기 싫은거 아니라고 아ㅋㅋ']
# ['배 때리면 뽈랑~ 할 것 같애']
# ['형부 비법좀 알려줘봐요']
# ['작가님 살찐 마쉬멜로우 같아요']
# ['-30kg 뺄때 죽는줄 알았쥬..']
# ['황영조']
# ['가장 당연하지만 가장 지키기 어려운 것']
# ['뭘 해도 하실 분이다. ']
# ['예전일이지만 식당일이나 서비스 업이 다이어트 최고죠! 한달사이 4kg 빠진적도 있습니다. 물론.... 브레이크 타임 없고 점심 저녘은 먹지만 주문 들어오면 먹다가 못먹으면 시간 지나 폐기 처분하고 8시 퇴근이지만 조금이라도 늦게 들어오면 9~10시 퇴근에 7일중 5~6일을 손놈과 갑질을....', '(훌쩍-)']
# ['내 팔뚝해도해도 너무해', '튼실한 소세지같은 통통한 내 팔ㅠㅠ', '득근만이 살길인가...']
# ['💩의 무게를 알게되면 더 슬플거같다']
# ['스트레스 하도 받아서 건강 잃으니까 살 쫙쫙 빠지던데요 살기위해 강제로 식단도 조절하니까 저도 앞자리 숫자 2번 바뀌었어요...ㅎ']
# ['「하얗게 불태웠다...」']
# ['다이어트를 하는 이유는... 원판 사진 때문이죠ㅠ ㅠ 식장에서 당일 찍은 사진은 포토샵이 안됩니다!! ', '그래서 포샵된 웨딩 촬영 사진이 로비에 걸려있음 그거 보고 신부대기실 들어온 사람들이...음.... 그저 웃지요^^;;']
# ['말라가고 이쒀여 자까님']
# ['사람눈에도 필터 낄순없나 약간 3D처럼 결혼식장들어갈때 안경쓰고 다 안경써주세요 신부 입장합니다~이렇게 제발']
# ['나 8에서 7 앞자리 한번 바꾸는것도 생고생다하면서 뺐는데...매형 다이어트 비법좀 전수해줘요...']
# ['포토샵은...다...돼...👍']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 전혀 생각도못한 대답이라 당황함']
# ['닭가슴살만 먹으면 약간 합리화 되니까 먹었어요']
# ['깜짝 놀라시면 우째 너무 예뻐서 \U0001f979']
# ['동그라미가 되어가는 고딩인데 어떡해요? 이미 끊을 술도 없다.']
# ['사람 현실몸은 포샵 못 하고 사람 눈엔 필터 못 끼워요']
# ['이니 뜬금 고퀄 뭔데요 ㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['제로탄산도 살이 안찌진않는다는것.. 저도 알고싶지 않았..아 이거때문이아닌가']
# ['2000원 비싸지겠어요']
# ['아 제로 없으면 다이어트 못하는 거 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['장염걸리면 쌉가능ㅇㅇ']
# ['???: 어떻게 하면 수능 만점을 받을 수 있죠????: 교과서 위주로 공부했어요']
# ['궁서 등장']
# ['맞는말 했으니까 일단 맞으세요.독자들 팩트로 때린죄']
# ['달려라 허니']
# ['솔직히 먹는데 돈을 얼마나 들였는데,살 빼면 돈 빠지는거 아닌가?']
# ['먹고 눕는 습관은 피합시다']
# ['자까님 이번 작품 굿즈는 저런 인형이나 쿠션인가요? 두근두근']
# ['내가 본 신부 중에 가장 이뻐요']
# ['헬스장 수익의 9할은 기부금이라는 소문이 있다']
# ['라면먹을때 젓가락을 피해가려는 노른자...']
# ['부부 질량보존의 법칙인가요?']
# ['헬스장 전기세 내러다닌다는게 학계의 정설,,']
# ['홍채 위치가 너무 사실적이예요 자까님;;; ']
# ['... 뽀각!']
# ['우아 남편님 ㅎㅎㅎ ']
# ['아뇨 찌거나 삶은 닭가슴살 드세요 치킨이든 구운치킨이든 결국 지방덩어리거든요 ㅋ구운치킨?  집어서 으스러놨는데 기름 한방울 안묻으면 ㅇㅈ해드릴게 ', '']
# ['먹는데 돈을 얼마나 들였는데, 이걸 다 빼라고요?']
# ['원래 운동은 숨쉬기만 해도 충분함 ㅇㅇ']
# ['야식의 유혹을 도대체 어케 참냐고!!!!']
# ['무리하면 이제 다음날부터 운동 거들떠도 보기 싫어짐....']
# ['팩트라 반박불가']
# ['이게 자까님이 원하시던 티키타카구나ㅋㅋㅋㅋㅋㅋ']
# ['스트레스 받으면 폭식하니까...']
# ['뭐야 다이어트 하던 기억을 잃은 환자한테 사진 보여주는 주치의야 뭐야']
# ['술 안 마시고 야식 끊으니까 밥은 많이 먹어도 살 안찌긴 합니다ㅎㅎㅎㅎ 다들 작은거부터 시작하면 어렵지 않아요^^']
# ['그치 모든걸 비우긴한데 좀 다른거잖아']
# ['이 배에 얼마를 들였는지 생각하면 뺄 수가 없지 ㅋㅋㅋ']
# ['그러나 말을 듣지 않는 육체.....🛌']
# ['...아앗.....']
# ['(상대방의 뼈에) 맞는 말']
# ['저 순살됐어요....그만해 그러다 다 죽어']
# ['맞아요ㅠㅠ존경합니다']
# ['이게 더 아파 ㅋㅋㅋㅋㅋㅋㅋ큐ㅠㅠㅠㅠ']
# ['아니 스튜디오 촬영 때에는 그렇게 배가 뽈록 튀어나온 것처럼 묘사되었으면서....!']
# ['정X만 같아요']
# ['와, 금주...진짜 마음 단단히 먹으셨군요..독립일기때의 금주편을 생각하면...']
# ['모든걸 다 비워야하긴 하는데 그게 지방은 아니자나룤ㅋㅋㅋ']
# ['내표정=자까님표정']
# ['ㅓ 대학일기에서 본것같은데 데쟈뷰..?']
# ['하지만 결혼식장에서의 모습은 포샵이 안되쥬...']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['전 4번 바꿨었는데 지금은..... 더보기']
# ['굽네치킨 뜻밖의 호황']
# ['헬스장이건 필테건 3개월할거 6개월하는기 제일 후회였으... 출석은 한달도 안될듯 ㅋㅠㅠㅠㅠ훌륭한 전기세 납부였다']
# ['무알코올 맥주 칼로리 있습니다... ㅎㅎ']
# ['ㅋㅋㅋㅋㅋ사람 다 똑같구나']
# ['근데 보통 저런곳 거울은 날씬하게 나오지 않나요?']
# ['자까님 손에 든것부터 내려놓으시죠']
# ['다음날 아침...다리가 작동하지 않는다']
# ['저도 예신인데 살빼야하는데 큰일이에요🤣']
# ['자까님 대학일기에서 다이어트를 위해 천천히 폭식하시던 모습이 생각나서 오늘 제목 보고 좀 배신감 느껴질 뻔했는데 역시 제 기대룰 저버리지 않으시네요. 감사합니다.']
# ['답은 이 컷에 있었다ㅋㅋㅋㅋㅋㅋ']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 과자인줄 알았는데 안성탕면이얔ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['자까님 주위에만 비 내리나 봐']
# ['설탕이 없으시다잖아~']
# ['인생은 포토샵으로 커버 불가능해..❤️']
# ['저스트 라잌 TT이런 내 맘 모르고 너무해 너무해']
# ['비맞으셨어요ㅠㅠㅠ']
# ['진짜요! 세상에서 젤 멋있는 사람들']
# ['이와중에 안성탕면 라면 뽀개먹는거 ㅋㅌㅋㅋㅋㅋㅋㅋㅋ']
# ['ㄹㅇ 제로없으면 다이어트 못함']
# ['진씸... 다이어트 하는 사람들 보면 나도 해야겠다 생각은 드는데 생각 만 함... 진짜 생각만 해']
# ['글씨부터 t임ㅋㅋ']
# ["What's wrong with you너 T야?"]
# ['대장 내시경 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 획기적인 방법이네요...']
# ['냥군 어떻게 한거야 제발 알려줘']
# ['대학일기 83화 엄머니가 알려주신 방법이네요.ㅎㅎㅎㅎ']
# ['솔직히 우리 모두 드레스사진은 볼 자격이 잇다고본다 난']
# ['불어 있다니 프랑스어 좀 하시나 봐요 껄껄껄']
# ['맛있으면 0칼로리!']
# ['???정준하 아저씨???']
# ['방법은 나도 알고 있지....']
# ['아 팩폭으로 때리지 마요']
# ['한번도 힘든 앞자리 바꾸기를 두번이나']
# ['중간:내가 사라져볼게, 얍!']
# ['진짜 인공지능 모먼트 냥군님 ㅋㅋㅋㅋ']
# ['저도 알고싶지 않았어요...']
# ['자까님은 ISFJ ㅋㅋㅋㅋㅋㅋㅋ']
# ['냥군 T야?']
# ['다이어트는 내일부터라고 배웠는뎁쇼잉']
# ['약간 2024년이 다가오는 내 모습같다 정신차리면 24년이겠어']
# ['치킨은...닭가슴살만 먹으면 살안쪄!!']
# ['원래 행복하면 살찐다네요! 자까님 냥군과 함께해서 행복해서 그런것같아요!!']
# ['왜냐면 나도 알고 싶지 않았어요']
# ['원래 다이어트는 내일부터 하는거죠~!']
# ['어맛!!! 이건 입어야해!!!!!']
# ['아웃겨요ㅋㅋㅋㅋㅋㅋ']
# ['결혼식빼고 다른거 다 대입해도 성립하는 말이죠 ㅋㅋㅋㅠㅜ..']
# ['오 또 씻고가셔야죠❤️❤️']
# ['ㅋㅋㅋㅋㅋ묘하게 낭군보다 살쪄있는 자까님']
# ['냥군... 너무 멀어보이네요... ']
# ['아... 그런데 결혼식까지 4개월도 안 남으시지 않았어요...?']
# ['아 오늘 중력너무 강해']
# ['주변에 자기는 적게 먹는데 왜 살이 자꾸 찌지? 이런 말 하는 친구 있길래 인스타 피드를 봤는데 밤에 올린 음식사진 + 술... 네 뭐 긴말할 필요 없이 니 인스타 피드 다시 보고 그런 말 해라고 했습니다']
# ['하지만 결혼하면 그 길을 같이 가죠~♡']
# ['얽']
# ['지행이 합일하지 못하여 침대에 누웠더니 일어나서 운동하라 방법을 보여주니', '어와 냥군이여 가디록 망극하다']
# ['정말 예상 못한 제목이넼ㅋㅋ']
# ['배방구 해도 되나요?']
# ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['하기 가 제일 어렵죠']
# ['수능 50일 남겨둔 고3 같네요']
# ['깨알 에어팟']
# ['아파요...']
# ['이제 보니까 매형은 그냥 뭘 해도 잘하는 스타일이네']
# ['천상 만화가']
# ['두근두근 드레스복권']
# ['해야 할 건 많은데 아무것도 안 한 저 표정... ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ']
# ['지방이?']
# ['아니 웹툰을 그리셔야지 왜 내모습을 그려두신거지;;']
# ['팩폭다발구역입니다']
# ['구운치킨만요^^']
# ['어머 이건 사야해!!!!']
# ['다 아는 그것인데.. 고거시..........']
# ['똑같이 운동을 안 해서요']
# ['큐티?']
# ['몸무게 보존의 법칙?']
# ['허억 그게 진짜 힘든데 먹는거 줄이고 운동많이하기를 해내시다니']
# ['2kg쌉가능']
# ['다이어트 하는 방법을 모르는 사람은 없습니다..... 실천을 하지 못 하는 것 뿐...']
# ['와 한우1++이다']
# ['인형출시하면 구매의항있습니다']
# ['냥군 대단해요 ,, ｡°(°.◜ᯅ◝°)°｡ღ']
# ['대단해요 냥군...']
# ['냥군님,대단하세요!']
# ['팩트']
# ['제목보자마자 "뭐가살쪄!" 외치며 들어옴']
# ['ㅋㅋㅋㅋㅋㅋㅌㅋㅋㅋㅋㅋㅋㅋㅁㅊㅋㅋㅋㅋ']
# ['신협 은행 광고에 나오는 돼지 인형 같아요']
# ['우와']
# ['ㅘㅜ...']
# ['냥군 그는신이야']
# ['유지하는것도 어려울거 같은데']
# ['아는 데 그게 맘대로 돼지 않을까요...']
# ['앞자리가 한번도 아니고 두번 바뀐거면... 아팠던거 아니죠?ㄷㄷㄷ']
# ['알긴알아요 근데 어떻게하는지 몰라요']
# ['명언이다']
# ['ㄹㅇ임']
# ['아는데 몸은 안 따라줌']
# ['옷은입고 뛰세요']
# ['어머님ㅋㅋㅋㅋㅋ 귀여우셔요ㅋㅋㅋㅋ']
# ['자까의 마음은 갈대~♡']
# ['어 나 t야 ']
# ['1']
# ['하지만 안빠지죠...']
# ['당아ㅏ앙이ㅣㅣ어ㅓ트ㅡ???']
# ['ㄹㅇ 팔뚝살 시강 ㅠㅠ']
# ['"오우 씨 아메리칸 스타일"']
# ['1']
# ['제목부터 찔리네요']
# ['1']
# ['자까님이 더 예쁜데요...❤️']
