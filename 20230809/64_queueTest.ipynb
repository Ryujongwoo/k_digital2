# %%
from queueModule import Queue
queue = Queue()
queue.view()
# Out:
# 큐에 저장된 데이터 => 없음

# %%
menu = 0
while menu != 4:
    while True:
        print('=' * 30)
        print(' 1.add  2.remove  3.view  4.종료 ')
        print('=' * 30)
        menu = int(input('원하는 메뉴를 입력하고 Enter 키를 누르세요: '))
        if menu in [1, 2, 3, 4]:
            break
        else:
            print('메뉴는 1 ~ 4 사이의 정수만 입력해야 합니다.')
        # ===== if
    # ===== while
    
    if menu == 1:
        data = input('큐에 저장할 데이터를 입력하세요: ')
        queue.add(data)
    elif menu == 2:
        queue.remove()
    elif menu == 3:
        queue.view()
    # ===== if
# ===== while
print('프로그램을 종료합니다.')
# Out:
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 3
# 큐에 저장된 데이터 => 없음
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 111
# 큐에 111을(를) 저장합니다. rear = 1, front = 0
# 큐에 저장된 데이터 => 111
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 111
# 111는(은) 중복된 데이터 입니다.
# 큐에 저장된 데이터 => 111
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 999
# 큐에 999을(를) 저장합니다. rear = 2, front = 0
# 큐에 저장된 데이터 => 111 999
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 333
# 큐에 333을(를) 저장합니다. rear = 3, front = 0
# 큐에 저장된 데이터 => 111 999 333
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 777
# 큐에 777을(를) 저장합니다. rear = 4, front = 0
# 큐에 저장된 데이터 => 111 999 333 777
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 555
# 큐에 555을(를) 저장합니다. rear = 5, front = 0
# 큐에 저장된 데이터 => 111 999 333 777 555
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 1
# 큐에 저장할 데이터를 입력하세요: 888
# overflow 발생... 큐가 가득차서 888를(을) 저장할 수 없습니다.
# 큐에 저장된 데이터 => 111 999 333 777 555
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 3
# 큐에 저장된 데이터 => 111 999 333 777 555
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 2
# 큐에서 111을(를) 제거합니다. rear = 5, front = 1
# 큐에 저장된 데이터 => 999 333 777 555
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 2
# 큐에서 999을(를) 제거합니다. rear = 5, front = 2
# 큐에 저장된 데이터 => 333 777 555
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 2
# 큐에서 333을(를) 제거합니다. rear = 5, front = 3
# 큐에 저장된 데이터 => 777 555
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 2
# 큐에서 777을(를) 제거합니다. rear = 5, front = 4
# 큐에 저장된 데이터 => 555
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 2
# 큐에서 555을(를) 제거합니다. rear = 5, front = 5
# 큐에 저장된 데이터 => 없음
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 2
# 큐에 저장된 데이터가 없습니다.
# ==============================
#  1.add  2.remove  3.view  4.종료
# ==============================
# 원하는 메뉴를 입력하고 Enter 키를 누르세요: 4
# 프로그램을 종료합니다.
