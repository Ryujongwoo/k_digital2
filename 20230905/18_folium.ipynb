# %%
# folium은 Leaflet.js를 이용해서 위치 좌표계 값을 지도위에 시각화 할 수 있다.
# pip install folium
import folium

# %%
# folium의 Map() 메소드의 location 속성으로 지정한 위치를 중심으로 하는 zoom_start 속성으로 지정한 배율을 사용하는
# 지도를 만든다.
# folium.Map(location=[위도, 경도], zoom_start=배율[, tiles='지도 스타일'])
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15)
# folium 지도 객체에서 save() 메소드로 지도 차트를 html 파일로 저장할 수 있다.
folium_map.save('./output/map.html')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7a58cd2915733d5ce2a52b5869381b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7a58cd2915733d5ce2a52b5869381b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d7a58cd2915733d5ce2a52b5869381b5 = L.map(
#                 &quot;map_d7a58cd2915733d5ce2a52b5869381b5&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ad6934318f5d41bb455a27ed3131b3e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d7a58cd2915733d5ce2a52b5869381b5);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Map() 메소드의 tiles 속성으로 지도 스타일을 지정할 수 있다.
# 지도 스타일: Open street Map(기본값), Stamen Terrain, Stamen Toner

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15, tiles='Open street Map')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa134f9bbeaf15f4c2af0f6a8dbe8f46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa134f9bbeaf15f4c2af0f6a8dbe8f46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fa134f9bbeaf15f4c2af0f6a8dbe8f46 = L.map(
#                 &quot;map_fa134f9bbeaf15f4c2af0f6a8dbe8f46&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5ec1de46313711fdfd9a0d75b4a52f5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fa134f9bbeaf15f4c2af0f6a8dbe8f46);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15, tiles='Stamen Terrain')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cb54665b86a5498eadd4a0832766866 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cb54665b86a5498eadd4a0832766866&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_8cb54665b86a5498eadd4a0832766866 = L.map(
#                 &quot;map_8cb54665b86a5498eadd4a0832766866&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fe0680a70e7024434c78b6e4e0b7192 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8cb54665b86a5498eadd4a0832766866);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15, tiles='Stamen Toner')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ba9dd4ea34459aebad2a6d41472f343 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ba9dd4ea34459aebad2a6d41472f343&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3ba9dd4ea34459aebad2a6d41472f343 = L.map(
#                 &quot;map_3ba9dd4ea34459aebad2a6d41472f343&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_959f7e837cac46b33a7baefde8f20cef = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ba9dd4ea34459aebad2a6d41472f343);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15)

# folium의 Marker() 메소드의 location 속성으로 지정한 위치에 마커를 만든다. => add_to() 메소드로 지도에 추가한다.
# folium의 Marker() 메소드의 popup 속성으로 마커를 클릭했을 때 표시할 문자열을 지정할 수 있다.
folium.Marker(location=[37.579617, 126.977041], popup='경복궁').add_to(folium_map)
folium.Marker(location=[37.5658049, 126.9751461], popup='덕수궁').add_to(folium_map)
folium.Marker(location=[37.5794309, 126.9910426], popup='창덕궁').add_to(folium_map)
folium.Marker(location=[37.5787708, 126.9948698], popup='창경궁').add_to(folium_map)
folium.Marker(location=[37.57327406, 126.99516214], popup='종묘').add_to(folium_map)

# 마커를 클릭했을 때 팝업되는 말풍선의 크기는 folium의 Popup() 메소드의 max_width 속성으로 변경할 수 있다.
popup = folium.Popup('영풍문고 - 종로본점', max_width=200)
folium.Marker(location=[37.5697869, 126.9823161], popup=popup).add_to(folium_map)

folium_map.save('./output/map2.html')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a20a40e45ce815d053753023e8fbf410 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a20a40e45ce815d053753023e8fbf410&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a20a40e45ce815d053753023e8fbf410 = L.map(
#                 &quot;map_a20a40e45ce815d053753023e8fbf410&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59cf0a7036d25776186dd4dbe3b66612 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a20a40e45ce815d053753023e8fbf410);
#
#
#             var marker_5c473e3a4e695fdb230635d168315bf3 = L.marker(
#                 [37.579617, 126.977041],
#                 {}
#             ).addTo(map_a20a40e45ce815d053753023e8fbf410);
#
#
#         var popup_193488ee7ad0429fa2c7f7a5d633ffdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8f2979ebf23073ad77f5a4cf7832f1bf = $(`&lt;div id=&quot;html_8f2979ebf23073ad77f5a4cf7832f1bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_193488ee7ad0429fa2c7f7a5d633ffdb.setContent(html_8f2979ebf23073ad77f5a4cf7832f1bf);
#
#
#
#         marker_5c473e3a4e695fdb230635d168315bf3.bindPopup(popup_193488ee7ad0429fa2c7f7a5d633ffdb)
#         ;
#
#
#
#
#             var marker_9aca1ca17e7a5557732be73a2c6dbc8e = L.marker(
#                 [37.5658049, 126.9751461],
#                 {}
#             ).addTo(map_a20a40e45ce815d053753023e8fbf410);
#
#
#         var popup_bf62030fe52fa69ff5fd9e16b42eab0e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c792b94323b58013f868e6b3eef26266 = $(`&lt;div id=&quot;html_c792b94323b58013f868e6b3eef26266&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_bf62030fe52fa69ff5fd9e16b42eab0e.setContent(html_c792b94323b58013f868e6b3eef26266);
#
#
#
#         marker_9aca1ca17e7a5557732be73a2c6dbc8e.bindPopup(popup_bf62030fe52fa69ff5fd9e16b42eab0e)
#         ;
#
#
#
#
#             var marker_7031a1f02bb88c3c661cf50e9bb24413 = L.marker(
#                 [37.5794309, 126.9910426],
#                 {}
#             ).addTo(map_a20a40e45ce815d053753023e8fbf410);
#
#
#         var popup_fb6fc42441278aa08235cfb692735af3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd576d312a05dcda320f9767236faf50 = $(`&lt;div id=&quot;html_dd576d312a05dcda320f9767236faf50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창덕궁&lt;/div&gt;`)[0];
#                 popup_fb6fc42441278aa08235cfb692735af3.setContent(html_dd576d312a05dcda320f9767236faf50);
#
#
#
#         marker_7031a1f02bb88c3c661cf50e9bb24413.bindPopup(popup_fb6fc42441278aa08235cfb692735af3)
#         ;
#
#
#
#
#             var marker_5ddafd1597dd82364736575e5b858997 = L.marker(
#                 [37.5787708, 126.9948698],
#                 {}
#             ).addTo(map_a20a40e45ce815d053753023e8fbf410);
#
#
#         var popup_bce3a8889591eff49ac689b5e526849b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_07f5c0b5c8747f46fd9bab5faa13a43b = $(`&lt;div id=&quot;html_07f5c0b5c8747f46fd9bab5faa13a43b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창경궁&lt;/div&gt;`)[0];
#                 popup_bce3a8889591eff49ac689b5e526849b.setContent(html_07f5c0b5c8747f46fd9bab5faa13a43b);
#
#
#
#         marker_5ddafd1597dd82364736575e5b858997.bindPopup(popup_bce3a8889591eff49ac689b5e526849b)
#         ;
#
#
#
#
#             var marker_31e39d34f399427b1bc2c5e95a947128 = L.marker(
#                 [37.57327406, 126.99516214],
#                 {}
#             ).addTo(map_a20a40e45ce815d053753023e8fbf410);
#
#
#         var popup_95910c85b70bec192d353fc18d7e7560 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_08426354d6e97eeb15504f60b5889d2d = $(`&lt;div id=&quot;html_08426354d6e97eeb15504f60b5889d2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;종묘&lt;/div&gt;`)[0];
#                 popup_95910c85b70bec192d353fc18d7e7560.setContent(html_08426354d6e97eeb15504f60b5889d2d);
#
#
#
#         marker_31e39d34f399427b1bc2c5e95a947128.bindPopup(popup_95910c85b70bec192d353fc18d7e7560)
#         ;
#
#
#
#
#             var marker_9117cf6570575dd6c601ed579f41e173 = L.marker(
#                 [37.5697869, 126.9823161],
#                 {}
#             ).addTo(map_a20a40e45ce815d053753023e8fbf410);
#
#
#         var popup_0ba0f8c47706f6769cae29a0d71ed7e4 = L.popup({&quot;maxWidth&quot;: 200});

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15)

# Marker() 메소드의 icon 속성에 Icon() 메소드로 마커의 색상과 아이콘 모양을 지정할 수 있다.
# 마커에 표시되는 아이콘은 https://getbootstrap.com/docs/3.3/components/#glyphicons-glyph에서 제공하는 아이콘을
# 표시할 수 있다.
# 색상 이름 리스트
# 'blue', 'cadetblue', 'pink', 'red', 'lightgreen', 'purple', 'lightred', 'beige', 'orange', 'black', 'darkblue'
# 'white', 'gray', 'darkred', 'darkpurple', 'green', 'darkgreen', 'lightgray', 'lightblue'

folium.Marker(location=[37.579617, 126.977041], popup='경복궁',
             icon=folium.Icon(color='red', icon='arrow-down')).add_to(folium_map)
folium.Marker(location=[37.5658049, 126.9751461], popup='덕수궁',
             icon=folium.Icon(color='green', icon='ok')).add_to(folium_map)
folium.Marker(location=[37.5794309, 126.9910426], popup='창덕궁',
             icon=folium.Icon(color='purple', icon='star')).add_to(folium_map)
folium.Marker(location=[37.5787708, 126.9948698], popup='창경궁',
             icon=folium.Icon(color='orange', icon='heart')).add_to(folium_map)
folium.Marker(location=[37.57327406, 126.99516214], popup='종묘',
             icon=folium.Icon(color='pink', icon='cutlery')).add_to(folium_map)

folium_map.save('./output/map3.html')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_152fb12b023c135b59f5c5fd524d14d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_152fb12b023c135b59f5c5fd524d14d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_152fb12b023c135b59f5c5fd524d14d6 = L.map(
#                 &quot;map_152fb12b023c135b59f5c5fd524d14d6&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1594b550aed0fc3f3d11ce3c989d95ce = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_152fb12b023c135b59f5c5fd524d14d6);
#
#
#             var marker_7622bc5363f9531d3944ba3c7f52cdb1 = L.marker(
#                 [37.579617, 126.977041],
#                 {}
#             ).addTo(map_152fb12b023c135b59f5c5fd524d14d6);
#
#
#             var icon_b559bbeeb6853d51cb7be23b5a18d684 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;arrow-down&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7622bc5363f9531d3944ba3c7f52cdb1.setIcon(icon_b559bbeeb6853d51cb7be23b5a18d684);
#
#
#         var popup_5d72af3fdd764640818d6d0acbb5c3c1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb7675fa06c356374c169f21d3b8de60 = $(`&lt;div id=&quot;html_eb7675fa06c356374c169f21d3b8de60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_5d72af3fdd764640818d6d0acbb5c3c1.setContent(html_eb7675fa06c356374c169f21d3b8de60);
#
#
#
#         marker_7622bc5363f9531d3944ba3c7f52cdb1.bindPopup(popup_5d72af3fdd764640818d6d0acbb5c3c1)
#         ;
#
#
#
#
#             var marker_f735c52e299d400ce5d7c4f8c1379396 = L.marker(
#                 [37.5658049, 126.9751461],
#                 {}
#             ).addTo(map_152fb12b023c135b59f5c5fd524d14d6);
#
#
#             var icon_b09293bf5580c87f084ce95b8b13871a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;ok&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f735c52e299d400ce5d7c4f8c1379396.setIcon(icon_b09293bf5580c87f084ce95b8b13871a);
#
#
#         var popup_cb5597dea9d2c888b067a3b03b9200e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c9a6303115ec5c02d476570d4ca9414f = $(`&lt;div id=&quot;html_c9a6303115ec5c02d476570d4ca9414f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;덕수궁&lt;/div&gt;`)[0];
#                 popup_cb5597dea9d2c888b067a3b03b9200e9.setContent(html_c9a6303115ec5c02d476570d4ca9414f);
#
#
#
#         marker_f735c52e299d400ce5d7c4f8c1379396.bindPopup(popup_cb5597dea9d2c888b067a3b03b9200e9)
#         ;
#
#
#
#
#             var marker_e0379e4d9cf9f27b54a575077797d0c5 = L.marker(
#                 [37.5794309, 126.9910426],
#                 {}
#             ).addTo(map_152fb12b023c135b59f5c5fd524d14d6);
#
#
#             var icon_6a41756615990417bf262b466f8cd1ed = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;purple&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e0379e4d9cf9f27b54a575077797d0c5.setIcon(icon_6a41756615990417bf262b466f8cd1ed);
#
#
#         var popup_560faaf580f21f45675523625b0a4f30 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_58619c3f87604adf9304fffcf8451aa1 = $(`&lt;div id=&quot;html_58619c3f87604adf9304fffcf8451aa1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;창덕궁&lt;/div&gt;`)[0];
#                 popup_560faaf580f21f45675523625b0a4f30.setContent(html_58619c3f87604adf9304fffcf8451aa1);
#
#
#
#         marker_e0379e4d9cf9f27b54a575077797d0c5.bindPopup(popup_560faaf580f21f45675523625b0a4f30)
#         ;
#
#
#
#
#             var marker_4b98197df31bc3b79aef074e9fdcfe93 = L.marker(
#                 [37.5787708, 126.9948698],
#                 {}
#             ).addTo(map_152fb12b023c135b59f5c5fd524d14d6);
#
#
#             var icon_a938a0722afe315373edb6dbaae684d6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;heart&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );

# %%
folium_map = folium.Map(location=[37.5697599, 126.9836604], zoom_start=15)

# folium의 CircleMarker() 메소드로 원형 마커를 만들 수 있다.
# radius 속성으로 마커로 표시할 원의 반지름을 지정한다.
# color 속성으로 원의 색상, fill_color 속성으로 원 내부의 색상을 지정한다.

folium.CircleMarker(location=[37.579617, 126.977041], popup='경복궁',
                   radius=100, color='red', fill_color='blue').add_to(folium_map)
popup = folium.Popup('영풍문고 - 종로본점', max_width=200)
folium.CircleMarker(location=[37.5697869, 126.9823161], popup=popup,
                   radius=50, color='#48cfde', fill_color='#ee7b10').add_to(folium_map)

folium_map.save('./output/map4.html')
folium_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5a00bd22f79eb83a6cfa7b5b07eddff1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5a00bd22f79eb83a6cfa7b5b07eddff1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5a00bd22f79eb83a6cfa7b5b07eddff1 = L.map(
#                 &quot;map_5a00bd22f79eb83a6cfa7b5b07eddff1&quot;,
#                 {
#                     center: [37.5697599, 126.9836604],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b705f126f072fccbba16cde50fb5db9c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5a00bd22f79eb83a6cfa7b5b07eddff1);
#
#
#             var circle_marker_576fc1e719e5c874934acb207be4b73d = L.circleMarker(
#                 [37.579617, 126.977041],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 100, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5a00bd22f79eb83a6cfa7b5b07eddff1);
#
#
#         var popup_ffdeea58a91776deae7010a022c8f133 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eb579304a3c8c0f6325bde1acbf715ea = $(`&lt;div id=&quot;html_eb579304a3c8c0f6325bde1acbf715ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;경복궁&lt;/div&gt;`)[0];
#                 popup_ffdeea58a91776deae7010a022c8f133.setContent(html_eb579304a3c8c0f6325bde1acbf715ea);
#
#
#
#         circle_marker_576fc1e719e5c874934acb207be4b73d.bindPopup(popup_ffdeea58a91776deae7010a022c8f133)
#         ;
#
#
#
#
#             var circle_marker_9ef5b2a26603c0be24e4e380750a5e81 = L.circleMarker(
#                 [37.5697869, 126.9823161],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#48cfde&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ee7b10&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 50, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5a00bd22f79eb83a6cfa7b5b07eddff1);
#
#
#         var popup_08102c83826614c037e1f6a2fcf7990e = L.popup({&quot;maxWidth&quot;: 200});
#
#
#
#                 var html_2a622e645e6975b63fcb3d3f9e36feaa = $(`&lt;div id=&quot;html_2a622e645e6975b63fcb3d3f9e36feaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;영풍문고 - 종로본점&lt;/div&gt;`)[0];
#                 popup_08102c83826614c037e1f6a2fcf7990e.setContent(html_2a622e645e6975b63fcb3d3f9e36feaa);
#
#
#
#         circle_marker_9ef5b2a26603c0be24e4e380750a5e81.bindPopup(popup_08102c83826614c037e1f6a2fcf7990e)
#         ;
#
#
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
